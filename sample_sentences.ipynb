# %%
import pandas as pd
import numpy as np
import json

# %%
# assuming the data is located in the same directory as the notebook and the `Morphology_and_Readability.zip` file has been extracted

# %%
metadata = pd.read_excel('BAREC-10M/Data/Metadata.xlsx')
metadata.head()
# Out:
#                         Document Directory          Source          Book  \
# 0  BAREC_1001_introduction_1_001      1001  Arabian Nights  Introduction
# 1  BAREC_1001_introduction_2_001      1001  Arabian Nights  Introduction
# 2  BAREC_1001_introduction_3_001      1001  Arabian Nights  Introduction
# 3  BAREC_1001_introduction_4_001      1001  Arabian Nights  Introduction
# 4  BAREC_1001_introduction_5_001      1001  Arabian Nights  Introduction
#
#   Author             Domain  Readership Group            Text Category  \
# 0      #  Arts & Humanities  Specialized Text  Literature; Art & Music
# 1      #  Arts & Humanities  Specialized Text  Literature; Art & Music
# 2      #  Arts & Humanities  Specialized Text  Literature; Art & Music
# 3      #  Arts & Humanities  Specialized Text  Literature; Art & Music
# 4      #  Arts & Humanities  Specialized Text  Literature; Art & Music
#
#    Word Count  Sentence Count In BAREC Corpus?
# 0          73               6              Yes
# 1         730              73               No
# 2         397              47              Yes
# 3         237              23              Yes
# 4         659              62               No

# %%
metadata.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20535 entries, 0 to 20534
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Document          20535 non-null  str
#  1   Directory         20535 non-null  object
#  2   Source            20535 non-null  str
#  3   Book              20535 non-null  object
#  4   Author            20535 non-null  str
#  5   Domain            20535 non-null  str
#  6   Readership Group  20535 non-null  str
#  7   Text Category     20535 non-null  str
#  8   Word Count        20535 non-null  int64
#  9   Sentence Count    20535 non-null  int64
#  10  In BAREC Corpus?  20535 non-null  str
# dtypes: int64(2), object(2), str(7)
# memory usage: 1.7+ MB

# %%
metadata['Document'].nunique()
# Out:
# 20535

# %%
list(metadata['Source'].unique())
# Out:
# ['Arabian Nights',
#  'Arabic Learner Corpus (ALC)',
#  'ANERCorp',
#  'Arabic Poem Comprehensive Dataset (APCD)',
#  'Akhbarona News',
#  'AlArabiya News',
#  'AlKhaleej News',
#  'National Anthems',
#  'Arab Youth Publisher',
#  'ArabicMMLU',
#  'Basic Travel Expressions Corpus (BTEC)',
#  'Batman',
#  'Emarati Curriculum',
#  'DARES',
#  'Green Library',
#  'Hadith',
#  'Hayy ibn Yaqdhan',
#  'Hindawi',
#  'Kalima',
#  'Library of Arabic Literature',
#  'Ladybird',
#  'Lulu',
#  'Constitutions',
#  'Majarra',
#  'Majed',
#  'MedArabiQ',
#  'New Testament',
#  'Old Testament',
#  'Hanging Odes',
#  'Ofoq',
#  'Other Minor Sources',
#  'Quran',
#  'ReadMe++',
#  'Reading Corner',
#  'Sara',
#  'Spacetoon Songs',
#  'Subtitles',
#  'Superman',
#  'The Five Adventurers',
#  'Tunis Curriculum',
#  'UN (United Nations)',
#  'WikiNews',
#  'Wikipedia',
#  'Zayed Arabic-English Bilingual Undergraduate Corpus (ZAEBUC)',
#  'chatGPT']

# %%
metadata['Book'].nunique(), np.random.choice(list(metadata['Book'].unique()), 10), metadata['Book'].value_counts()
# Out:
# (4682,
#  array(['Riddle: 137', 'Sanka', 'The White Palace', 'Distant Memories',
#         'Riddle: 078', 'The Disguised Beauty', 'Martin Luther',
#         'The Rhinoceros and the Birds',
#         'Colors of the Short Story in American Literature', '44409'],
#        dtype='<U147'),
#  Book
#  Sports                       1010
#  Culture                      1001
#  Medical                      1000
#  Tech                         1000
#  Finance                       997
#                               ...
#  Prophet                         1
#  The Theory of the Iceberg       1
#  Nelson Mandela                  1
#  Engineering                     1
#  Volubilis                       1
#  Name: count, Length: 4682, dtype: int64)

# %%
metadata['Author'].nunique(), np.random.choice(list(metadata['Author'].unique()), 10), metadata['Author'].value_counts()
# Out:
# (2597,
#  array(['Abdul Aziz Al-Bashri', 'Khadouj', 'Nasif al-Yazji',
#         'Harriet Beecher Stowe', 'C. Julian Chen', 'Abu Hafs al-Salmi',
#         'Mahmoud Mohammed Ali', 'Mohamed Saeed al-Arian', 'Firas Hamieh',
#         'Hassan Hanafi'], dtype='<U90'),
#  Author
#  #                              15227
#  Mahmoud Salem                    337
#  Kamel Kilani                     123
#  Abbas Mahmoud Al-Aqqad            88
#  Rafeef Reda Saidawi               59
#                                 ...
#  Talal Ma’alla                      1
#  Al-Habib Istani Zain Al-Din        1
#  Hashim Qasim                       1
#  Suleiman Al-Issa                   1
#  UN (United Nations)                1
#  Name: count, Length: 2597, dtype: int64)

# %%
metadata['Domain'].value_counts()
# Out:
# Domain
# Arts & Humanities    10342
# STEM                  5444
# Social Sciences       4749
# Name: count, dtype: int64

# %%
metadata['Readership Group'].value_counts()
# Out:
# Readership Group
# Advanced Text        9165
# Specialized Text     8884
# Foundational Text    2486
# Name: count, dtype: int64

# %%
metadata['Text Category'].value_counts()
# Out:
# Text Category
# Media & Culture                                  7122
# Educational Materials; Language & Linguistics    4709
# Academic                                         4301
# Literature; Art & Music                          3974
# Religion & Philosophy                             254
# Encyclopedic                                      175
# Name: count, dtype: int64

# %%
metadata['Word Count'].describe()
# Out:
# count    20535.000000
# mean       490.731385
# std        262.089359
# min          3.000000
# 25%        278.000000
# 50%        544.000000
# 75%        622.000000
# max       5074.000000
# Name: Word Count, dtype: float64

# %%
metadata['Sentence Count'].describe()
# Out:
# count    20535.000000
# mean        25.073241
# std         25.196396
# min          1.000000
# 25%          8.000000
# 50%         17.000000
# 75%         33.000000
# max        405.000000
# Name: Sentence Count, dtype: float64

# %%
metadata['average sentence length'] = metadata['Word Count'] / metadata['Sentence Count']
metadata['average sentence length'].describe()
# Out:
# count    20535.000000
# mean        31.768280
# std         24.374336
# min          1.666667
# 25%         14.820856
# 50%         27.260870
# 75%         39.904545
# max       1107.000000
# Name: average sentence length, dtype: float64

# %%
metadata['In BAREC Corpus?'].value_counts()
# Out:
# In BAREC Corpus?
# No       18281
# Yes       2031
# ST2&3      223
# Name: count, dtype: int64

# %%
for i, text_category in enumerate(metadata['Text Category'].unique()):
    corr_domain = list(metadata[metadata['Text Category'] == text_category]['Domain'].unique())
    print(f"{i+1}: {text_category}: {corr_domain}")
# Out:
# 1: Literature; Art & Music: ['Arts & Humanities']
# 2: Educational Materials; Language & Linguistics: ['Arts & Humanities', 'Social Sciences', 'STEM']
# 3: Media & Culture: ['Arts & Humanities', 'Social Sciences', 'STEM']
# 4: Religion & Philosophy: ['Arts & Humanities']
# 5: Academic: ['Social Sciences', 'STEM', 'Arts & Humanities']
# 6: Encyclopedic: ['Social Sciences', 'STEM', 'Arts & Humanities']

# %%
for i, text_category in enumerate(metadata['Text Category'].unique()):
    corr_readership = list(metadata[metadata['Text Category'] == text_category]['Readership Group'].unique())
    print(f"{i+1}: {text_category}: {corr_readership}")
# Out:
# 1: Literature; Art & Music: ['Specialized Text', 'Foundational Text', 'Advanced Text']
# 2: Educational Materials; Language & Linguistics: ['Advanced Text', 'Foundational Text', 'Specialized Text']
# 3: Media & Culture: ['Advanced Text', 'Foundational Text']
# 4: Religion & Philosophy: ['Specialized Text']
# 5: Academic: ['Specialized Text', 'Foundational Text', 'Advanced Text']
# 6: Encyclopedic: ['Advanced Text']

# %%
LAM_df = metadata[metadata['Text Category']=='Literature; Art & Music']
print("Literature; Art & Music")
print("==========================")
print(f"Number of documents: {LAM_df.shape[0]}")
print("--------------------------")
print(f"Number of sentences: {LAM_df['Sentence Count'].sum()}")
print("--------------------------")
print(f"Number of unique books: {LAM_df['Book'].nunique()}")
print("--------------------------")
print(f"Number of unique authors: {LAM_df['Author'].nunique()}")
print("--------------------------")
print(f"Domain distribution:\n{LAM_df['Domain'].value_counts().to_dict()}")
print("--------------------------")
print(f"Readership Group distribution:\n{LAM_df['Readership Group'].value_counts().to_dict()}")
print("--------------------------")
print(f"Average sentence length distribution:\n{LAM_df['average sentence length'].describe().to_dict()}")
print("==========================")
# Out:
# Literature; Art & Music
# ==========================
# Number of documents: 3974
# --------------------------
# Number of sentences: 148343
# --------------------------
# Number of unique books: 2858
# --------------------------
# Number of unique authors: 1681
# --------------------------
# Domain distribution:
# {'Arts & Humanities': 3974}
# --------------------------
# Readership Group distribution:
# {'Specialized Text': 2286, 'Foundational Text': 1281, 'Advanced Text': 407}
# --------------------------
# Average sentence length distribution:
# {'count': 3974.0, 'mean': 16.17055897763152, 'std': 11.658903148591186, 'min': 2.526315789473684, '25%': 9.317993557294063, '50%': 12.6, '75%': 19.884615384615383, 'max': 221.33333333333334}
# ==========================

# %%
LAM_foundational_df = LAM_df[LAM_df['Readership Group']=='Foundational Text']
print("Literature; Art & Music - Foundational")
print("==========================")
print(f"Number of documents: {LAM_foundational_df.shape[0]}")
print("--------------------------")
print(f"Number of sentences: {LAM_foundational_df['Sentence Count'].sum()}")
print("--------------------------")
print(f"Number of unique books: {LAM_foundational_df['Book'].nunique()}")
print("--------------------------")
print(f"Number of unique authors: {LAM_foundational_df['Author'].nunique()}")
print("--------------------------")
print(f"Domain distribution:\n{LAM_foundational_df['Domain'].value_counts().to_dict()}")
print("--------------------------")
print(f"Average sentence length distribution:\n{LAM_foundational_df['average sentence length'].describe().to_dict()}")
print("==========================")
# Out:
# Literature; Art & Music - Foundational
# ==========================
# Number of documents: 1281
# --------------------------
# Number of sentences: 58143
# --------------------------
# Number of unique books: 1009
# --------------------------
# Number of unique authors: 32
# --------------------------
# Domain distribution:
# {'Arts & Humanities': 1281}
# --------------------------
# Average sentence length distribution:
# {'count': 1281.0, 'mean': 13.908297148843703, 'std': 6.7821186229810015, 'min': 2.652173913043478, '25%': 8.620689655172415, '50%': 13.263157894736842, '75%': 17.609756097560975, 'max': 56.111111111111114}
# ==========================

# %%
sampled_LAM_foundational_df = LAM_foundational_df.sample(17, random_state=42)

# %%
sampled_LAM_foundational_df
# Out:
#                                                 Document           Directory  \
# 20002               BAREC_TheFiveAdventurers_149 لغز_001  TheFiveAdventurers
# 15247                         BAREC_Hindawi_97962586_001             Hindawi
# 19981               BAREC_TheFiveAdventurers_128 لغز_001  TheFiveAdventurers
# 15889                   BAREC_Ladybird_القدر السحرية_001            Ladybird
# 14792                         BAREC_Hindawi_83941583_001             Hindawi
# 19686                 BAREC_SpacetoonSong_أنا وأخي_001       SpacetoonSong
# 12666                         BAREC_Hindawi_17290296_001             Hindawi
# 19823                             BAREC_Superman_070_011            Superman
# 12837                         BAREC_Hindawi_24146069_001             Hindawi
# 20002                12.925926
# 15247                12.948718
# 19981                15.704545
# 15889                11.250000
# 14792                24.090909
# 19686                 4.000000
# 12666                21.739130
# 19823                 8.116279
# 12837                14.000000
# 19930                10.750000
# 19853                 7.802632
# 12664                12.803922
# 7760                 12.727273
# 7739                 19.600000
# 19783                 9.803279
# 19986                12.490566
# 19738                 8.608696

# %%
sampled_LAM_foundational_sentences_indices = []
for i, row in sampled_LAM_foundational_df.iterrows():
    directory = row['Directory']
    document = row['Document']
    annotations_file_path = f"BAREC-10M/Data/Morphology_and_Readability/{directory}/{document}.json"

    with open(annotations_file_path, 'r', encoding='utf-8') as f:
        annotations = json.load(f)
        annotations = pd.DataFrame(annotations)
    

    sampled_index = annotations[annotations['sents_word_count'] > 5].sample(1, random_state=42).index.item()
    sampled_LAM_foundational_sentences_indices.append(sampled_index)
print(sampled_LAM_foundational_sentences_indices)
# Out:
# [45, 10, 20, 49, 1, 10, 1, 16, 21, 27, 66, 28, 3, 4, 54, 33, 60]

# %%
sampled_LAM_foundational_df['sampled_sentence_index'] = sampled_LAM_foundational_sentences_indices

# %%
LAM_advanced_df = LAM_df[LAM_df['Readership Group']=='Advanced Text']
print("Literature; Art & Music - Advanced")
print("==========================")
print(f"Number of documents: {LAM_advanced_df.shape[0]}")
print("--------------------------")
print(f"Number of sentences: {LAM_advanced_df['Sentence Count'].sum()}")
print("--------------------------")
print(f"Number of unique books: {LAM_advanced_df['Book'].nunique()}")
print("--------------------------")
print(f"Number of unique authors: {LAM_advanced_df['Author'].nunique()}")
print("--------------------------")
print(f"Domain distribution:\n{LAM_advanced_df['Domain'].value_counts().to_dict()}")
print("--------------------------")
print(f"Average sentence length distribution:\n{LAM_advanced_df['average sentence length'].describe().to_dict()}")
print("==========================")
# Out:
# Literature; Art & Music - Advanced
# ==========================
# Number of documents: 407
# --------------------------
# Number of sentences: 13216
# --------------------------
# Number of unique books: 390
# --------------------------
# Number of unique authors: 107
# --------------------------
# Domain distribution:
# {'Arts & Humanities': 407}
# --------------------------
# Average sentence length distribution:
# {'count': 407.0, 'mean': 20.54016798418344, 'std': 11.93829403319979, 'min': 4.239316239316239, '25%': 13.561561561561561, '50%': 17.857142857142858, '75%': 24.11904761904762, 'max': 128.25}
# ==========================

# %%
sampled_LAM_advanced_df = LAM_advanced_df.sample(16, random_state=42)

# %%
sampled_LAM_advanced_df
# Out:
#                          Document Directory               Source  \
# 13033  BAREC_Hindawi_28648582_001   Hindawi              Hindawi
# 14107  BAREC_Hindawi_62505363_001   Hindawi              Hindawi
# 14368  BAREC_Hindawi_71693707_001   Hindawi              Hindawi
# 12727  BAREC_Hindawi_18686373_001   Hindawi              Hindawi
# 12795  BAREC_Hindawi_20429368_001   Hindawi              Hindawi
# 13064  BAREC_Hindawi_29392697_001   Hindawi              Hindawi
# 13515  BAREC_Hindawi_42475809_001   Hindawi              Hindawi
# 14867  BAREC_Hindawi_85802403_001   Hindawi              Hindawi
# 14287  BAREC_Hindawi_69407460_001   Hindawi              Hindawi
# 14412  BAREC_Hindawi_72735281_001   Hindawi              Hindawi
# 15102  BAREC_Hindawi_94264040_001   Hindawi              Hindawi
# 13066  BAREC_Hindawi_29403629_001   Hindawi              Hindawi
# 14492  BAREC_Hindawi_74859409_001   Hindawi              Hindawi
# 19437     BAREC_Other_الكشكول_001     Other  Other Minor Sources
# 13648  BAREC_Hindawi_48293606_001   Hindawi              Hindawi
# 13846  BAREC_Hindawi_52951836_001   Hindawi              Hindawi
#
#                                              Book                Author  \
# 13033                                    Ragnarok   Antonia Susan Byatt
# 14107                     Steps in the Same River        Riyadh Hammadi
# 14368                     Cases of John Thorndike     R. Austin Freeman
# 12727                        The Gentle Strongman        Naguib Mahfouz
# 12795                         The Younger Brother         Corey Ductoro
# 13064                      The Virtuous Successor       Wadi’ Abu Fadil
# 13515            The Mystery of the Lost Necklace         Jack Footrell
# 14867                      The Thief and the Dogs        Naguib Mahfouz
# 14287                        The Heart of a Woman     Ponson du Terrail
# 14412                              The Earth Gods  Gibran Khalil Gibran
# 15102  The Big Portrait Mystery and Other Stories     R. Austin Freeman
# 13066     I Am the Sultan of the Law of Existence           Yusuf Idris
# 14492                           The Amazing Visit  Herbert George Wells
# 19437                                 al-Kashkuul          Bayan Safadi
# 13648                     The Specter of the Soul  Edward Page Mitchell
# 13846               The Adventure of Sherlo Combs           Robert Barr
#
#                   Domain Readership Group            Text Category  \
# 13033  Arts & Humanities    Advanced Text  Literature; Art & Music
# 14107  Arts & Humanities    Advanced Text  Literature; Art & Music
# 14368  Arts & Humanities    Advanced Text  Literature; Art & Music
# 12727  Arts & Humanities    Advanced Text  Literature; Art & Music
# 12795  Arts & Humanities    Advanced Text  Literature; Art & Music
# 13064  Arts & Humanities    Advanced Text  Literature; Art & Music
# 13515  Arts & Humanities    Advanced Text  Literature; Art & Music
# 14867  Arts & Humanities    Advanced Text  Literature; Art & Music
# 14287  Arts & Humanities    Advanced Text  Literature; Art & Music
# 14412  Arts & Humanities    Advanced Text  Literature; Art & Music
# 15102  Arts & Humanities    Advanced Text  Literature; Art & Music
# 13066  Arts & Humanities    Advanced Text  Literature; Art & Music
# 14492  Arts & Humanities    Advanced Text  Literature; Art & Music
# 19437  Arts & Humanities    Advanced Text  Literature; Art & Music
# 13648  Arts & Humanities    Advanced Text  Literature; Art & Music
# 13846  Arts & Humanities    Advanced Text  Literature; Art & Music
#
#        Word Count  Sentence Count In BAREC Corpus?  average sentence length
# 13033        1366              82              Yes                16.658537
# 14107         505              81               No                 6.234568
# 14368         501              23               No                21.782609
# 12727         502              27               No                18.592593
# 12795         887              46              Yes                19.282609
# 13064         544              18               No                30.222222
# 13515         516              23               No                22.434783
# 14867         524              26               No                20.153846
# 14287         544              26               No                20.923077
# 14412         503              61               No                 8.245902
# 15102         517              43               No                12.023256
# 13066         740              46              Yes                16.086957
# 14492         629              39              Yes                16.128205
# 19437         287              15              Yes                19.133333
# 13648         500              26               No                19.230769
# 13846         504              48               No                10.500000

# %%
sampled_LAM_advanced_sentences_indices = []
for i, row in sampled_LAM_advanced_df.iterrows():
    directory = row['Directory']
    document = row['Document']
    annotations_file_path = f"BAREC-10M/Data/Morphology_and_Readability/{directory}/{document}.json"

    with open(annotations_file_path, 'r', encoding='utf-8') as f:
        annotations = json.load(f)
        annotations = pd.DataFrame(annotations)
    

    sampled_index = annotations[annotations['sents_word_count'] > 5].sample(1, random_state=42).index.item()
    sampled_LAM_advanced_sentences_indices.append(sampled_index)
print(sampled_LAM_advanced_sentences_indices)
# Out:
# [5, 46, 1, 1, 39, 12, 1, 1, 9, 16, 15, 21, 18, 9, 2, 20]

# %%
sampled_LAM_advanced_df['sampled_sentence_index'] = sampled_LAM_advanced_sentences_indices

# %%
LAM_specialized_df = LAM_df[LAM_df['Readership Group']=='Specialized Text']
print("Literature; Art & Music - Specialized")
print("==========================")
print(f"Number of documents: {LAM_specialized_df.shape[0]}")
print("--------------------------")
print(f"Number of sentences: {LAM_specialized_df['Sentence Count'].sum()}")
print("--------------------------")
print(f"Number of unique books: {LAM_specialized_df['Book'].nunique()}")
print("--------------------------")
print(f"Number of unique authors: {LAM_specialized_df['Author'].nunique()}")
print("--------------------------")
print(f"Domain distribution:\n{LAM_specialized_df['Domain'].value_counts().to_dict()}")
print("--------------------------")
print(f"Average sentence length distribution:\n{LAM_specialized_df['average sentence length'].describe().to_dict()}")
print("==========================")
# Out:
# Literature; Art & Music - Specialized
# ==========================
# Number of documents: 2286
# --------------------------
# Number of sentences: 76984
# --------------------------
# Number of unique books: 1464
# --------------------------
# Number of unique authors: 1568
# --------------------------
# Domain distribution:
# {'Arts & Humanities': 2286}
# --------------------------
# Average sentence length distribution:
# {'count': 2286.0, 'mean': 16.660290621118204, 'std': 13.36958423325814, 'min': 2.526315789473684, '25%': 9.314814814814815, '50%': 10.666666666666666, '75%': 20.962222222222223, 'max': 221.33333333333334}
# ==========================

# %%
sampled_LAM_specialized_df = LAM_specialized_df.sample(17, random_state=42)

# %%
sampled_LAM_specialized_df
# Out:
#                                                 Document Directory  \
# 13887                         BAREC_Hindawi_53957515_001   Hindawi
# 12902                         BAREC_Hindawi_25817168_001   Hindawi
# 13898                         BAREC_Hindawi_57097372_001   Hindawi
# 1077    BAREC_APCD_علي بن أبي طالب_الديوان الرئيسي_001      APCD
# 15676                               BAREC_Kalima_عدو_001    Kalima
# 808     BAREC_APCD_جرجس عيسى السكاف_الديوان الرئيسي_001      APCD
# 975    BAREC_APCD_شيخ الدولة البركردزي_شيخ الدولة الب...      APCD
# 15692                     BAREC_Kalima_غوته_ونابليون_001    Kalima
# 15280                  BAREC_Kalima_الاسلام_الايطالي_001    Kalima
# 14933                         BAREC_Hindawi_86952059_001   Hindawi
# 643    BAREC_APCD_أبو جعفر الزوزني الزاهد_أبو جعفر ...      APCD
# 14160                         BAREC_Hindawi_63795362_001   Hindawi
# 13432                         BAREC_Hindawi_40702826_001   Hindawi
# 448               BAREC_APCD_الحبسي_الديوان الرئيسي_001      APCD
# 627    BAREC_APCD_أبو المواهب المعري_أبو المواهب ال...      APCD
# 13756                         BAREC_Hindawi_50926304_001   Hindawi
# 15642     BAREC_Kalima_شعراء_القرن_16_بيير_دو_رونسار_001    Kalima
#
#                                          Source  \
# 13887                                   Hindawi
# 12902                                   Hindawi
# 13898                                   Hindawi
# 1077   Arabic Poem Comprehensive Dataset (APCD)
# 15676                                    Kalima
# 808    Arabic Poem Comprehensive Dataset (APCD)
# 975    Arabic Poem Comprehensive Dataset (APCD)
# 15692                                    Kalima
# 15280                                    Kalima
# 14933                                   Hindawi
# 643    Arabic Poem Comprehensive Dataset (APCD)
# 14160                                   Hindawi
# 13432                                   Hindawi
# 448    Arabic Poem Comprehensive Dataset (APCD)
# 627    Arabic Poem Comprehensive Dataset (APCD)
# 13756                                   Hindawi
# 15642                                    Kalima
#
#                                                     Book  \
# 13887                                  Gardens and Satan
# 12902                             Letters of Holy Ankara
# 13898                                            Breezes
# 1077                                      The Main Diwan
# 15676                                            Running
# 808                                       The Main Diwan
# 975                         Shaykh Al-Dawla Al-Barkardzi
# 15692        Goethe and Napoleon: A Historical Encounter
# 15280  Italian Islam: A Journey Through the Realities...
# 14933                       My Diaries in Women’s Prison
# 643                        Abu Ja'far Al-Zuzani Al-Zahid
# 14160                                     Complete Works
# 13432                                     Roland Barthes
# 448                                       The Main Diwan
# 627                            Abu Al-Mawahib Al-Ma'arri
# 13756                             Letters of the Orators
# 15642                        Sixteenth Century Poets (3)
#
#                                         Author             Domain  \
# 13887                         Nawal El-Saadawi  Arts & Humanities
# 12902                          Qudriya Hussein  Arts & Humanities
# 13898                              Salma Saigh  Arts & Humanities
# 1077                         Ali ibn Abi Talib  Arts & Humanities
# 15676                             Jean Echenoz  Arts & Humanities
# 808                       Jurjis Isa al-Sakkaf  Arts & Humanities
# 975               Shaykh Al-Dawla Al-Barkardzi  Arts & Humanities
# 15692                            Gustave Seibt  Arts & Humanities
# 15280                           Stefano Alievi  Arts & Humanities
# 14933                         Nawal El-Saadawi  Arts & Humanities
# 643              Abu Ja'far Al-Zuzani Al-Zahid  Arts & Humanities
# 14160  Poet of the Nile Muhammad Hafiz Ibrahim  Arts & Humanities
# 13432                          Jonathan Koller  Arts & Humanities
# 448                                   Al-Habsi  Arts & Humanities
# 627                  Abu Al-Mawahib Al-Ma'arri  Arts & Humanities
# 13756                         Mohamed Kurd Ali  Arts & Humanities
# 15642                        Pierre de Ronsard  Arts & Humanities
#
#        Readership Group            Text Category  Word Count  Sentence Count  \
# 13887  Specialized Text  Literature; Art & Music         505              26
# 12902  Specialized Text  Literature; Art & Music         523              20
# 13898  Specialized Text  Literature; Art & Music         506              32
# 1077   Specialized Text  Literature; Art & Music         501              52
# 15676  Specialized Text  Literature; Art & Music         687              47
# 808    Specialized Text  Literature; Art & Music         503              61
# 975    Specialized Text  Literature; Art & Music          38               4
# 15692  Specialized Text  Literature; Art & Music         729              35
# 15280  Specialized Text  Literature; Art & Music         748              31
# 14933  Specialized Text  Literature; Art & Music         526              16
# 643    Specialized Text  Literature; Art & Music          16               2
# 14160  Specialized Text  Literature; Art & Music         504              85
# 13432  Specialized Text  Literature; Art & Music         513              23
# 448    Specialized Text  Literature; Art & Music         507              62
# 627    Specialized Text  Literature; Art & Music          52               5
# 13756  Specialized Text  Literature; Art & Music         521              21
# 15642  Specialized Text  Literature; Art & Music         686              47
#
#       In BAREC Corpus?  average sentence length
# 13887               No                19.423077
# 12902               No                26.150000
# 13898               No                15.812500
# 1077                No                 9.634615
# 15676              Yes                14.617021
# 808                 No                 8.245902
# 975                 No                 9.500000
# 15692               No                20.828571
# 15280               No                24.129032
# 14933               No                32.875000
# 643                 No                 8.000000
# 14160               No                 5.929412
# 13432               No                22.304348
# 448                 No                 8.177419
# 627                 No                10.400000
# 13756               No                24.809524
# 15642               No                14.595745

# %%
sampled_LAM_specialized_sentences_indices = []
for i, row in sampled_LAM_specialized_df.iterrows():
    directory = row['Directory']
    document = row['Document']
    annotations_file_path = f"BAREC-10M/Data/Morphology_and_Readability/{directory}/{document}.json"

    with open(annotations_file_path, 'r', encoding='utf-8') as f:
        annotations = json.load(f)
        annotations = pd.DataFrame(annotations)
    

    sampled_index = annotations[annotations['sents_word_count'] > 5].sample(1, random_state=42).index.item()
    sampled_LAM_specialized_sentences_indices.append(sampled_index)
print(sampled_LAM_specialized_sentences_indices)
# Out:
# [9, 1, 11, 19, 30, 0, 1, 15, 5, 11, 1, 22, 1, 0, 1, 2, 27]

# %%
sampled_LAM_specialized_df['sampled_sentence_index'] = sampled_LAM_specialized_sentences_indices

# %%
A_df = pd.concat([sampled_LAM_foundational_df, sampled_LAM_advanced_df, sampled_LAM_specialized_df], ignore_index=True)
A_df
# Out:
#                                              Document           Directory  \
# 0                BAREC_TheFiveAdventurers_149 لغز_001  TheFiveAdventurers
# 1                          BAREC_Hindawi_97962586_001             Hindawi
# 2                BAREC_TheFiveAdventurers_128 لغز_001  TheFiveAdventurers
# 3                    BAREC_Ladybird_القدر السحرية_001            Ladybird
# 4                          BAREC_Hindawi_83941583_001             Hindawi
# 5                  BAREC_SpacetoonSong_أنا وأخي_001       SpacetoonSong
# 6                          BAREC_Hindawi_17290296_001             Hindawi
# 7                              BAREC_Superman_070_011            Superman
# 8                          BAREC_Hindawi_24146069_001             Hindawi
# 9                BAREC_TheFiveAdventurers_077 لغز_001  TheFiveAdventurers
# 10                             BAREC_Superman_100_010            Superman
# 11                         BAREC_Hindawi_17271461_001             Hindawi
# 12  BAREC_ArabYouthPublisher_مالك الحزين يشتري حذا...  ArabYouthPublisher
# 13          BAREC_ArabYouthPublisher_جزيرة الضياع_001  ArabYouthPublisher
# 14                             BAREC_Superman_040_010            Superman
# 15               BAREC_TheFiveAdventurers_133 لغز_001  TheFiveAdventurers
# 16                             BAREC_Superman_010_011            Superman
# 17                         BAREC_Hindawi_28648582_001             Hindawi
# 18                         BAREC_Hindawi_62505363_001             Hindawi
# 19                         BAREC_Hindawi_71693707_001             Hindawi
# 20                         BAREC_Hindawi_18686373_001             Hindawi
# 21                         BAREC_Hindawi_20429368_001             Hindawi
# 22                         BAREC_Hindawi_29392697_001             Hindawi
# 23                         BAREC_Hindawi_42475809_001             Hindawi
# 24                         BAREC_Hindawi_85802403_001             Hindawi
# 25                         BAREC_Hindawi_69407460_001             Hindawi
# 26                         BAREC_Hindawi_72735281_001             Hindawi
# 27                         BAREC_Hindawi_94264040_001             Hindawi
# 28                         BAREC_Hindawi_29403629_001             Hindawi
# 29                         BAREC_Hindawi_74859409_001             Hindawi
# 30                            BAREC_Other_الكشكول_001               Other
# 31                         BAREC_Hindawi_48293606_001             Hindawi
# 32                         BAREC_Hindawi_52951836_001             Hindawi
# 33                         BAREC_Hindawi_53957515_001             Hindawi
# 34                         BAREC_Hindawi_25817168_001             Hindawi
# 35                         BAREC_Hindawi_57097372_001             Hindawi
# 36   BAREC_APCD_علي بن أبي طالب_الديوان الرئيسي_001                APCD
# 37                               BAREC_Kalima_عدو_001              Kalima
# 38   BAREC_APCD_جرجس عيسى السكاف_الديوان الرئيسي_001                APCD
# 39  BAREC_APCD_شيخ الدولة البركردزي_شيخ الدولة الب...                APCD
# 40                     BAREC_Kalima_غوته_ونابليون_001              Kalima
# 41                  BAREC_Kalima_الاسلام_الايطالي_001              Kalima
# 42                         BAREC_Hindawi_86952059_001             Hindawi
# 43  BAREC_APCD_أبو جعفر الزوزني الزاهد_أبو جعفر ...                APCD
# 44                         BAREC_Hindawi_63795362_001             Hindawi
# 45                         BAREC_Hindawi_40702826_001             Hindawi
# 46             BAREC_APCD_الحبسي_الديوان الرئيسي_001                APCD
# 47  BAREC_APCD_أبو المواهب المعري_أبو المواهب ال...                APCD
# 48                         BAREC_Hindawi_50926304_001             Hindawi
# 49     BAREC_Kalima_شعراء_القرن_16_بيير_دو_رونسار_001              Kalima
#
#                                       Source  \
# 0                       The Five Adventurers
# 1                                    Hindawi
# 2                       The Five Adventurers
# 3                                   Ladybird
# 4                                    Hindawi
# 5                            Spacetoon Songs
# 6                                    Hindawi
# 7                                   Superman
# 8                                    Hindawi
# 9                       The Five Adventurers
# 10                                  Superman
# 11                                   Hindawi
# 12                      Arab Youth Publisher
# 13                      Arab Youth Publisher
# 20      Advanced Text  Literature; Art & Music         502              27
# 21      Advanced Text  Literature; Art & Music         887              46
# 22      Advanced Text  Literature; Art & Music         544              18
# 23      Advanced Text  Literature; Art & Music         516              23
# 24      Advanced Text  Literature; Art & Music         524              26
# 25      Advanced Text  Literature; Art & Music         544              26
# 26      Advanced Text  Literature; Art & Music         503              61
# 27      Advanced Text  Literature; Art & Music         517              43
# 28      Advanced Text  Literature; Art & Music         740              46
# 29      Advanced Text  Literature; Art & Music         629              39
# 30      Advanced Text  Literature; Art & Music         287              15
# 31      Advanced Text  Literature; Art & Music         500              26
# 32      Advanced Text  Literature; Art & Music         504              48
# 33   Specialized Text  Literature; Art & Music         505              26
# 34   Specialized Text  Literature; Art & Music         523              20
# 35   Specialized Text  Literature; Art & Music         506              32
# 36   Specialized Text  Literature; Art & Music         501              52
# 37   Specialized Text  Literature; Art & Music         687              47
# 38   Specialized Text  Literature; Art & Music         503              61
# 39   Specialized Text  Literature; Art & Music          38               4
# 40   Specialized Text  Literature; Art & Music         729              35
# 41   Specialized Text  Literature; Art & Music         748              31
# 42   Specialized Text  Literature; Art & Music         526              16
# 43   Specialized Text  Literature; Art & Music          16               2
# 44   Specialized Text  Literature; Art & Music         504              85
# 45   Specialized Text  Literature; Art & Music         513              23
# 46   Specialized Text  Literature; Art & Music         507              62
# 47   Specialized Text  Literature; Art & Music          52               5
# 48   Specialized Text  Literature; Art & Music         521              21
# 49   Specialized Text  Literature; Art & Music         686              47
#
#    In BAREC Corpus?  average sentence length  sampled_sentence_index
# 0                No                12.925926                      45
# 1                No                12.948718                      10
# 2                No                15.704545                      20
# 3                No                11.250000                      49
# 4                No                24.090909                       1
# 5               Yes                 4.000000                      10
# 6                No                21.739130                       1
# 7                No                 8.116279                      16
# 8                No                14.000000                      21
# 9                No                10.750000                      27
# 10               No                 7.802632                      66
# 11              Yes                12.803922                      28
# 12               No                12.727273                       3
# 13               No                19.600000                       4
# 14               No                 9.803279                      54
# 15               No                12.490566                      33
# 16               No                 8.608696                      60
# 17              Yes                16.658537                       5
# 18               No                 6.234568                      46
# 19               No                21.782609                       1
# 20               No                18.592593                       1
# 21              Yes                19.282609                      39
# 22               No                30.222222                      12
# 23               No                22.434783                       1
# 24               No                20.153846                       1
# 25               No                20.923077                       9
# 26               No                 8.245902                      16
# 27               No                12.023256                      15
# 28              Yes                16.086957                      21
# 29              Yes                16.128205                      18
# 30              Yes                19.133333                       9
# 31               No                19.230769                       2
# 32               No                10.500000                      20
# 33               No                19.423077                       9
# 34               No                26.150000                       1
# 35               No                15.812500                      11
# 36               No                 9.634615                      19
# 37              Yes                14.617021                      30
# 38               No                 8.245902                       0
# 39               No                 9.500000                       1
# 40               No                20.828571                      15
# 41               No                24.129032                       5
# 42               No                32.875000                      11
# 43               No                 8.000000                       1
# 44               No                 5.929412                      22
# 45               No                22.304348                       1
# 46               No                 8.177419                       0
# 47               No                10.400000                       1
# 48               No                24.809524                       2
# 49               No                14.595745                      27

# %%
A_df['selected_sent_raw'] = None
A_df['selected_sent_word_count'] = None
A_df['selected_sent_words'] = None

for i, row in A_df.iterrows():
    directory = row['Directory']
    document = row['Document']

    annotations_file_path = (
        f"BAREC-10M/Data/Morphology_and_Readability/"
        f"{directory}/{document}.json"
    )

    with open(annotations_file_path, 'r', encoding='utf-8') as f:
        annotations = json.load(f)

    annotations = pd.DataFrame(annotations)

    selected_sentence_index = int(row['sampled_sentence_index'])

    selected_row = annotations.iloc[selected_sentence_index]

    raw_sentence = selected_row['raw_sents']
    word_count = selected_row['sents_word_count']
    words = selected_row['word']   # list of strings

    A_df.at[i, 'selected_sent_raw'] = raw_sentence
    A_df.at[i, 'selected_sent_word_count'] = word_count
    A_df.at[i, 'selected_sent_words'] = words

# %%
A_df = A_df[[
    'Directory',
    'Document',
    'sampled_sentence_index',
    'Source',
    'Book',
    'Author',
    'Domain',
    'Readership Group',
    'Text Category',
    'average sentence length',
    'selected_sent_raw',
    'selected_sent_word_count',
    'selected_sent_words'
]]

# %%
A_df.rename(columns={
    'average sentence length': 'average_sentence_length_per_doc',
}, inplace=True)

# %%
A_df
# Out:
#              Directory                                           Document  \
# 0   TheFiveAdventurers               BAREC_TheFiveAdventurers_149 لغز_001
# 1              Hindawi                         BAREC_Hindawi_97962586_001
# 2   TheFiveAdventurers               BAREC_TheFiveAdventurers_128 لغز_001
# 3             Ladybird                   BAREC_Ladybird_القدر السحرية_001
# 4              Hindawi                         BAREC_Hindawi_83941583_001
# 5        SpacetoonSong                 BAREC_SpacetoonSong_أنا وأخي_001
# 6              Hindawi                         BAREC_Hindawi_17290296_001
# 7             Superman                             BAREC_Superman_070_011
# 8              Hindawi                         BAREC_Hindawi_24146069_001
# 9   TheFiveAdventurers               BAREC_TheFiveAdventurers_077 لغز_001
# 10            Superman                             BAREC_Superman_100_010
# 11             Hindawi                         BAREC_Hindawi_17271461_001
# 12  ArabYouthPublisher  BAREC_ArabYouthPublisher_مالك الحزين يشتري حذا...
# 13  ArabYouthPublisher          BAREC_ArabYouthPublisher_جزيرة الضياع_001
# 14            Superman                             BAREC_Superman_040_010
# 15  TheFiveAdventurers               BAREC_TheFiveAdventurers_133 لغز_001
# 16            Superman                             BAREC_Superman_010_011
# 17             Hindawi                         BAREC_Hindawi_28648582_001
# 18             Hindawi                         BAREC_Hindawi_62505363_001
# 19             Hindawi                         BAREC_Hindawi_71693707_001
# 20             Hindawi                         BAREC_Hindawi_18686373_001
# 21             Hindawi                         BAREC_Hindawi_20429368_001
# 22             Hindawi                         BAREC_Hindawi_29392697_001
# 23             Hindawi                         BAREC_Hindawi_42475809_001
# 24             Hindawi                         BAREC_Hindawi_85802403_001
# 25             Hindawi                         BAREC_Hindawi_69407460_001
# 26             Hindawi                         BAREC_Hindawi_72735281_001
# 27             Hindawi                         BAREC_Hindawi_94264040_001
# 28             Hindawi                         BAREC_Hindawi_29403629_001
# 29             Hindawi                         BAREC_Hindawi_74859409_001
# 30               Other                            BAREC_Other_الكشكول_001
# 31             Hindawi                         BAREC_Hindawi_48293606_001
# 32             Hindawi                         BAREC_Hindawi_52951836_001
# 33             Hindawi                         BAREC_Hindawi_53957515_001
# 34             Hindawi                         BAREC_Hindawi_25817168_001
# 35             Hindawi                         BAREC_Hindawi_57097372_001
# 36                APCD   BAREC_APCD_علي بن أبي طالب_الديوان الرئيسي_001
# 37              Kalima                               BAREC_Kalima_عدو_001
# 38                APCD   BAREC_APCD_جرجس عيسى السكاف_الديوان الرئيسي_001
# 39                APCD  BAREC_APCD_شيخ الدولة البركردزي_شيخ الدولة الب...
# 40              Kalima                     BAREC_Kalima_غوته_ونابليون_001
# 41              Kalima                  BAREC_Kalima_الاسلام_الايطالي_001
# 42             Hindawi                         BAREC_Hindawi_86952059_001
# 43                APCD  BAREC_APCD_أبو جعفر الزوزني الزاهد_أبو جعفر ...
# 44             Hindawi                         BAREC_Hindawi_63795362_001
# 45             Hindawi                         BAREC_Hindawi_40702826_001
# 46                APCD             BAREC_APCD_الحبسي_الديوان الرئيسي_001
# 47                APCD  BAREC_APCD_أبو المواهب المعري_أبو المواهب ال...
# 48             Hindawi                         BAREC_Hindawi_50926304_001
# 49              Kalima     BAREC_Kalima_شعراء_القرن_16_بيير_دو_رونسار_001
#
#     sampled_sentence_index                                    Source  \
# 0                       45                      The Five Adventurers
# 1                       10                                   Hindawi
# 2                       20                      The Five Adventurers
# 3                       49                                  Ladybird
# 4                        1                                   Hindawi
# 5                       10                           Spacetoon Songs
# 6                        1                                   Hindawi
# 7                       16                                  Superman
# 8                       21                                   Hindawi
# 9                       27                      The Five Adventurers
# 10                      66                                  Superman
# 11                      28                                   Hindawi
# 12                       3                      Arab Youth Publisher
# 13                       4                      Arab Youth Publisher
# 14                      54                                  Superman
# 15                      33                      The Five Adventurers
# 16                      60                                  Superman
# 17                       5                                   Hindawi
# 18                      46                                   Hindawi
# 19                       1                                   Hindawi
# 20                       1                                   Hindawi
# 21                      39                                   Hindawi
# 22                      12                                   Hindawi
# 23                       1                                   Hindawi
# 24                       1                                   Hindawi
# 25                       9                                   Hindawi
# 26                      16                                   Hindawi
# 27                      15                                   Hindawi
# 28                      21                                   Hindawi
# 29                      18                                   Hindawi
# 30                       9                       Other Minor Sources
# 31                       2                                   Hindawi
# 32                      20                                   Hindawi
# 33                       9                                   Hindawi
# 34                       1                                   Hindawi
# 35                      11                                   Hindawi
# 36                      19  Arabic Poem Comprehensive Dataset (APCD)
# 37                      30                                    Kalima
# 38                       0  Arabic Poem Comprehensive Dataset (APCD)
# 39                       1  Arabic Poem Comprehensive Dataset (APCD)
# 40                      15                                    Kalima
# 41                       5                                    Kalima
# 42                      11                                   Hindawi
# 43                       1  Arabic Poem Comprehensive Dataset (APCD)
# 44                      22                                   Hindawi
# 45                       1                                   Hindawi
# 46                       0  Arabic Poem Comprehensive Dataset (APCD)
# 47                       1  Arabic Poem Comprehensive Dataset (APCD)
# 48                       2                                   Hindawi
# 49                      27                                    Kalima
#
#                                                  Book  \
# 0                                         Riddle: 149
# 1                       Baba Abdullah and the Dervish
# 2                                         Riddle: 128
# 3                                       The Magic Pot
# 4                                   The Poplar Forest
# 5                                   Me and My Brother
# 6                                     Information War
# 7                                         Edition: 70
# 11                        12.803922
# 12                        12.727273
# 13                        19.600000
# 14                         9.803279
# 15                        12.490566
# 16                         8.608696
# 17                        16.658537
# 18                         6.234568
# 19                        21.782609
# 20                        18.592593
# 21                        19.282609
# 22                        30.222222
# 23                        22.434783
# 24                        20.153846
# 25                        20.923077
# 26                         8.245902
# 27                        12.023256
# 28                        16.086957
# 29                        16.128205
# 30                        19.133333
# 31                        19.230769
# 32                        10.500000
# 33                        19.423077
# 34                        26.150000
# 35                        15.812500
# 36                         9.634615
# 37                        14.617021
# 38                         8.245902
# 39                         9.500000
# 40                        20.828571
# 41                        24.129032
# 42                        32.875000
# 43                         8.000000
# 44                         5.929412
# 45                        22.304348
# 46                         8.177419
# 47                        10.400000
# 48                        24.809524
# 49                        14.595745
#
#                                     selected_sent_raw  \
# 0                     وسوف أبدؤها بزيارة أخي "طلعت"..
# 1   وَبَيْنا كانَ عَائِدًا وَجَدَ — فِي طَرِيقِهِ ...
# 2   أجاب "ممدوح" وهو يجري مبتعدًا: ليس عندي وقت لم...
# 3   أما القدر الصغيرة فإنها واصلت طبخ المهلبية طبخ...
# 4                             رقم «١»: «أحمد» من مصر.
# 5   لو سرقت منا الأيام قلبا معطاء بسّام لن نستسلم ...
# 6                             رقم «١»: «أحمد» من مصر.
# 7                         ما أسهل سرقة المصرف الآن...
# 8   وقد تَجاوَزَ المدخل بِمَنْكِبَيْهِ العَريضَين،...
# 9                    وأخذت السيدة العجوز تشير بيدها..
# 10                        فتح "سوبرمان" خزانة خفية...
# 11      ثم استدار إلى كورا وساعدها على امتطاء حصانها.
# 12  ذهب "مالك الحزين" مع زوجته إلى سوق الأحذية ليش...
# 13  تحطمت سفينة السائحين وغرقت في بحر الظلمات، واس...
# 14    نجحت خطة "الفتى الجبار" ولفت المعطف نظر كلبه...
# 15  وقد تردد أن الثري المصري على علاقة بهذا المهرب...
# 16                           يجب أن أبعد هذا الصاروخ!
# 17  كانت الحياةُ عبارة عن حالة تدور فيها رحى حرب م...
# 18                تنافَسَ تجار الفنون على لوحة بيضاء،
# 19  في اعتقادي أنه ليس هناك الكثير من الأماكن حتى ...
# 20  جلس ينظر إلى صورته في المرآة الكبيرة، ويتابع ب...
# 21  كان فريدريك بينسان — رقم الضمان الاجتماعي ٥٤٥-...
# 22  حاشا للدين أنْ يكون كما تفعلون وإلَّا كان الكف...
# 23  في صباح اليوم التالي تلقَّى «مُحب» رسالة من «ت...
# 24  نظر إلى الباب المفتوح، المفتوح دائمًا كما عهِد...
# 25  وأريد بذلك أن ابنك ليس لك الآن، بل هو للبوليس ...
# 26         وهي ما أودُّ أن أتنشقَّه الآن وفي كل أوان.
# 27  وقد مثلت هذه المشكلةُ موضعَ اهتمام عميق للسيد ...
# 28  في هالة من فرقعة الأسواط والجئير الذي تضخِّمه ...
# 29  ولا أعرف إن كان لهذا الوهج أو تلك الموسيقى صلة...
# 30  إن اختيار النصوص لا يعني تفضيلاً فنياً لها على...
# 31  آراء البروفيسور تيندال التي أثبتَتها بما لا يد...
# 32  «حيَّر لغز بيجرام حتى المُحقق جريجوري من شرطة ...
# 33        وجوههم يغطيها شعرٌ ذابل يتدلَّى فوق صدورهم.
# 34  رأيت أبناء وطني توَّاقين إلى الاستقلال متعطشين...
# 35  يا لجمالك في الماء تشابهين الدُّمى والتماثيل، ...
# 36  إِذا أَنكَرتُ عَهداً مِن حَميمٍ    فَفي نَفسي ...
# 37  إميل في السابعة عشرة، وهو ولد فارع القامة أشقر...
# 38  لقد حزتم صفات الأكرمينا    فعدتم في الورى غوثا...
# 39  من تراخي العظام عند قيام    وفتور الكلام مع ما...
# 40  ثم بدأت عشرات القذائف تتساقط في معركة فالمي، ك...
# 41                         عز الدين عناية - عدنان علي
# 42  وإن كان عضوًا بحزب الجهاد أو داعش أو حزب الحكو...
# 43        بكيت عليه وقد فاتني    بكاء الكظيم على يوسف
# 44  (٤) تهنئة المؤيّد بداره وبمظهره الجديدين (نشرت...
# 45  عندما رحل رولان بارت عن عالمنا عن عمر يناهز ال...
# 46           وقائلٍ مَن شفيعُ ال    أنام يومَ اللقاءِ
# 47  ليت شعري بأي جرمٍ تفرد    ت عن الأصدقاء بأكل ا...
# 48  أمَّا بعد: فإنَّ لكل مخلوق حاجةً، ولكل حاجة غا...
# 49              بالشمس التي أعشقها أوحد الشمس الأخرى.
#
#    selected_sent_word_count                                selected_sent_words
# 0                         9      [وسوف, أبدؤها, بزيارة, أخي, ", طلعت, ", ., .]
# 1                        11  [وبينا, كان, عائدا, وجد, -, في, طريقه, -, مكان...
# 2                        20  [أجاب, ", ممدوح, ", وهو, يجري, مبتعدا, :, ليس,...
# 3                        10  [أما, القدر, الصغيرة, فإنها, واصلت, طبخ, المهل...
# 4                        11          [رقم, ", ١, ", :, ", أحمد, ", من, مصر, .]
# 5                        10  [لو, سرقت, منا, الأيام, قلبا, معطاء, بسام, لن,...
# 6                        11          [رقم, ", ١, ", :, ", أحمد, ", من, مصر, .]
# 7                         8            [ما, أسهل, سرقة, المصرف, الآن, ., ., .]
# 8                        18  [وقد, تجاوز, المدخل, بمنكبيه, العريضين, ,, ورا...
# 9                         7         [وأخذت, السيدة, العجوز, تشير, بيدها, ., .]
# 10                        9         [فتح, ", سوبرمان, ", خزانة, خفية, ., ., .]
# 11                        9  [ثم, استدار, إلى, كورا, وساعدها, على, امتطاء, ...
# 12                       16  [ذهب, ", مالك, الحزين, ", مع, زوجته, إلى, سوق,...
# 13                       24  [تحطمت, سفينة, السائحين, وغرقت, في, بحر, الظلم...
# 14                       13  [نجحت, خطة, ", الفتى, الجبار, ", ولفت, المعطف,...
# 15                       18  [وقد, تردد, أن, الثري, المصري, على, علاقة, بهذ...
# 16                        6                   [يجب, أن, أبعد, هذا, الصاروخ, !]
# 17                       11  [كانت, الحياة, عبارة, عن, حالة, تدور, فيها, رح...
# 18                        7         [تنافس, تجار, الفنون, على, لوحة, بيضاء, ,]
# 19                       28  [في, اعتقادي, أنه, ليس, هناك, الكثير, من, الأم...
# 20                       35  [جلس, ينظر, إلى, صورته, في, المرآة, الكبيرة, ,...
# 21                       34  [كان, فريدريك, بينسان, -, رقم, الضمان, الاجتما...
# 22                       13  [حاشا, للدين, أن, يكون, كما, تفعلون, وإلا, كان...
# 23                       29  [في, صباح, اليوم, التالي, تلقى, ", محب, ", رسا...
# 24                       32  [نظر, إلى, الباب, المفتوح, ,, المفتوح, دائما, ...
# 25                       18  [وأريد, بذلك, أن, ابنك, ليس, لك, الآن, ,, بل, ...
# 26                       10  [وهي, ما, أود, أن, أتنشقه, الآن, وفي, كل, أوان...
# 27                       36  [وقد, مثلت, هذه, المشكلة, موضع, اهتمام, عميق, ...
# 28                       22  [في, هالة, من, فرقعة, الأسواط, والجئير, الذي, ...
# 29                       18  [ولا, أعرف, إن, كان, لهذا, الوهج, أو, تلك, الم...
# 30                       27  [إن, اختيار, النصوص, لا, يعني, تفضيلا, فنيا, ل...
# 31                       19  [آراء, البروفيسور, تيندال, التي, أثبتتها, بما,...
# 32                       12  [", حير, لغز, بيجرام, حتى, المحقق, جريجوري, من...
# 33                        8  [وجوههم, يغطيها, شعر, ذابل, يتدلى, فوق, صدورهم...
# 34                       22  [رأيت, أبناء, وطني, تواقين, إلى, الاستقلال, مت...
# 35                       23  [يا, لجمالك, في, الماء, تشابهين, الدمى, والتما...
# 36                        9  [إذا, أنكرت, عهدا, من, حميم, ففي, نفسي, التكرم...
# 37                       26  [إميل, في, السابعة, عشرة, ,, وهو, ولد, فارع, ا...
# 38                        9  [لقد, حزتم, صفات, الأكرمينا, فعدتم, في, الورى,...
# 39                       10  [من, تراخي, العظام, عند, قيام, وفتور, الكلام, ...
# 40                       46  [ثم, بدأت, عشرات, القذائف, تتساقط, في, معركة, ...
# 41                        6                  [عز, الدين, عناية, -, عدنان, علي]
# 42                       26  [وإن, كان, عضوا, بحزب, الجهاد, أو, داعش, أو, ح...
# 43                        8  [بكيت, عليه, وقد, فاتني, بكاء, الكظيم, على, يوسف]
# 44                       17  [(, ٤, ), تهنئة, المؤيد, بداره, وبمظهره, الجدي...
# 45                       28  [عندما, رحل, رولان, بارت, عن, عالمنا, عن, عمر,...
# 46                        7           [وقائل, من, شفيع, ال, أنام, يوم, اللقاء]
# 47                       10  [ليت, شعري, بأي, جرم, تفرد, ت, عن, الأصدقاء, ب...
# 48                       37  [أما, بعد, :, فإن, لكل, مخلوق, حاجة, ,, ولكل, ...
# 49                        7     [بالشمس, التي, أعشقها, أوحد, الشمس, الأخرى, .]

# %%
# A_df.to_json('sampled_LAM_sentences.json', orient='records', force_ascii=False, indent=4)

# %%
metadata['Text Category'].value_counts()
# Out:
# Text Category
# Media & Culture                                  7122
# Educational Materials; Language & Linguistics    4709
# Academic                                         4301
# Literature; Art & Music                          3974
# Religion & Philosophy                             254
# Encyclopedic                                      175
# Name: count, dtype: int64

# %%
MC_df = metadata[metadata['Text Category']=='Media & Culture']
print("Media & Culture")
print("==========================")
print(f"Number of documents: {MC_df.shape[0]}")
print("--------------------------")
print(f"Number of sentences: {MC_df['Sentence Count'].sum()}")
print("--------------------------")
print(f"Number of unique books: {MC_df['Book'].nunique()}")
print("--------------------------")
print(f"Number of unique authors: {MC_df['Author'].nunique()}")
print("--------------------------")
print(f"Domain distribution:\n{MC_df['Domain'].value_counts().to_dict()}")
print("--------------------------")
print(f"Readership Group distribution:\n{MC_df['Readership Group'].value_counts().to_dict()}")
print("--------------------------")
print(f"Average sentence length distribution:\n{MC_df['average sentence length'].describe().to_dict()}")
print("==========================")
# Out:
# Media & Culture
# ==========================
# Number of documents: 7122
# --------------------------
# Number of sentences: 90271
# --------------------------
# Number of unique books: 73
# --------------------------
# Number of unique authors: 1
# --------------------------
# Domain distribution:
# {'Arts & Humanities': 3339, 'STEM': 2050, 'Social Sciences': 1733}
# --------------------------
# Readership Group distribution:
# {'Advanced Text': 6804, 'Foundational Text': 318}
# --------------------------
# Average sentence length distribution:
# {'count': 7122.0, 'mean': 34.177115010952846, 'std': 21.194923549289182, 'min': 2.5, '25%': 24.4, '50%': 31.550505050505052, '75%': 41.1972972972973, 'max': 1107.0}
# ==========================

# %%
MC_AH_df = MC_df[MC_df['Domain']=='Arts & Humanities']
print("Media & Culture - Arts & Humanities")
print("==========================")
print(f"Number of documents: {MC_AH_df.shape[0]}")
print("--------------------------")
print(f"Number of sentences: {MC_AH_df['Sentence Count'].sum()}")
print("--------------------------")
print(f"Number of unique books: {MC_AH_df['Book'].nunique()}")
print("--------------------------")
print(f"Number of unique authors: {MC_AH_df['Author'].nunique()}")
print("--------------------------")
print(f"Domain distribution:\n{MC_AH_df['Domain'].value_counts().to_dict()}")
print("--------------------------")
print(f"Readership Group distribution:\n{MC_AH_df['Readership Group'].value_counts().to_dict()}")
print("--------------------------")
print(f"Average sentence length distribution:\n{MC_AH_df['average sentence length'].describe().to_dict()}")
print("==========================")
# Out:
# Media & Culture - Arts & Humanities
# ==========================
# Number of documents: 3339
# --------------------------
# Number of sentences: 53523
# --------------------------
# Number of unique books: 16
# --------------------------
# Number of unique authors: 1
# --------------------------
# Domain distribution:
# {'Arts & Humanities': 3339}
# --------------------------
# Readership Group distribution:
# {'Advanced Text': 3021, 'Foundational Text': 318}
# --------------------------
# Average sentence length distribution:
# {'count': 3339.0, 'mean': 33.815569826253, 'std': 26.823106990512063, 'min': 3.0, '25%': 23.0, '50%': 30.555555555555557, '75%': 40.63333333333333, 'max': 1107.0}
# ==========================

# %%
sampled_MC_AH_foundational_df = MC_AH_df[MC_AH_df['Readership Group']=='Foundational Text'].sample(8, random_state=42)
sampled_MC_AH_advanced_df = MC_AH_df[MC_AH_df['Readership Group']=='Advanced Text'].sample(9, random_state=42)

# %%
sampled_MC_AH_df = pd.concat([sampled_MC_AH_foundational_df, sampled_MC_AH_advanced_df], ignore_index=True)

# %%
sampled_MC_AH_sentences_indices = []
for i, row in sampled_MC_AH_df.iterrows():
    directory = row['Directory']
    document = row['Document']
    annotations_file_path = f"BAREC-10M/Data/Morphology_and_Readability/{directory}/{document}.json"

    with open(annotations_file_path, 'r', encoding='utf-8') as f:
        annotations = json.load(f)
        annotations = pd.DataFrame(annotations)
    

    sampled_index = annotations[annotations['sents_word_count'] > 5].sample(1, random_state=42).index.item()
    sampled_MC_AH_sentences_indices.append(sampled_index)
print(sampled_MC_AH_sentences_indices)
# Out:
# [30, 7, 32, 33, 26, 43, 5, 36, 0, 0, 1, 0, 28, 1, 8, 0, 9]

# %%
sampled_MC_AH_df['sampled_sentence_index'] = sampled_MC_AH_sentences_indices

# %%
MC_ST_df = MC_df[MC_df['Domain']=='STEM']
print("Media & Culture - STEM")
print("==========================")
print(f"Number of documents: {MC_ST_df.shape[0]}")
print("--------------------------")
print(f"Number of sentences: {MC_ST_df['Sentence Count'].sum()}")
print("--------------------------")
print(f"Number of unique books: {MC_ST_df['Book'].nunique()}")
print("--------------------------")
print(f"Number of unique authors: {MC_ST_df['Author'].nunique()}")
print("--------------------------")
print(f"Domain distribution:\n{MC_ST_df['Domain'].value_counts().to_dict()}")
print("--------------------------")
print(f"Readership Group distribution:\n{MC_ST_df['Readership Group'].value_counts().to_dict()}")
print("--------------------------")
print(f"Average sentence length distribution:\n{MC_ST_df['average sentence length'].describe().to_dict()}")
print("==========================")
# Out:
# Media & Culture - STEM
# ==========================
# Number of documents: 2050
# --------------------------
# Number of sentences: 18572
# --------------------------
# Number of unique books: 34
# --------------------------
# Number of unique authors: 1
# --------------------------
# Domain distribution:
# {'STEM': 2050}
# --------------------------
# Readership Group distribution:
# {'Advanced Text': 2050}
# --------------------------
# Average sentence length distribution:
# {'count': 2050.0, 'mean': 36.51979165085057, 'std': 14.279902363926452, 'min': 6.8, '25%': 27.186363636363637, '50%': 34.2, '75%': 43.333333333333336, 'max': 146.0}
# ==========================

# %%
sampled_MC_ST_df = MC_ST_df.sample(17, random_state=42)

# %%
sampled_MC_ST_sentences_indices = []
for i, row in sampled_MC_ST_df.iterrows():
    directory = row['Directory']
    document = row['Document']
    annotations_file_path = f"BAREC-10M/Data/Morphology_and_Readability/{directory}/{document}.json"

    with open(annotations_file_path, 'r', encoding='utf-8') as f:
        annotations = json.load(f)
        annotations = pd.DataFrame(annotations)
    

    sampled_index = annotations[annotations['sents_word_count'] > 5].sample(1, random_state=42).index.item()
    sampled_MC_ST_sentences_indices.append(sampled_index)
print(sampled_MC_ST_sentences_indices)
# Out:
# [0, 0, 7, 0, 1, 10, 38, 0, 5, 10, 0, 7, 0, 0, 0, 0, 0]

# %%
sampled_MC_ST_df['sampled_sentence_index'] = sampled_MC_ST_sentences_indices

# %%
MC_SS_df = MC_df[MC_df['Domain']=='Social Sciences']
print("Media & Culture - Social Sciences")
print("==========================")
print(f"Number of documents: {MC_SS_df.shape[0]}")
print("--------------------------")
print(f"Number of sentences: {MC_SS_df['Sentence Count'].sum()}")
print("--------------------------")
print(f"Number of unique books: {MC_SS_df['Book'].nunique()}")
print("--------------------------")
print(f"Number of unique authors: {MC_SS_df['Author'].nunique()}")
print("--------------------------")
print(f"Domain distribution:\n{MC_SS_df['Domain'].value_counts().to_dict()}")
print("--------------------------")
print(f"Readership Group distribution:\n{MC_SS_df['Readership Group'].value_counts().to_dict()}")
print("--------------------------")
print(f"Average sentence length distribution:\n{MC_SS_df['average sentence length'].describe().to_dict()}")
print("==========================")
# Out:
# Media & Culture - Social Sciences
# ==========================
# Number of documents: 1733
# --------------------------
# Number of sentences: 18176
# --------------------------
# Number of unique books: 23
# --------------------------
# Number of unique authors: 1
# --------------------------
# Domain distribution:
# {'Social Sciences': 1733}
# --------------------------
# Readership Group distribution:
# {'Advanced Text': 1733}
# --------------------------
# Average sentence length distribution:
# {'count': 1733.0, 'mean': 32.10251158332588, 'std': 14.423877229819887, 'min': 2.5, '25%': 23.4, '50%': 30.1, '75%': 39.46666666666667, 'max': 238.33333333333334}
# ==========================

# %%
sampled_MC_SS_df = MC_SS_df.sample(16, random_state=42)

# %%
sampled_MC_SS_sentences_indices = []
for i, row in sampled_MC_SS_df.iterrows():
    directory = row['Directory']
    document = row['Document']
    annotations_file_path = f"BAREC-10M/Data/Morphology_and_Readability/{directory}/{document}.json"

    with open(annotations_file_path, 'r', encoding='utf-8') as f:
        annotations = json.load(f)
        annotations = pd.DataFrame(annotations)
    

    sampled_index = annotations[annotations['sents_word_count'] > 5].sample(1, random_state=42).index.item()
    sampled_MC_SS_sentences_indices.append(sampled_index)
print(sampled_MC_SS_sentences_indices)
# Out:
# [10, 1, 1, 9, 1, 8, 2, 0, 9, 0, 8, 8, 1, 1, 0, 0]

# %%
sampled_MC_SS_df['sampled_sentence_index'] = sampled_MC_SS_sentences_indices

# %%
B_df = pd.concat([sampled_MC_AH_df, sampled_MC_ST_df, sampled_MC_SS_df], ignore_index=True)
B_df
# Out:
#                              Document  Directory          Source  \
# 0           BAREC_Majed_0670_1991_021      Majed           Majed
# 1           BAREC_Majed_1901_2015_022      Majed           Majed
# 2           BAREC_Majed_0229_1983_026      Majed           Majed
# 3           BAREC_Majed_1901_2015_001      Majed           Majed
# 4           BAREC_Majed_0229_1983_010      Majed           Majed
# 5           BAREC_Majed_0836_1995_023      Majed           Majed
# 6           BAREC_Majed_1269_2003_034      Majed           Majed
# 7           BAREC_Majed_1481_2007_006      Majed           Majed
# 8    BAREC_AlArabiya_Culture_0275_001  AlArabiya  AlArabiya News
# 9   BAREC_Akhbarona_Religion_0073_001  Akhbarona  Akhbarona News
# 10   BAREC_Akhbarona_Culture_0088_001  Akhbarona  Akhbarona News
# 11           BAREC_ANERCorp_train_171   ANERCorp        ANERCorp
# 12           BAREC_ANERCorp_train_012   ANERCorp        ANERCorp
# 13   BAREC_Akhbarona_Culture_0190_001  Akhbarona  Akhbarona News
# 14    BAREC_Akhbarona_Sports_0191_001  Akhbarona  Akhbarona News
# 15    BAREC_Akhbarona_Sports_0214_001  Akhbarona  Akhbarona News
# 16              BAREC_ReadMe_Test_008     ReadMe        ReadMe++
# 17      BAREC_AlKhaleej_Tech_0158_001  AlKhaleej  AlKhaleej News
# 18   BAREC_AlArabiya_Medical_0094_001  AlArabiya  AlArabiya News
# 19   BAREC_AlArabiya_Medical_0306_001  AlArabiya  AlArabiya News
# 20     BAREC_Akhbarona_Tech_00244_001  Akhbarona  Akhbarona News
# 21      BAREC_AlKhaleej_Tech_0197_001  AlKhaleej  AlKhaleej News
# 22   BAREC_AlKhaleej_Medical_0266_001  AlKhaleej  AlKhaleej News
# 23   BAREC_AlKhaleej_Medical_0272_001  AlKhaleej  AlKhaleej News
# 24   BAREC_AlArabiya_Medical_0344_001  AlArabiya  AlArabiya News
# 25   BAREC_AlArabiya_Medical_0218_001  AlArabiya  AlArabiya News
# 26   BAREC_AlArabiya_Medical_0229_001  AlArabiya  AlArabiya News
# 27   BAREC_AlKhaleej_Medical_0230_001  AlKhaleej  AlKhaleej News
# 24        Medical      #               STEM      Advanced Text
# 25        Medical      #               STEM      Advanced Text
# 26        Medical      #               STEM      Advanced Text
# 27        Medical      #               STEM      Advanced Text
# 28           Tech      #               STEM      Advanced Text
# 29        Medical      #               STEM      Advanced Text
# 30        Medical      #               STEM      Advanced Text
# 31        Medical      #               STEM      Advanced Text
# 32           Tech      #               STEM      Advanced Text
# 33        Medical      #               STEM      Advanced Text
# 34       Politics      #    Social Sciences      Advanced Text
# 35        Finance      #    Social Sciences      Advanced Text
# 36       Politics      #    Social Sciences      Advanced Text
# 37       Politics      #    Social Sciences      Advanced Text
# 38       Politics      #    Social Sciences      Advanced Text
# 39        Finance      #    Social Sciences      Advanced Text
# 40        Finance      #    Social Sciences      Advanced Text
# 41        Finance      #    Social Sciences      Advanced Text
# 42       Politics      #    Social Sciences      Advanced Text
# 43        Finance      #    Social Sciences      Advanced Text
# 44       Politics      #    Social Sciences      Advanced Text
# 45       Politics      #    Social Sciences      Advanced Text
# 46        Finance      #    Social Sciences      Advanced Text
# 47        Finance      #    Social Sciences      Advanced Text
# 48        Finance      #    Social Sciences      Advanced Text
# 49        Finance      #    Social Sciences      Advanced Text
#
#       Text Category  Word Count  Sentence Count In BAREC Corpus?  \
# 0   Media & Culture         340              41              Yes
# 1   Media & Culture          86              28              Yes
# 2   Media & Culture         611              92              Yes
# 3   Media & Culture         374              41              Yes
# 4   Media & Culture         389              55              Yes
# 5   Media & Culture         561              71              Yes
# 6   Media & Culture         148              37              Yes
# 7   Media & Culture         749              49              Yes
# 8   Media & Culture         309               7               No
# 9   Media & Culture          40               5               No
# 10  Media & Culture         136               2               No
# 11  Media & Culture         603              16               No
# 12  Media & Culture         606              32               No
# 13  Media & Culture         165               4               No
# 14  Media & Culture         564              24               No
# 15  Media & Culture         108               1               No
# 16  Media & Culture         239              20              Yes
# 17  Media & Culture         252               8               No
# 18  Media & Culture         201               7               No
# 19  Media & Culture         279               9               No
# 20  Media & Culture         246               7               No
# 21  Media & Culture         278               8               No
# 22  Media & Culture         627              12               No
# 23  Media & Culture        2212              45               No
# 24  Media & Culture         527              21               No
# 25  Media & Culture         305              11               No
# 26  Media & Culture         333              12               No
# 27  Media & Culture         254               6               No
# 28  Media & Culture         450               9               No
# 29  Media & Culture         134               3               No
# 30  Media & Culture         218               7               No
# 31  Media & Culture         284              25               No
# 32  Media & Culture         299               7               No
# 33  Media & Culture         330               7               No
# 34  Media & Culture        1349              29               No
# 35  Media & Culture         270               5               No
# 36  Media & Culture          97               4               No
# 37  Media & Culture         611              15               No
# 38  Media & Culture         193               4               No
# 39  Media & Culture         376              10              Yes
# 40  Media & Culture          70               3               No
# 41  Media & Culture          45               1               No
# 42  Media & Culture         374              14               No
# 43  Media & Culture         230               6               No
# 44  Media & Culture         186              11               No
# 45  Media & Culture         277              10               No
# 46  Media & Culture         151               9               No
# 47  Media & Culture         331               8               No
# 48  Media & Culture         349               7               No
# 49  Media & Culture         307               7               No
#
#     average sentence length  sampled_sentence_index
# 0                  8.292683                      30
# 1                  3.071429                       7
# 2                  6.641304                      32
# 3                  9.121951                      33
# 4                  7.072727                      26
# 5                  7.901408                      43
# 6                  4.000000                       5
# 7                 15.285714                      36
# 8                 44.142857                       0
# 9                  8.000000                       0
# 10                68.000000                       1
# 11                37.687500                       0
# 12                18.937500                      28
# 13                41.250000                       1
# 14                23.500000                       8
# 15               108.000000                       0
# 16                11.950000                       9
# 17                31.500000                       0
# 18                28.714286                       0
# 19                31.000000                       7
# 20                35.142857                       0
# 21                34.750000                       1
# 22                52.250000                      10
# 23                49.155556                      38
# 24                25.095238                       0
# 25                27.727273                       5
# 26                27.750000                      10
# 27                42.333333                       0
# 28                50.000000                       7
# 29                44.666667                       0
# 30                31.142857                       0
# 31                11.360000                       0
# 32                42.714286                       0
# 33                47.142857                       0
# 34                46.517241                      10
# 35                54.000000                       1
# 36                24.250000                       1
# 37                40.733333                       9
# 38                48.250000                       1
# 39                37.600000                       8
# 40                23.333333                       2
# 41                45.000000                       0
# 42                26.714286                       9
# 43                38.333333                       0
# 44                16.909091                       8
# 45                27.700000                       8
# 46                16.777778                       1
# 47                41.375000                       1
# 48                49.857143                       0
# 49                43.857143                       0

# %%
B_df['selected_sent_raw'] = None
B_df['selected_sent_word_count'] = None
B_df['selected_sent_words'] = None

for i, row in B_df.iterrows():
    directory = row['Directory']
    document = row['Document']

    annotations_file_path = (
        f"BAREC-10M/Data/Morphology_and_Readability/"
        f"{directory}/{document}.json"
    )

    with open(annotations_file_path, 'r', encoding='utf-8') as f:
        annotations = json.load(f)

    annotations = pd.DataFrame(annotations)

    selected_sentence_index = int(row['sampled_sentence_index'])

    selected_row = annotations.iloc[selected_sentence_index]

    raw_sentence = selected_row['raw_sents']
    word_count = selected_row['sents_word_count']
    words = selected_row['word']   # list of strings

    B_df.at[i, 'selected_sent_raw'] = raw_sentence
    B_df.at[i, 'selected_sent_word_count'] = word_count
    B_df.at[i, 'selected_sent_words'] = words

# %%
B_df = B_df[[
    'Directory',
    'Document',
    'sampled_sentence_index',
    'Source',
    'Book',
    'Author',
    'Domain',
    'Readership Group',
    'Text Category',
    'average sentence length',
    'selected_sent_raw',
    'selected_sent_word_count',
    'selected_sent_words'
]]

# %%
B_df.rename(columns={
    'average sentence length': 'average_sentence_length_per_doc',
}, inplace=True)

# %%
B_df
# Out:
#     Directory                           Document  sampled_sentence_index  \
# 0       Majed          BAREC_Majed_0670_1991_021                      30
# 1       Majed          BAREC_Majed_1901_2015_022                       7
# 2       Majed          BAREC_Majed_0229_1983_026                      32
# 3       Majed          BAREC_Majed_1901_2015_001                      33
# 4       Majed          BAREC_Majed_0229_1983_010                      26
# 5       Majed          BAREC_Majed_0836_1995_023                      43
# 6       Majed          BAREC_Majed_1269_2003_034                       5
# 7       Majed          BAREC_Majed_1481_2007_006                      36
# 8   AlArabiya   BAREC_AlArabiya_Culture_0275_001                       0
# 9   Akhbarona  BAREC_Akhbarona_Religion_0073_001                       0
# 10  Akhbarona   BAREC_Akhbarona_Culture_0088_001                       1
# 11   ANERCorp           BAREC_ANERCorp_train_171                       0
# 12   ANERCorp           BAREC_ANERCorp_train_012                      28
# 20      Advanced Text  Media & Culture                        35.142857
# 21      Advanced Text  Media & Culture                        34.750000
# 22      Advanced Text  Media & Culture                        52.250000
# 23      Advanced Text  Media & Culture                        49.155556
# 24      Advanced Text  Media & Culture                        25.095238
# 25      Advanced Text  Media & Culture                        27.727273
# 26      Advanced Text  Media & Culture                        27.750000
# 27      Advanced Text  Media & Culture                        42.333333
# 28      Advanced Text  Media & Culture                        50.000000
# 29      Advanced Text  Media & Culture                        44.666667
# 30      Advanced Text  Media & Culture                        31.142857
# 31      Advanced Text  Media & Culture                        11.360000
# 32      Advanced Text  Media & Culture                        42.714286
# 33      Advanced Text  Media & Culture                        47.142857
# 34      Advanced Text  Media & Culture                        46.517241
# 35      Advanced Text  Media & Culture                        54.000000
# 36      Advanced Text  Media & Culture                        24.250000
# 37      Advanced Text  Media & Culture                        40.733333
# 38      Advanced Text  Media & Culture                        48.250000
# 39      Advanced Text  Media & Culture                        37.600000
# 40      Advanced Text  Media & Culture                        23.333333
# 41      Advanced Text  Media & Culture                        45.000000
# 42      Advanced Text  Media & Culture                        26.714286
# 43      Advanced Text  Media & Culture                        38.333333
# 44      Advanced Text  Media & Culture                        16.909091
# 45      Advanced Text  Media & Culture                        27.700000
# 46      Advanced Text  Media & Culture                        16.777778
# 47      Advanced Text  Media & Culture                        41.375000
# 48      Advanced Text  Media & Culture                        49.857143
# 49      Advanced Text  Media & Culture                        43.857143
#
#                                     selected_sent_raw  \
# 0   وقال لهم: اهجموا على الأكل، بلا شفقة ولا رحمةـ...
# 1                                     هلا.. هلا.. هلا
# 2                            أنا واثق من نجاح الخطة..
# 3   الإجازة فرصة كي نستفيد ونتعلم ونكتسب مهارات جد...
# 4                        كوثر محمد – شمبات – السودان:
# 5                    وأحيانًا أخرى تضحكين من كل قلبك.
# 6                      لا بد أن يكون لك اسم أناديك به
# 7   ستتسبب هذه القوة في العديد من المشاكل لفريقه ح...
# 8   غضب وشوق حملته منة فضالي لجمهورها، بعد عودتها ...
# 9               الإيمان صفحة اسبوعية تصدر كل يوم جمعة
# 10  حيث توصل  في هذا الإطار بعدد من رسائل المدح من...
# 11  وكان قادة الانقلاب الذي وقع يوم 19 سبتمبر / أي...
# 12  وانتشرت زراعة الأرز في غينيا وسيراليون وليبيريا .
# 13  يبدو أن المنشط الإذاعي محمد بوصفيحة الشهير بمو...
# 14  وتحلم تشيلي بالفوز باللقب لأول مرة بعد عروضها ...
# 15  عبدالاله بوسحابة : أخبارنا المغربيةبعدما شاعت ...
# 16                    أرني كل الانذارات التي أعددتها.
# 17  قدمت وزارة الداخلية، خلال مؤتمر أمن الإنترنت و...
# 18  هل صادف أن وجدت نفسك في الشارع "تتمتم متحدثاً ...
# 19  والكميات التي طلبت إيطاليا تعليق استخدامها مصن...
# 20  أعلنت شركة سامسونغ عن إجراء تحسينات شاملة على ...
# 21  وتوفر كومون سينس ميديا نصائح للآباء فيما يتعلق...
# 22  وأوضح التقرير أنه من المتوقع أن يصل حجم سوق ال...
# 23  وصرحت ل"الخليج" على هامش مؤتمر الصحة العربي، ب...
# 24  نحن لا نولد ومعنا الميل إلى كراهية من يختلفون ...
# 25  وينتج جسم الإنسان بشكل طبيعي مستويات عالية من ...
# 26  وقال رودريكو اوفرين مسؤول الاستجابة للطوارئ في...
# 27  أكد إبراهيم بوملحة، مستشار صاحب السموّ حاكم دب...
# 28  ولهذا السبب وصلت "فيسبوك" إلى طريقة تستفيد من ...
# 29  أكدت نخبة من الخبراء والأطباء المحليين والإقلي...
# 30  يؤكد متخصصون على أهمية مراجعة الطبيب في حال عد...
# 31  فكرة التنظيف متعبة من جميع الاتجاهات ولكن اكثر...
# 32  ألمح صاحب التسريبات الشهير إيفان بلاس إلى أن ش...
# 33  هناك أطعمة ربما تتسبب في إصابة الجسم بالتهابات...
# 34  مراد، إلى إشارة الأمير في خطابه إلى تركيا على ...
# 35  ووفقا لصحيفة الجزيرة السعودية، يجتمع صباح اليو...
# 36  وقال المتحدث باسم قيادة الجيش العقيد فادي أبو ...
# 37  ونقلت وسائل إعلام تركية تصريحات داود أوغلو للص...
# 38  وقال أنان في تصريحات على هامش زيارته لمكتبة ال...
# 39  ولا شك أن نشر سعر شهري رسمي للنفط الخام في دبي...
# 40  و تابعت يومية المساء في عددها الصادر اليوم ، أ...
# 41  اعلنت شركة ديبا في بيان على موقع ناسداك دبي ام...
# 42  ويجري اتحاد القوى مشاورات مع رؤساء الكتل السيا...
# 43  ارتفع المؤشر العام لسوق أبوظبي للأوراق المالية...
# 44  وأضاف أنه تم إلقاء القبض على الجنديين العراقيي...
# 45         وتفجرت موجة احتجاجات عالمية على قرار ترمب.
# 46                                وتدير شركة سينو-سي.
# 47  وأوضحت أن التمويلات الإسلامية حققت أرقاماً جيد...
# 48  أكد رئيس مجلس إدارة غرفة الشرقية عبدالرحمن الر...
# 49  أفادت وزارة المالية الإماراتية بأنها تدرس فرض ...
#
#    selected_sent_word_count                                selected_sent_words
# 0                        17  [وقال, لهم, :, اهجموا, على, الأكل, ,, بلا, شفق...
# 1                         7                        [هلا, ., ., هلا, ., ., هلا]
# 2                         7                 [أنا, واثق, من, نجاح, الخطة, ., .]
# 3                        10  [الإجازة, فرصة, كي, نستفيد, ونتعلم, ونكتسب, مه...
# 4                         7              [كوثر, محمد, -, شمبات, -, السودان, :]
# 5                         7           [وأحيانا, أخرى, تضحكين, من, كل, قلبك, .]
# 6                         8            [لا, بد, أن, يكون, لك, اسم, أناديك, به]
# 7                        14  [ستتسبب, هذه, القوة, في, العديد, من, المشاكل, ...
# 8                        30  [غضب, وشوق, حملته, منة, فضالي, لجمهورها, ,, بع...
# 9                         7      [الإيمان, صفحة, اسبوعية, تصدر, كل, يوم, جمعة]
# 10                       65  [حيث, توصل, في, هذا, الإطار, بعدد, من, رسائل, ...
# 11                       54  [وكان, قادة, الانقلاب, الذي, وقع, يوم, 19, سبت...
# 12                        8  [وانتشرت, زراعة, الأرز, في, غينيا, وسيراليون, ...
# 13                       63  [يبدو, أن, المنشط, الإذاعي, محمد, بوصفيحة, الش...
# 14                       31  [وتحلم, تشيلي, بالفوز, باللقب, لأول, مرة, بعد,...
# 15                      108  [عبدالاله, بوسحابة, :, أخبارنا, المغربيةبعدما,...
# 16                        6            [أرني, كل, الانذارات, التي, أعددتها, .]
# 17                       37  [قدمت, وزارة, الداخلية, ,, خلال, مؤتمر, أمن, ا...
# 18                       14  [هل, صادف, أن, وجدت, نفسك, في, الشارع, ", تتمت...
# 19                       18  [والكميات, التي, طلبت, إيطاليا, تعليق, استخدام...
# 20                       27  [أعلنت, شركة, سامسونغ, عن, إجراء, تحسينات, شام...
# 21                       22  [وتوفر, كومون, سينس, ميديا, نصائح, للآباء, فيم...
# 22                       49  [وأوضح, التقرير, أنه, من, المتوقع, أن, يصل, حج...
# 23                       49  [وصرحت, ل, ", الخليج, ", على, هامش, مؤتمر, الص...
# 24                       13  [نحن, لا, نولد, ومعنا, الميل, إلى, كراهية, من,...
# 25                       32  [وينتج, جسم, الإنسان, بشكل, طبيعي, مستويات, عا...
# 26                       56  [وقال, رودريكو, اوفرين, مسؤول, الاستجابة, للطو...
# 27                       99  [أكد, إبراهيم, بوملحة, ,, مستشار, صاحب, السمو,...
# 28                       49  [ولهذا, السبب, وصلت, ", فيسبوك, ", إلى, طريقة,...
# 29                       53  [أكدت, نخبة, من, الخبراء, والأطباء, المحليين, ...
# 30                       44  [يؤكد, متخصصون, على, أهمية, مراجعة, الطبيب, في...
# 31                       18  [فكرة, التنظيف, متعبة, من, جميع, الاتجاهات, ول...
# 32                       37  [ألمح, صاحب, التسريبات, الشهير, إيفان, بلاس, إ...
# 33                       36  [هناك, أطعمة, ربما, تتسبب, في, إصابة, الجسم, ب...
# 34                       38  [مراد, ,, إلى, إشارة, الأمير, في, خطابه, إلى, ...
# 35                       35  [ووفقا, لصحيفة, الجزيرة, السعودية, ,, يجتمع, ص...
# 36                       34  [وقال, المتحدث, باسم, قيادة, الجيش, العقيد, فا...
# 37                       35  [ونقلت, وسائل, إعلام, تركية, تصريحات, داود, أو...
# 38                       74  [وقال, أنان, في, تصريحات, على, هامش, زيارته, ل...
# 39                       48  [ولا, شك, أن, نشر, سعر, شهري, رسمي, للنفط, الخ...
# 40                       41  [و, تابعت, يومية, المساء, في, عددها, الصادر, ا...
# 41                       45  [اعلنت, شركة, ديبا, في, بيان, على, موقع, ناسدا...
# 42                       24  [ويجري, اتحاد, القوى, مشاورات, مع, رؤساء, الكت...
# 43                       18  [ارتفع, المؤشر, العام, لسوق, أبوظبي, للأوراق, ...
# 44                       16  [وأضاف, أنه, تم, إلقاء, القبض, على, الجنديين, ...
# 45                        8  [وتفجرت, موجة, احتجاجات, عالمية, على, قرار, تر...
# 46                        6                      [وتدير, شركة, سينو, -, سي, .]
# 47                       24  [وأوضحت, أن, التمويلات, الإسلامية, حققت, أرقام...
# 48                       33  [أكد, رئيس, مجلس, إدارة, غرفة, الشرقية, عبدالر...
# 49                       19  [أفادت, وزارة, المالية, الإماراتية, بأنها, تدر...

# %%
# B_df.to_json('sampled_MC_sentences.json', orient='records', force_ascii=False, indent=4)

# %%
metadata['Text Category'].value_counts()
# Out:
# Text Category
# Media & Culture                                  7122
# Educational Materials; Language & Linguistics    4709
# Academic                                         4301
# Literature; Art & Music                          3974
# Religion & Philosophy                             254
# Encyclopedic                                      175
# Name: count, dtype: int64

# %%
ELL_df = metadata[metadata['Text Category']=='Educational Materials; Language & Linguistics']
print("Educational Materials; Language & Linguistics")
print("==========================")
print(f"Number of documents: {ELL_df.shape[0]}")
print("--------------------------")
print(f"Number of sentences: {ELL_df['Sentence Count'].sum()}")
print("--------------------------")
print(f"Number of unique books: {ELL_df['Book'].nunique()}")
print("--------------------------")
print(f"Number of unique authors: {ELL_df['Author'].nunique()}")
print("--------------------------")
print(f"Domain distribution:\n{ELL_df['Domain'].value_counts().to_dict()}")
print("--------------------------")
print(f"Readership Group distribution:\n{ELL_df['Readership Group'].value_counts().to_dict()}")
print("--------------------------")
print(f"Average sentence length distribution:\n{ELL_df['average sentence length'].describe().to_dict()}")
print("==========================")
# Out:
# Educational Materials; Language & Linguistics
# ==========================
# Number of documents: 4709
# --------------------------
# Number of sentences: 176003
# --------------------------
# Number of unique books: 153
# --------------------------
# Number of unique authors: 1
# --------------------------
# Domain distribution:
# {'Arts & Humanities': 2644, 'Social Sciences': 1143, 'STEM': 922}
# --------------------------
# Readership Group distribution:
# {'Specialized Text': 2131, 'Advanced Text': 1700, 'Foundational Text': 878}
# --------------------------
# Average sentence length distribution:
# {'count': 4709.0, 'mean': 40.3278243679819, 'std': 36.4060742197123, 'min': 1.6666666666666667, '25%': 9.725806451612904, '50%': 20.12121212121212, '75%': 71.44444444444444, 'max': 233.0}
# ==========================

# %%
ELL_AH_df = ELL_df[ELL_df['Domain']=='Arts & Humanities']
print("Educational Materials; Language & Linguistics - Arts & Humanities")
print("==========================")
print(f"Number of documents: {ELL_AH_df.shape[0]}")
print("--------------------------")
print(f"Number of sentences: {ELL_AH_df['Sentence Count'].sum()}")
print("--------------------------")
print(f"Number of unique books: {ELL_AH_df['Book'].nunique()}")
print("--------------------------")
print(f"Number of unique authors: {ELL_AH_df['Author'].nunique()}")
print("--------------------------")
print(f"Domain distribution:\n{ELL_AH_df['Domain'].value_counts().to_dict()}")
print("--------------------------")
print(f"Readership Group distribution:\n{ELL_AH_df['Readership Group'].value_counts().to_dict()}")
print("--------------------------")
print(f"Average sentence length distribution:\n{ELL_AH_df['average sentence length'].describe().to_dict()}")
print("==========================")
# Out:
# Educational Materials; Language & Linguistics - Arts & Humanities
# ==========================
# Number of documents: 2644
# --------------------------
# Number of sentences: 125647
# --------------------------
# Number of unique books: 61
# --------------------------
# Number of unique authors: 1
# --------------------------
# Domain distribution:
# {'Arts & Humanities': 2644}
# --------------------------
# Readership Group distribution:
# {'Advanced Text': 1107, 'Specialized Text': 961, 'Foundational Text': 576}
# --------------------------
# Average sentence length distribution:
# {'count': 2644.0, 'mean': 31.706006481763776, 'std': 36.29987302225113, 'min': 2.6548672566371683, '25%': 8.173469387755102, '50%': 12.604166666666668, '75%': 43.035714285714285, 'max': 233.0}
# ==========================

# %%
sampled_ELL_AH_foundational_df = ELL_AH_df[ELL_AH_df['Readership Group']=='Foundational Text'].sample(5, random_state=42)
sampled_ELL_AH_advanced_df = ELL_AH_df[ELL_AH_df['Readership Group']=='Advanced Text'].sample(6, random_state=42)
sampled_ELL_AH_special_df = ELL_AH_df[ELL_AH_df['Readership Group']=='Specialized Text'].sample(6, random_state=42)

# %%
sampled_ELL_AH_df = pd.concat([sampled_ELL_AH_foundational_df, sampled_ELL_AH_advanced_df, sampled_ELL_AH_special_df], ignore_index=True)

# %%
sampled_ELL_AH_sentences_indices = []
for i, row in sampled_ELL_AH_df.iterrows():
    directory = row['Directory']
    document = row['Document']
    annotations_file_path = f"BAREC-10M/Data/Morphology_and_Readability/{directory}/{document}.json"

    with open(annotations_file_path, 'r', encoding='utf-8') as f:
        annotations = json.load(f)
        annotations = pd.DataFrame(annotations)
    

    sampled_index = annotations[annotations['sents_word_count'] > 5].sample(1, random_state=42).index.item()
    sampled_ELL_AH_sentences_indices.append(sampled_index)
print(sampled_ELL_AH_sentences_indices)
# Out:
# [68, 42, 51, 52, 7, 84, 42, 0, 0, 41, 0, 0, 20, 0, 0, 58, 0]

# %%
sampled_ELL_AH_df['sampled_sentence_index'] = sampled_ELL_AH_sentences_indices

# %%
ELL_ST_df = ELL_df[ELL_df['Domain']=='STEM']
print("Educational Materials; Language & Linguistics - STEM")
print("==========================")
print(f"Number of documents: {ELL_ST_df.shape[0]}")
print("--------------------------")
print(f"Number of sentences: {ELL_ST_df['Sentence Count'].sum()}")
print("--------------------------")
print(f"Number of unique books: {ELL_ST_df['Book'].nunique()}")
print("--------------------------")
print(f"Number of unique authors: {ELL_ST_df['Author'].nunique()}")
print("--------------------------")
print(f"Domain distribution:\n{ELL_ST_df['Domain'].value_counts().to_dict()}")
print("--------------------------")
print(f"Readership Group distribution:\n{ELL_ST_df['Readership Group'].value_counts().to_dict()}")
print("--------------------------")
print(f"Average sentence length distribution:\n{ELL_ST_df['average sentence length'].describe().to_dict()}")
print("==========================")
# Out:
# Educational Materials; Language & Linguistics - STEM
# ==========================
# Number of documents: 922
# --------------------------
# Number of sentences: 8695
# --------------------------
# Number of unique books: 49
# --------------------------
# Number of unique authors: 1
# --------------------------
# Domain distribution:
# {'STEM': 922}
# --------------------------
# Readership Group distribution:
# {'Specialized Text': 662, 'Advanced Text': 175, 'Foundational Text': 85}
# --------------------------
# Average sentence length distribution:
# {'count': 922.0, 'mean': 71.35990994101527, 'std': 21.467599100210514, 'min': 14.6, '25%': 61.51136363636364, '50%': 70.22222222222223, '75%': 81.09375, 'max': 169.0}
# ==========================

# %%
sampled_ELL_ST_foundational_df = ELL_ST_df[ELL_ST_df['Readership Group']=='Foundational Text'].sample(5, random_state=42)
sampled_ELL_ST_advanced_df = ELL_ST_df[ELL_ST_df['Readership Group']=='Advanced Text'].sample(6, random_state=42)
sampled_ELL_ST_special_df = ELL_ST_df[ELL_ST_df['Readership Group']=='Specialized Text'].sample(6, random_state=42)

# %%
sampled_ELL_ST_df = pd.concat([sampled_ELL_ST_foundational_df, sampled_ELL_ST_advanced_df, sampled_ELL_ST_special_df], ignore_index=True)

# %%
sampled_ELL_ST_sentences_indices = []
for i, row in sampled_ELL_ST_df.iterrows():
    directory = row['Directory']
    document = row['Document']
    annotations_file_path = f"BAREC-10M/Data/Morphology_and_Readability/{directory}/{document}.json"

    with open(annotations_file_path, 'r', encoding='utf-8') as f:
        annotations = json.load(f)
        annotations = pd.DataFrame(annotations)
    

    sampled_index = annotations[annotations['sents_word_count'] > 5].sample(1, random_state=42).index.item()
    sampled_ELL_ST_sentences_indices.append(sampled_index)
print(sampled_ELL_ST_sentences_indices)
# Out:
# [0, 0, 1, 0, 0, 8, 1, 0, 7, 5, 7, 1, 0, 1, 5, 1, 1]

# %%
sampled_ELL_ST_df['sampled_sentence_index'] = sampled_ELL_ST_sentences_indices

# %%
ELL_SS_df = ELL_df[ELL_df['Domain']=='Social Sciences']
print("Educational Materials; Language & Linguistics - Social Sciences")
print("==========================")
print(f"Number of documents: {ELL_SS_df.shape[0]}")
print("--------------------------")
print(f"Number of sentences: {ELL_SS_df['Sentence Count'].sum()}")
print("--------------------------")
print(f"Number of unique books: {ELL_SS_df['Book'].nunique()}")
print("--------------------------")
print(f"Number of unique authors: {ELL_SS_df['Author'].nunique()}")
print("--------------------------")
print(f"Domain distribution:\n{ELL_SS_df['Domain'].value_counts().to_dict()}")
print("--------------------------")
print(f"Readership Group distribution:\n{ELL_SS_df['Readership Group'].value_counts().to_dict()}")
print("--------------------------")
print(f"Average sentence length distribution:\n{ELL_SS_df['average sentence length'].describe().to_dict()}")
print("==========================")
# Out:
# Educational Materials; Language & Linguistics - Social Sciences
# ==========================
# Number of documents: 1143
# --------------------------
# Number of sentences: 41661
# --------------------------
# Number of unique books: 45
# --------------------------
# Number of unique authors: 1
# --------------------------
# Domain distribution:
# {'Social Sciences': 1143}
# --------------------------
# Readership Group distribution:
# {'Specialized Text': 508, 'Advanced Text': 418, 'Foundational Text': 217}
# --------------------------
# Average sentence length distribution:
# {'count': 1143.0, 'mean': 35.23990100212361, 'std': 32.67019027449575, 'min': 1.6666666666666667, '25%': 10.487288135593221, '50%': 15.512820512820513, '75%': 67.0, 'max': 157.0}
# ==========================

# %%
sampled_ELL_SS_foundational_df = ELL_SS_df[ELL_SS_df['Readership Group']=='Foundational Text'].sample(5, random_state=42)
sampled_ELL_SS_advanced_df = ELL_SS_df[ELL_SS_df['Readership Group']=='Advanced Text'].sample(5, random_state=42)
sampled_ELL_SS_special_df = ELL_SS_df[ELL_SS_df['Readership Group']=='Specialized Text'].sample(6, random_state=42)

# %%
sampled_ELL_SS_df = pd.concat([sampled_ELL_SS_foundational_df, sampled_ELL_SS_advanced_df, sampled_ELL_SS_special_df], ignore_index=True)

# %%
sampled_ELL_SS_sentences_indices = []
for i, row in sampled_ELL_SS_df.iterrows():
    directory = row['Directory']
    document = row['Document']
    annotations_file_path = f"BAREC-10M/Data/Morphology_and_Readability/{directory}/{document}.json"

    with open(annotations_file_path, 'r', encoding='utf-8') as f:
        annotations = json.load(f)
        annotations = pd.DataFrame(annotations)
    

    sampled_index = annotations[annotations['sents_word_count'] > 5].sample(1, random_state=42).index.item()
    sampled_ELL_SS_sentences_indices.append(sampled_index)
print(sampled_ELL_SS_sentences_indices)
# Out:
# [7, 7, 17, 17, 0, 32, 27, 7, 71, 76, 15, 7, 0, 7, 16, 1]

# %%
sampled_ELL_SS_df['sampled_sentence_index'] = sampled_ELL_SS_sentences_indices

# %%
C_df = pd.concat([sampled_ELL_AH_df, sampled_ELL_ST_df, sampled_ELL_SS_df], ignore_index=True)
C_df
# Out:
#                                        Document        Directory  \
# 0            BAREC_Curriculum_03_slm_t1_u01_008       Curriculum
# 1            BAREC_Curriculum_02_arb_t1_u02_003       Curriculum
# 2            BAREC_Curriculum_04_slm_t1_u02_001       Curriculum
# 3   BAREC_TunisCurriculum_Pri_03_reading_P1_007  TunisCurriculum
# 4           BAREC_DARES_ArabicLanguage_G3_2_001            DARES
# 5            BAREC_Curriculum_09_arb_a1_u02_001       Curriculum
# 6      BAREC_TunisCurriculum_Pri_05_reading_020  TunisCurriculum
# 7                 BAREC_ArabicMMLU_Group_19_002       ArabicMMLU
# 8            BAREC_Curriculum_09_arb_t1_u02_006       Curriculum
# 9            BAREC_Curriculum_08_arb_t1_u03_008       Curriculum
# 10           BAREC_Curriculum_09_arb_t1_u02_023       Curriculum
# 11           BAREC_Curriculum_11_arb_a1_u03_020       Curriculum
# 12           BAREC_Curriculum_11_arb_t1_u02_034       Curriculum
# 13           BAREC_Curriculum_11_arb_t1_u02_004       Curriculum
# 14      BAREC_DARES_Artistic_Education_G9_5_001            DARES
# 15           BAREC_Curriculum_11_arb_a1_u01_047       Curriculum
# 16        BAREC_DARES_Arabic_Language_G10_5_008            DARES
# 17                   BAREC_DARES_Science_G4_006            DARES
# 18                 BAREC_ArabicMMLU_Group_2_001       ArabicMMLU
# 19                 BAREC_DARES_Science_G3_3_001            DARES
# 20                 BAREC_ArabicMMLU_Group_8_007       ArabicMMLU
# 21                 BAREC_ArabicMMLU_Group_7_009       ArabicMMLU
# 22                 BAREC_DARES_Science_G8_2_008            DARES
# 23                   BAREC_DARES_Science_G8_003            DARES
# 24                 BAREC_DARES_Science_G5_4_001            DARES
# 25                 BAREC_DARES_Science_G7_3_001            DARES
# 26                 BAREC_DARES_Science_G7_4_005            DARES
# 27                 BAREC_DARES_Science_G7_4_003            DARES
# 28                BAREC_DARES_Geography_G10_001            DARES
# 29               BAREC_DARES_Psychology_G10_008            DARES
# 30                BAREC_DARES_Physics_G10_2_001            DARES
# 31                  BAREC_DARES_Geology_G10_012            DARES
# 32           BAREC_DARES_Computer_Sci_G10_3_005            DARES
# 33                     BAREC_DARES_Tech_G12_003            DARES
# 34                 BAREC_DARES_Sociology_G4_006            DARES
# 35               BAREC_DARES_Sociology_G4_4_005            DARES
# 36           BAREC_Curriculum_04_soc_t1_u03_004       Curriculum
# 37           BAREC_Curriculum_04_soc_t2_u08_004       Curriculum
# 38                 BAREC_ArabicMMLU_Group_9_009       ArabicMMLU
# 39           BAREC_Curriculum_09_soc_t3_u07_006       Curriculum
# 40           BAREC_Curriculum_09_soc_t3_u08_002       Curriculum
# 41               BAREC_DARES_Sociology_G7_2_009            DARES
# 42           BAREC_Curriculum_05_soc_t3_u06_001       Curriculum
# 43           BAREC_Curriculum_07_soc_t1_u02_001       Curriculum
# 44           BAREC_Curriculum_10_soc_t2_u07_003       Curriculum
# 45       BAREC_DARES_Critical_Thinking_G9_2_006            DARES
# 46              BAREC_DARES_Sociology_G10_2_009            DARES
# 47                  BAREC_DARES_History_G11_008            DARES
# 48           BAREC_Curriculum_11_soc_t3_u09_004       Curriculum
# 49               BAREC_DARES_Sociology_G9_2_001            DARES
#
#                 Source                      Book Author             Domain  \
# 0   Emarati Curriculum   Grade 3 Islamic Studies      #  Arts & Humanities
# 1   Emarati Curriculum   Grade 2 Arabic Language      #  Arts & Humanities
# 2   Emarati Curriculum   Grade 4 Islamic Studies      #  Arts & Humanities
# 3     Tunis Curriculum   Grade 3 Arabic Language      #  Arts & Humanities
# 4                DARES       G3 - ArabicLanguage      #  Arts & Humanities
# 5   Emarati Curriculum   Grade 9 Arabic Language      #  Arts & Humanities
# 6     Tunis Curriculum   Grade 5 Arabic Language      #  Arts & Humanities
# 7           ArabicMMLU                         #      #  Arts & Humanities
# 8   Emarati Curriculum   Grade 9 Arabic Language      #  Arts & Humanities
# 9   Emarati Curriculum   Grade 8 Arabic Language      #  Arts & Humanities
# 10  Emarati Curriculum   Grade 9 Arabic Language      #  Arts & Humanities
# 11  Emarati Curriculum  Grade 11 Arabic Language      #  Arts & Humanities
# 12  Emarati Curriculum  Grade 11 Arabic Language      #  Arts & Humanities
# 13  Emarati Curriculum  Grade 11 Arabic Language      #  Arts & Humanities
# 14               DARES   G9 - Artistic_Education      #  Arts & Humanities
# 15  Emarati Curriculum  Grade 11 Arabic Language      #  Arts & Humanities
# 16               DARES     G10 - Arabic_Language      #  Arts & Humanities
# 17               DARES              G4 - Science      #               STEM
# 18          ArabicMMLU                         #      #               STEM
# 19               DARES              G3 - Science      #               STEM
# 20          ArabicMMLU                         #      #               STEM
# 21          ArabicMMLU                         #      #               STEM
# 22               DARES              G8 - Science      #               STEM
# 23               DARES              G8 - Science      #               STEM
# 24               DARES              G5 - Science      #               STEM
# 25               DARES              G7 - Science      #               STEM
# 26               DARES              G7 - Science      #               STEM
# 27               DARES              G7 - Science      #               STEM
# 28               DARES           G10 - Geography      #               STEM
# 29               DARES          G10 - Psychology      #               STEM
# 30               DARES             G10 - Physics      #               STEM
# 31               DARES             G10 - Geology      #               STEM
# 32               DARES        G10 - Computer_Sci      #               STEM
# 33               DARES                G12 - Tech      #               STEM
# 34               DARES            G4 - Sociology      #    Social Sciences
# 35               DARES            G4 - Sociology      #    Social Sciences
# 36  Emarati Curriculum   Grade 4 Social Sciences      #    Social Sciences
# 37  Emarati Curriculum   Grade 4 Social Sciences      #    Social Sciences
# 38          ArabicMMLU                         #      #    Social Sciences
# 39  Emarati Curriculum   Grade 9 Social Sciences      #    Social Sciences
# 40  Emarati Curriculum   Grade 9 Social Sciences      #    Social Sciences
# 41               DARES            G7 - Sociology      #    Social Sciences
# 42  Emarati Curriculum   Grade 5 Social Sciences      #    Social Sciences
# 43  Emarati Curriculum   Grade 7 Social Sciences      #    Social Sciences
# 44  Emarati Curriculum  Grade 10 Social Sciences      #    Social Sciences
# 45               DARES    G9 - Critical_Thinking      #    Social Sciences
# 46               DARES           G10 - Sociology      #    Social Sciences
# 47               DARES             G11 - History      #    Social Sciences
# 48  Emarati Curriculum  Grade 11 Social Sciences      #    Social Sciences
# 7          529              20              Yes                26.450000
# 8          605              34               No                17.794118
# 9          604             141               No                 4.283688
# 10         601              21               No                28.619048
# 11         621              35               No                17.742857
# 12         613              41               No                14.951220
# 13         605              24               No                25.208333
# 14         673               6               No               112.166667
# 15         607              69               No                 8.797101
# 16         621               6               No               103.500000
# 17         477               7               No                68.142857
# 18         372              20              Yes                18.600000
# 19         614               8               No                76.750000
# 20         509              20              Yes                25.450000
# 21         357              20              Yes                17.850000
# 22         670              10               No                67.000000
# 23         644               8               No                80.500000
# 24         499               7               No                71.285714
# 25         611               9               No                67.888889
# 26         634              11               No                57.636364
# 27         659               9               No                73.222222
# 28         674               8               No                84.250000
# 29         602               7               No                86.000000
# 30         641               8               No                80.125000
# 31         601              11               No                54.636364
# 32         656               8               No                82.000000
# 33         684               8               No                85.500000
# 34         651               9               No                72.333333
# 35         631               9               No                70.111111
# 36         606              59               No                10.271186
# 37         604              44               No                13.727273
# 38         304              20              Yes                15.200000
# 39         607              65               No                 9.338462
# 40         606              52               No                11.653846
# 41         649               9               No                72.111111
# 42         605             132               No                 4.583333
# 43         851              85              Yes                10.011765
# 44         640              50               No                12.800000
# 45         609               9               No                67.666667
# 46         635               7               No                90.714286
# 47         629               9               No                69.888889
# 48         649              51               No                12.725490
# 49          73               2               No                36.500000
#
#     sampled_sentence_index
# 0                       68
# 1                       42
# 2                       51
# 3                       52
# 4                        7
# 5                       84
# 6                       42
# 7                        0
# 8                        0
# 9                       41
# 10                       0
# 11                       0
# 12                      20
# 13                       0
# 14                       0
# 15                      58
# 16                       0
# 17                       0
# 18                       0
# 19                       1
# 20                       0
# 21                       0
# 22                       8
# 23                       1
# 24                       0
# 25                       7
# 26                       5
# 27                       7
# 28                       1
# 29                       0
# 30                       1
# 31                       5
# 32                       1
# 33                       1
# 34                       7
# 35                       7
# 36                      17
# 37                      17
# 38                       0
# 39                      32
# 40                      27
# 41                       7
# 42                      71
# 43                      76
# 44                      15
# 45                       7
# 46                       0
# 47                       7
# 48                      16
# 49                       1

# %%
C_df['selected_sent_raw'] = None
C_df['selected_sent_word_count'] = None
C_df['selected_sent_words'] = None

for i, row in C_df.iterrows():
    directory = row['Directory']
    document = row['Document']

    annotations_file_path = (
        f"BAREC-10M/Data/Morphology_and_Readability/"
        f"{directory}/{document}.json"
    )

    with open(annotations_file_path, 'r', encoding='utf-8') as f:
        annotations = json.load(f)

    annotations = pd.DataFrame(annotations)

    selected_sentence_index = int(row['sampled_sentence_index'])

    selected_row = annotations.iloc[selected_sentence_index]

    raw_sentence = selected_row['raw_sents']
    word_count = selected_row['sents_word_count']
    words = selected_row['word']   # list of strings

    C_df.at[i, 'selected_sent_raw'] = raw_sentence
    C_df.at[i, 'selected_sent_word_count'] = word_count
    C_df.at[i, 'selected_sent_words'] = words

# %%
C_df = C_df[[
    'Directory',
    'Document',
    'sampled_sentence_index',
    'Source',
    'Book',
    'Author',
    'Domain',
    'Readership Group',
    'Text Category',
    'average sentence length',
    'selected_sent_raw',
    'selected_sent_word_count',
    'selected_sent_words'
]]

# %%
C_df.rename(columns={
    'average sentence length': 'average_sentence_length_per_doc',
}, inplace=True)

# %%
C_df
# Out:
#           Directory                                     Document  \
# 0        Curriculum           BAREC_Curriculum_03_slm_t1_u01_008
# 1        Curriculum           BAREC_Curriculum_02_arb_t1_u02_003
# 2        Curriculum           BAREC_Curriculum_04_slm_t1_u02_001
# 3   TunisCurriculum  BAREC_TunisCurriculum_Pri_03_reading_P1_007
# 4             DARES          BAREC_DARES_ArabicLanguage_G3_2_001
# 5        Curriculum           BAREC_Curriculum_09_arb_a1_u02_001
# 6   TunisCurriculum     BAREC_TunisCurriculum_Pri_05_reading_020
# 7        ArabicMMLU                BAREC_ArabicMMLU_Group_19_002
# 8        Curriculum           BAREC_Curriculum_09_arb_t1_u02_006
# 9        Curriculum           BAREC_Curriculum_08_arb_t1_u03_008
# 10       Curriculum           BAREC_Curriculum_09_arb_t1_u02_023
# 11       Curriculum           BAREC_Curriculum_11_arb_a1_u03_020
# 12       Curriculum           BAREC_Curriculum_11_arb_t1_u02_034
# 13       Curriculum           BAREC_Curriculum_11_arb_t1_u02_004
# 14            DARES      BAREC_DARES_Artistic_Education_G9_5_001
# 15       Curriculum           BAREC_Curriculum_11_arb_a1_u01_047
# 16            DARES        BAREC_DARES_Arabic_Language_G10_5_008
# 17            DARES                   BAREC_DARES_Science_G4_006
# 18       ArabicMMLU                 BAREC_ArabicMMLU_Group_2_001
# 19            DARES                 BAREC_DARES_Science_G3_3_001
# 20       ArabicMMLU                 BAREC_ArabicMMLU_Group_8_007
# 21       ArabicMMLU                 BAREC_ArabicMMLU_Group_7_009
# 22            DARES                 BAREC_DARES_Science_G8_2_008
# 23            DARES                   BAREC_DARES_Science_G8_003
# 24            DARES                 BAREC_DARES_Science_G5_4_001
# 25            DARES                 BAREC_DARES_Science_G7_3_001
# 26            DARES                 BAREC_DARES_Science_G7_4_005
# 27            DARES                 BAREC_DARES_Science_G7_4_003
# 28            DARES                BAREC_DARES_Geography_G10_001
# 29            DARES               BAREC_DARES_Psychology_G10_008
# 30            DARES                BAREC_DARES_Physics_G10_2_001
# 31            DARES                  BAREC_DARES_Geology_G10_012
# 32            DARES           BAREC_DARES_Computer_Sci_G10_3_005
# 33            DARES                     BAREC_DARES_Tech_G12_003
# 34            DARES                 BAREC_DARES_Sociology_G4_006
# 35            DARES               BAREC_DARES_Sociology_G4_4_005
# 36       Curriculum           BAREC_Curriculum_04_soc_t1_u03_004
# 37       Curriculum           BAREC_Curriculum_04_soc_t2_u08_004
# 38       ArabicMMLU                 BAREC_ArabicMMLU_Group_9_009
# 39       Curriculum           BAREC_Curriculum_09_soc_t3_u07_006
# 40       Curriculum           BAREC_Curriculum_09_soc_t3_u08_002
# 41            DARES               BAREC_DARES_Sociology_G7_2_009
# 42       Curriculum           BAREC_Curriculum_05_soc_t3_u06_001
# 43       Curriculum           BAREC_Curriculum_07_soc_t1_u02_001
# 44       Curriculum           BAREC_Curriculum_10_soc_t2_u07_003
# 45            DARES       BAREC_DARES_Critical_Thinking_G9_2_006
# 46            DARES              BAREC_DARES_Sociology_G10_2_009
# 47            DARES                  BAREC_DARES_History_G11_008
# 48       Curriculum           BAREC_Curriculum_11_soc_t3_u09_004
# 49            DARES               BAREC_DARES_Sociology_G9_2_001
#
#     sampled_sentence_index              Source                      Book  \
# 0                       68  Emarati Curriculum   Grade 3 Islamic Studies
# 1                       42  Emarati Curriculum   Grade 2 Arabic Language
# 2                       51  Emarati Curriculum   Grade 4 Islamic Studies
# 3                       52    Tunis Curriculum   Grade 3 Arabic Language
# 4                        7               DARES       G3 - ArabicLanguage
# 5                       84  Emarati Curriculum   Grade 9 Arabic Language
# 6                       42    Tunis Curriculum   Grade 5 Arabic Language
# 7                        0          ArabicMMLU                         #
# 8                        0  Emarati Curriculum   Grade 9 Arabic Language
# 9                       41  Emarati Curriculum   Grade 8 Arabic Language
# 10                       0  Emarati Curriculum   Grade 9 Arabic Language
# 11                       0  Emarati Curriculum  Grade 11 Arabic Language
# 12                      20  Emarati Curriculum  Grade 11 Arabic Language
# 13                       0  Emarati Curriculum  Grade 11 Arabic Language
# 14                       0               DARES   G9 - Artistic_Education
# 15                      58  Emarati Curriculum  Grade 11 Arabic Language
# 16                       0               DARES     G10 - Arabic_Language
# 17                       0               DARES              G4 - Science
# 18                       0          ArabicMMLU                         #
# 19                       1               DARES              G3 - Science
# 20                       0          ArabicMMLU                         #
# 21                       0          ArabicMMLU                         #
# 22                       8               DARES              G8 - Science
# 23                       1               DARES              G8 - Science
# 24                       0               DARES              G5 - Science
# 25                       7               DARES              G7 - Science
# 26                       5               DARES              G7 - Science
# 27                       7               DARES              G7 - Science
# 28                       1               DARES           G10 - Geography
# 29                       0               DARES          G10 - Psychology
# 30                       1               DARES             G10 - Physics
# 31                       5               DARES             G10 - Geology
# 32                       1               DARES        G10 - Computer_Sci
# 33                       1               DARES                G12 - Tech
# 34                       7               DARES            G4 - Sociology
# 35                       7               DARES            G4 - Sociology
# 36                      17  Emarati Curriculum   Grade 4 Social Sciences
# 37                      17  Emarati Curriculum   Grade 4 Social Sciences
# 38                       0          ArabicMMLU                         #
# 39                      32  Emarati Curriculum   Grade 9 Social Sciences
# 40                      27  Emarati Curriculum   Grade 9 Social Sciences
# 41                       7               DARES            G7 - Sociology
# 42                      71  Emarati Curriculum   Grade 5 Social Sciences
# 43                      76  Emarati Curriculum   Grade 7 Social Sciences
# 44                      15  Emarati Curriculum  Grade 10 Social Sciences
# 45                       7               DARES    G9 - Critical_Thinking
# 46                       0               DARES           G10 - Sociology
# 47                       7               DARES             G11 - History
# 48                      16  Emarati Curriculum  Grade 11 Social Sciences
# 49                       1               DARES            G9 - Sociology
#
#    Author             Domain   Readership Group  \
# 0       #  Arts & Humanities  Foundational Text
# 1       #  Arts & Humanities  Foundational Text
# 2       #  Arts & Humanities  Foundational Text
# 3       #  Arts & Humanities  Foundational Text
# 4       #  Arts & Humanities  Foundational Text
# 5       #  Arts & Humanities      Advanced Text
# 6       #  Arts & Humanities      Advanced Text
# 7       #  Arts & Humanities      Advanced Text
# 8       #  Arts & Humanities      Advanced Text
# 9       #  Arts & Humanities      Advanced Text
# 38  Educational Materials; Language & Linguistics
# 39  Educational Materials; Language & Linguistics
# 40  Educational Materials; Language & Linguistics
# 41  Educational Materials; Language & Linguistics
# 42  Educational Materials; Language & Linguistics
# 43  Educational Materials; Language & Linguistics
# 44  Educational Materials; Language & Linguistics
# 45  Educational Materials; Language & Linguistics
# 46  Educational Materials; Language & Linguistics
# 47  Educational Materials; Language & Linguistics
# 48  Educational Materials; Language & Linguistics
# 49  Educational Materials; Language & Linguistics
#
#     average_sentence_length_per_doc  \
# 0                          7.500000
# 1                          7.390244
# 2                          6.874126
# 3                          9.949153
# 4                         66.888889
# 5                          8.517647
# 6                         12.387755
# 7                         26.450000
# 8                         17.794118
# 9                          4.283688
# 10                        28.619048
# 11                        17.742857
# 12                        14.951220
# 13                        25.208333
# 14                       112.166667
# 15                         8.797101
# 16                       103.500000
# 17                        68.142857
# 18                        18.600000
# 19                        76.750000
# 20                        25.450000
# 21                        17.850000
# 22                        67.000000
# 23                        80.500000
# 24                        71.285714
# 25                        67.888889
# 26                        57.636364
# 27                        73.222222
# 28                        84.250000
# 29                        86.000000
# 30                        80.125000
# 31                        54.636364
# 32                        82.000000
# 33                        85.500000
# 34                        72.333333
# 35                        70.111111
# 36                        10.271186
# 37                        13.727273
# 38                        15.200000
# 39                         9.338462
# 40                        11.653846
# 41                        72.111111
# 42                         4.583333
# 43                        10.011765
# 44                        12.800000
# 45                        67.666667
# 46                        90.714286
# 47                        69.888889
# 48                        12.725490
# 49                        36.500000
#
#                                     selected_sent_raw  \
# 0   سَأُرْسِلُ إِلَيْهِمْ بِهَدِيَّةٍ ثَمينَةٍ, وَ...
# 1   وَطَنُنا وَطَنُ خيرٍ وَعَطاءٍ, وَطَنُ أَمْنٍ س...
# 2   ما الْكُتُبُ الْمَقْصودَةُ في الْآيَةِ الْكَري...
# 3        وعلى ساعدك المضنى لنا كل فصل موسم يطفح رزقاً
# 4   قف خالد يتأمل البحر وجماله وأمواجه المتلاطمة، ...
# 5   ما الّذي يمكنُ أنْ تعملَهُ لكي تصبحَ كلُّ وصاي...
# 6   ذات يوم من أواخر شهر جوان خرجت كعادتي إلى أطرا...
# 7   دعاء الاستفتاح من  (أ) شروط الاستفتاح  (ب) أرك...
# 8   إذ مال الشعراء إلى إحياء النماذج التراثية في ا...
# 9   إنَّ التلَوُّثَ وارْتفاعِ نِسَبِ المُلوحةِ في ...
# 10  ولذلك يعدّ الصدق من أهم شروط كتابة السيرة الأد...
# 11  وأن يكون قد سجّل أي سؤال لديه حول أي نقطة من ن...
# 12  كل ما في الأمر أننا كنا ثمانية عشر شخصًا في بي...
# 13                يقول حسان بن ثابت في إحدى بديعياته:
# 14  صحيح أن الألوان الشائعة غالبا ما تكون الأسود، ...
# 15  الكَلامُ المتَواصِلُ بِصوتٍ مُنخَفِضٍ وَصوتُ ا...
# 16  تقع الأخطاء الإملائية واللغوية في النص التالي ...
# 17  تحسين التصاميم يتم من خلال استخدام النماذج، وا...
# 18  تظهر نتيجة العمل في منطقة المنصة.  (أ) صح  (ب)...
# 19  نظرا لمرور الهواء الرطب من فوق البحر نحو الجبا...
# 20  عندما تسمع شيئا ما فالذي يعمل على التعرف على ه...
# 21  عدد إذا جمعته مع 4 كان الناتج 4  (أ) 0  (ب) 4 ...
# 22  يمكن تصحيح طول النظر باستخدام جراحة الليزر. تح...
# 23  على الرغم من أن هذا الحامض يعمل على هضم الطعام...
# 24  الفصل السابع الدرس الأول الغلاف الجوي والطقس أ...
# 25  الصخرة المتحولة هي الصخرة الأم التي تغيرت تحت ...
# 26  التصرف اللائق المتوقع في المختبر هو الجدية وال...
# 27  أثناء تنفيذ هذه الدراسة، يجب توخي الدقة في تسج...
# 28  مدينة المكسيك، العاصمة السابعة عشرة من حيث عدد...
# 29  ما الفرق بين التوكيد والعدوان والخضوع في الإشا...
# 30  القانون الثاني لكيبلر ينص على أن الخط الوهمي م...
# 31  تتكون الكثبان الرملية عادة من رمل ناعم جيد الف...
# 32  تمت زيارتي لمتحف الفن الحديث يوم الخميس الماضي...
# 33  هناك برامج مصممة للتخطيط للمشاريع والمجموعات ا...
# 34  تصحيح مسار الرسالة في أي زمن، وتجنب التشويش وا...
# 35  أقاربي من جهة أمي يكتبون. ثلاثة من فوائد العمل...
# 36  أَمَامَي مَجْمُوعَةُ صُوَرٍ لِعِدَّةِ مَوَانِئ...
# 37  وَمِنْ هَذا المُنْطَلَقِ اسْتَخْدَمَتْ دَوْلَة...
# 38  من النباتات البریة  (أ) الزعرور  (ب) الصنوبر  ...
# 39  إذا أردت نشر أي شئ عن أصدقائك تأكد أنت تنشر عن...
# 40  أقرأُ بتركيز الفقرات الواردة في كتاب وسائل الت...
# 41  هل يدل شكل الأرض على أنها كاملة القطر؟ يلاحظ أ...
# 42  أَصوغُ بِأُسْلوبي مِنْ خِلالِ الشَّكْلِ مَفْهو...
# 43  أشارَ الرسولُ على أصحابِهِ أنْ يهاجروا إلى الح...
# 44  هو الزعيم الروحي للهند, والزعيم الروحي للثورة ...
# 45  القدرة على الفهم والاستيعاب، وإصدار الحكم بناء...
# 46  مصطلح المغرب العربي يطلق على عدد من الدول العر...
# 47  قرر منصور المريدي جد الأسرة المالكة من أهم الأ...
# 48  الى ما يغرس بداخلهم لأننا سنجده يتردد في أعمال...
# 49  الصيانة الدائمة للأدوات والأجهزة المستخدمة داخ...
#
#    selected_sent_word_count                                selected_sent_words
# 0                         9  [سأرسل, إليهم, بهدية, ثمينة, ,, وأرى, ما, سيفع...
# 1                         9     [وطننا, وطن, خير, وعطاء, ,, وطن, أمن, سلام, .]
# 2                         7       [ما, الكتب, المقصودة, في, الآية, الكريمة, ؟]
# 3                         9  [وعلى, ساعدك, المضنى, لنا, كل, فصل, موسم, يطفح...
# 4                        81  [قف, خالد, يتأمل, البحر, وجماله, وأمواجه, المت...
# 5                        16  [ما, الذي, يمكن, أن, تعمله, لكي, تصبح, كل, وصا...
# 6                        30  [ذات, يوم, من, أواخر, شهر, جوان, خرجت, كعادتي,...
# 7                        23  [دعاء, الاستفتاح, من, (, أ, ), شروط, الاستفتاح...
# 8                        61  [إذ, مال, الشعراء, إلى, إحياء, النماذج, التراث...
# 9                        17  [إن, التلوث, وارتفاع, نسب, الملوحة, في, الكثير...
# 10                       10  [ولذلك, يعد, الصدق, من, أهم, شروط, كتابة, السي...
# 11                       14  [وأن, يكون, قد, سجل, أي, سؤال, لديه, حول, أي, ...
# 12                       23  [كل, ما, في, الأمر, أننا, كنا, ثمانية, عشر, شخ...
# 13                        8      [يقول, حسان, بن, ثابت, في, إحدى, بديعياته, :]
# 14                      175  [صحيح, أن, الألوان, الشائعة, غالبا, ما, تكون, ...
# 15                        8  [الكلام, المتواصل, بصوت, منخفض, وصوت, الذباب, ...
# 16                      116  [تقع, الأخطاء, الإملائية, واللغوية, في, النص, ...
# 17                      133  [تحسين, التصاميم, يتم, من, خلال, استخدام, النم...
# 18                       15  [تظهر, نتيجة, العمل, في, منطقة, المنصة, ., (, ...
# 19                       56  [نظرا, لمرور, الهواء, الرطب, من, فوق, البحر, ن...
# 20                       29  [عندما, تسمع, شيئا, ما, فالذي, يعمل, على, التع...
# 21                       20  [عدد, إذا, جمعته, مع, 4, كان, الناتج, 4, (, أ,...
# 22                       42  [يمكن, تصحيح, طول, النظر, باستخدام, جراحة, الل...
# 23                       64  [على, الرغم, من, أن, هذا, الحامض, يعمل, على, ه...
# 24                      119  [الفصل, السابع, الدرس, الأول, الغلاف, الجوي, و...
# 25                       51  [الصخرة, المتحولة, هي, الصخرة, الأم, التي, تغي...
# 26                       49  [التصرف, اللائق, المتوقع, في, المختبر, هو, الج...
# 27                       59  [أثناء, تنفيذ, هذه, الدراسة, ,, يجب, توخي, الد...
# 28                       80  [مدينة, المكسيك, ,, العاصمة, السابعة, عشرة, من...
# 29                      120  [ما, الفرق, بين, التوكيد, والعدوان, والخضوع, ف...
# 30                       46  [القانون, الثاني, لكيبلر, ينص, على, أن, الخط, ...
# 31                       82  [تتكون, الكثبان, الرملية, عادة, من, رمل, ناعم,...
# 32                      114  [تمت, زيارتي, لمتحف, الفن, الحديث, يوم, الخميس...
# 33                       56  [هناك, برامج, مصممة, للتخطيط, للمشاريع, والمجم...
# 34                       95  [تصحيح, مسار, الرسالة, في, أي, زمن, ,, وتجنب, ...
# 35                       52  [أقاربي, من, جهة, أمي, يكتبون, ., ثلاثة, من, ف...
# 36                       22  [أمامي, مجموعة, صور, لعدة, موانئ, في, بلدنا, د...
# 37                       33  [ومن, هذا, المنطلق, استخدمت, دولة, الإمارات, ا...
# 38                       15  [من, النباتات, البرية, (, أ, ), الزعرور, (, ب,...
# 39                       17  [إذا, أردت, نشر, أي, شئ, عن, أصدقائك, تأكد, أن...
# 40                       23  [أقرأ, بتركيز, الفقرات, الواردة, في, كتاب, وسا...
# 41                       76  [هل, يدل, شكل, الأرض, على, أنها, كاملة, القطر,...
# 42                        9  [أصوغ, بأسلوبي, من, خلال, الشكل, مفهوم, دوائر,...
# 43                       21  [أشار, الرسول, على, أصحابه, أن, يهاجروا, إلى, ...
# 44                       17  [هو, الزعيم, الروحي, للهند, ,, والزعيم, الروحي...
# 45                       59  [القدرة, على, الفهم, والاستيعاب, ,, وإصدار, ال...
# 46                      109  [مصطلح, المغرب, العربي, يطلق, على, عدد, من, ال...
# 47                       68  [قرر, منصور, المريدي, جد, الأسرة, المالكة, من,...
# 48                       17  [الى, ما, يغرس, بداخلهم, لأننا, سنجده, يتردد, ...
# 49                       35  [الصيانة, الدائمة, للأدوات, والأجهزة, المستخدم...

# %%
# C_df.to_json('sampled_ELL_sentences.json', orient='records', force_ascii=False, indent=4)

# %%
metadata['Text Category'].value_counts()
# Out:
# Text Category
# Media & Culture                                  7122
# Educational Materials; Language & Linguistics    4709
# Academic                                         4301
# Literature; Art & Music                          3974
# Religion & Philosophy                             254
# Encyclopedic                                      175
# Name: count, dtype: int64

# %%
AC_df = metadata[metadata['Text Category']=='Academic']
print("Academic")
print("==========================")
print(f"Number of documents: {AC_df.shape[0]}")
print("--------------------------")
print(f"Number of sentences: {AC_df['Sentence Count'].sum()}")
print("--------------------------")
print(f"Number of unique books: {AC_df['Book'].nunique()}")
print("--------------------------")
print(f"Number of unique authors: {AC_df['Author'].nunique()}")
print("--------------------------")
print(f"Domain distribution:\n{AC_df['Domain'].value_counts().to_dict()}")
print("--------------------------")
print(f"Readership Group distribution:\n{AC_df['Readership Group'].value_counts().to_dict()}")
print("--------------------------")
print(f"Average sentence length distribution:\n{AC_df['average sentence length'].describe().to_dict()}")
print("==========================")
# Out:
# Academic
# ==========================
# Number of documents: 4301
# --------------------------
# Number of sentences: 90235
# --------------------------
# Number of unique books: 1389
# --------------------------
# Number of unique authors: 1001
# --------------------------
# Domain distribution:
# {'STEM': 2435, 'Social Sciences': 1783, 'Arts & Humanities': 83}
# --------------------------
# Readership Group distribution:
# {'Specialized Text': 4213, 'Advanced Text': 79, 'Foundational Text': 9}
# --------------------------
# Average sentence length distribution:
# {'count': 4301.0, 'mean': 34.18488759420031, 'std': 13.131808815146508, 'min': 4.269565217391304, '25%': 25.0, '50%': 33.421052631578945, '75%': 40.4, 'max': 185.6}
# ==========================

# %%
AC_AH_df = AC_df[AC_df['Domain']=='Arts & Humanities']
print("Academic - Arts & Humanities")
print("==========================")
print(f"Number of documents: {AC_AH_df.shape[0]}")
print("--------------------------")
print(f"Number of sentences: {AC_AH_df['Sentence Count'].sum()}")
print("--------------------------")
print(f"Number of unique books: {AC_AH_df['Book'].nunique()}")
print("--------------------------")
print(f"Number of unique authors: {AC_AH_df['Author'].nunique()}")
print("--------------------------")
print(f"Domain distribution:\n{AC_AH_df['Domain'].value_counts().to_dict()}")
print("--------------------------")
print(f"Readership Group distribution:\n{AC_AH_df['Readership Group'].value_counts().to_dict()}")
print("--------------------------")
print(f"Average sentence length distribution:\n{AC_AH_df['average sentence length'].describe().to_dict()}")
print("==========================")
# Out:
# Academic - Arts & Humanities
# ==========================
# Number of documents: 83
# --------------------------
# Number of sentences: 1802
# --------------------------
# Number of unique books: 83
# --------------------------
# Number of unique authors: 59
# --------------------------
# Domain distribution:
# {'Arts & Humanities': 83}
# --------------------------
# Readership Group distribution:
# {'Specialized Text': 79, 'Advanced Text': 4}
# --------------------------
# Average sentence length distribution:
# {'count': 83.0, 'mean': 31.188017042231646, 'std': 22.67701525021513, 'min': 11.767441860465116, '25%': 21.682065217391305, '50%': 25.61904761904762, '75%': 34.7, 'max': 185.6}
# ==========================

# %%
sampled_AC_AH_advanced_df = AC_AH_df[AC_AH_df['Readership Group']=='Advanced Text'].sample(4, random_state=42)
sampled_AC_AH_special_df = AC_AH_df[AC_AH_df['Readership Group']=='Specialized Text'].sample(12, random_state=42)

# %%
sampled_AC_AH_df = pd.concat([sampled_AC_AH_advanced_df, sampled_AC_AH_special_df], ignore_index=True)

# %%
sampled_AC_AH_sentences_indices = []
for i, row in sampled_AC_AH_df.iterrows():
    directory = row['Directory']
    document = row['Document']
    annotations_file_path = f"BAREC-10M/Data/Morphology_and_Readability/{directory}/{document}.json"

    with open(annotations_file_path, 'r', encoding='utf-8') as f:
        annotations = json.load(f)
        annotations = pd.DataFrame(annotations)
    

    sampled_index = annotations[annotations['sents_word_count'] > 5].sample(1, random_state=42).index.item()
    sampled_AC_AH_sentences_indices.append(sampled_index)
print(sampled_AC_AH_sentences_indices)
# Out:
# [1, 1, 1, 35, 2, 9, 10, 1, 2, 9, 6, 1, 19, 1, 2, 16]

# %%
sampled_AC_AH_df['sampled_sentence_index'] = sampled_AC_AH_sentences_indices

# %%
AC_ST_df = AC_df[AC_df['Domain']=='STEM']
print("Academic - STEM")
print("==========================")
print(f"Number of documents: {AC_ST_df.shape[0]}")
print("--------------------------")
print(f"Number of sentences: {AC_ST_df['Sentence Count'].sum()}")
print("--------------------------")
print(f"Number of unique books: {AC_ST_df['Book'].nunique()}")
print("--------------------------")
print(f"Number of unique authors: {AC_ST_df['Author'].nunique()}")
print("--------------------------")
print(f"Domain distribution:\n{AC_ST_df['Domain'].value_counts().to_dict()}")
print("--------------------------")
print(f"Readership Group distribution:\n{AC_ST_df['Readership Group'].value_counts().to_dict()}")
print("--------------------------")
print(f"Average sentence length distribution:\n{AC_ST_df['average sentence length'].describe().to_dict()}")
print("==========================")
# Out:
# Academic - STEM
# ==========================
# Number of documents: 2435
# --------------------------
# Number of sentences: 42324
# --------------------------
# Number of unique books: 274
# --------------------------
# Number of unique authors: 190
# --------------------------
# Domain distribution:
# {'STEM': 2435}
# --------------------------
# Readership Group distribution:
# {'Specialized Text': 2392, 'Advanced Text': 34, 'Foundational Text': 9}
# --------------------------
# Average sentence length distribution:
# {'count': 2435.0, 'mean': 38.80142923324701, 'std': 11.955880682021828, 'min': 6.740259740259741, '25%': 32.3078947368421, '50%': 37.35294117647059, '75%': 44.142857142857146, 'max': 105.66666666666667}
# ==========================

# %%
sampled_AC_ST_foundational_df = AC_ST_df[AC_ST_df['Readership Group']=='Foundational Text'].sample(5, random_state=42)
sampled_AC_ST_advanced_df = AC_ST_df[AC_ST_df['Readership Group']=='Advanced Text'].sample(5, random_state=42)
sampled_AC_ST_special_df = AC_ST_df[AC_ST_df['Readership Group']=='Specialized Text'].sample(7, random_state=42)

# %%
sampled_AC_ST_df = pd.concat([sampled_AC_ST_foundational_df, sampled_AC_ST_advanced_df, sampled_AC_ST_special_df], ignore_index=True)

# %%
sampled_AC_ST_sentences_indices = []
for i, row in sampled_AC_ST_df.iterrows():
    directory = row['Directory']
    document = row['Document']
    annotations_file_path = f"BAREC-10M/Data/Morphology_and_Readability/{directory}/{document}.json"

    with open(annotations_file_path, 'r', encoding='utf-8') as f:
        annotations = json.load(f)
        annotations = pd.DataFrame(annotations)
    

    sampled_index = annotations[annotations['sents_word_count'] > 5].sample(1, random_state=42).index.item()
    sampled_AC_ST_sentences_indices.append(sampled_index)
print(sampled_AC_ST_sentences_indices)
# Out:
# [10, 1, 1, 76, 9, 1, 1, 36, 2, 1, 0, 15, 10, 9, 0, 15, 5]

# %%
sampled_AC_ST_df['sampled_sentence_index'] = sampled_AC_ST_sentences_indices

# %%
AC_SS_df = AC_df[AC_df['Domain']=='Social Sciences']
print("Academic - Social Sciences")
print("==========================")
print(f"Number of documents: {AC_SS_df.shape[0]}")
print("--------------------------")
print(f"Number of sentences: {AC_SS_df['Sentence Count'].sum()}")
print("--------------------------")
print(f"Number of unique books: {AC_SS_df['Book'].nunique()}")
print("--------------------------")
print(f"Number of unique authors: {AC_SS_df['Author'].nunique()}")
print("--------------------------")
print(f"Domain distribution:\n{AC_SS_df['Domain'].value_counts().to_dict()}")
print("--------------------------")
print(f"Readership Group distribution:\n{AC_SS_df['Readership Group'].value_counts().to_dict()}")
print("--------------------------")
print(f"Average sentence length distribution:\n{AC_SS_df['average sentence length'].describe().to_dict()}")
print("==========================")
# Out:
# Academic - Social Sciences
# ==========================
# Number of documents: 1783
# --------------------------
# Number of sentences: 46109
# --------------------------
# Number of unique books: 1032
# --------------------------
# Number of unique authors: 779
# --------------------------
# Domain distribution:
# {'Social Sciences': 1783}
# --------------------------
# Readership Group distribution:
# {'Specialized Text': 1742, 'Advanced Text': 41}
# --------------------------
# Average sentence length distribution:
# {'count': 1783.0, 'mean': 28.01969486550411, 'std': 11.385668890412788, 'min': 4.269565217391304, '25%': 20.436666666666667, '50%': 26.05, '75%': 32.91875, 'max': 134.75}
# ==========================

# %%
sampled_AC_SS_advanced_df = AC_SS_df[AC_SS_df['Readership Group']=='Advanced Text'].sample(7, random_state=42)
sampled_AC_SS_special_df = AC_SS_df[AC_SS_df['Readership Group']=='Specialized Text'].sample(10, random_state=42)

# %%
sampled_AC_SS_df = pd.concat([sampled_AC_SS_advanced_df, sampled_AC_SS_special_df], ignore_index=True)
sampled_AC_SS_df.shape
# Out:
# (17, 12)

# %%
sampled_AC_SS_sentences_indices = []
for i, row in sampled_AC_SS_df.iterrows():
    directory = row['Directory']
    document = row['Document']
    annotations_file_path = f"BAREC-10M/Data/Morphology_and_Readability/{directory}/{document}.json"

    with open(annotations_file_path, 'r', encoding='utf-8') as f:
        annotations = json.load(f)
        annotations = pd.DataFrame(annotations)
    

    sampled_index = annotations[annotations['sents_word_count'] > 5].sample(1, random_state=42).index.item()
    sampled_AC_SS_sentences_indices.append(sampled_index)
print(sampled_AC_SS_sentences_indices)
# Out:
# [35, 1, 29, 9, 1, 77, 1, 21, 14, 3, 0, 45, 1, 12, 11, 8, 12]

# %%
sampled_AC_SS_df['sampled_sentence_index'] = sampled_AC_SS_sentences_indices

# %%
D_df = pd.concat([sampled_AC_AH_df, sampled_AC_ST_df, sampled_AC_SS_df], ignore_index=True)
D_df
# Out:
#                                              Document  Directory  \
# 0                          BAREC_Hindawi_58285828_001    Hindawi
# 1                          BAREC_Hindawi_97969752_001    Hindawi
# 2                          BAREC_Hindawi_42048057_001    Hindawi
# 3                          BAREC_Hindawi_90507395_001    Hindawi
# 4                          BAREC_Hindawi_57379637_001    Hindawi
# 5                          BAREC_Hindawi_14046425_001    Hindawi
# 6                          BAREC_Hindawi_41928480_001    Hindawi
# 7                          BAREC_Hindawi_59752571_001    Hindawi
# 8                          BAREC_Hindawi_38614175_001    Hindawi
# 9                          BAREC_Hindawi_51971317_001    Hindawi
# 10                         BAREC_Hindawi_29318372_001    Hindawi
# 11                         BAREC_Hindawi_97961385_001    Hindawi
# 12                         BAREC_Hindawi_19204286_001    Hindawi
# 13                         BAREC_Hindawi_30719715_001    Hindawi
# 14                         BAREC_Hindawi_74969797_001    Hindawi
# 15                         BAREC_Hindawi_60697085_001    Hindawi
# 16                         BAREC_Hindawi_85285919_001    Hindawi
# 17                         BAREC_Hindawi_25029086_001    Hindawi
# 18                         BAREC_Hindawi_74618628_001    Hindawi
# 19                         BAREC_Hindawi_13026818_001    Hindawi
# 20                         BAREC_Hindawi_92080696_001    Hindawi
# 21                         BAREC_Hindawi_48350803_001    Hindawi
# 22                         BAREC_Hindawi_51929307_001    Hindawi
# 23                         BAREC_Hindawi_79392975_001    Hindawi
# 24                         BAREC_Hindawi_75261636_001    Hindawi
# 25                         BAREC_Hindawi_26973525_001    Hindawi
# 26          BAREC_MedArabiQ_Y1_Physiology_PDF_QA1_015  MedArabiQ
# 27            BAREC_MedArabiQ_Y1_Anatomy_PDF_QA13_010  MedArabiQ
# 28   BAREC_MedArabiQ_Y5_Ophthalmology_Scanned_QA2_007  MedArabiQ
# 29      BAREC_MedArabiQ_Y2_Histology_Scanned_QA26_023  MedArabiQ
# 30         BAREC_MedArabiQ_Y1_Cardiology_PDF_QA10_002  MedArabiQ
# 31         BAREC_MedArabiQ_Y1_Anatomy_Scanned_QA5_036  MedArabiQ
# 32   BAREC_MedArabiQ_Y2_Biochemistry_Scanned_QA11_012  MedArabiQ
# 33                         BAREC_Hindawi_59395164_001    Hindawi
# 34                         BAREC_Hindawi_38063631_001    Hindawi
# 35                         BAREC_Hindawi_31306851_001    Hindawi
# 36                         BAREC_Hindawi_63172484_001    Hindawi
# 37                         BAREC_Hindawi_20271796_001    Hindawi
# 38  BAREC_UN_Universal Declaration of Human Rights...         UN
# 39                         BAREC_Hindawi_46494205_001    Hindawi
# 40                         BAREC_Hindawi_71858151_001    Hindawi
# 41               BAREC_Ofoq_May_2023_أحمد_جابر_7_001       Ofoq
# 42    BAREC_Ofoq_April_2021_عبد_الإله_الديوهﭽي_6_001       Ofoq
# 43         BAREC_Ofoq_Aug_2020_رفيف_رضا_صيداوي_10_001       Ofoq
# 44        BAREC_Kalima_الارض_واحلام_يقظة_الإرادة_001     Kalima
# 45                         BAREC_Hindawi_46050209_001    Hindawi
# 9                                 Zaki Naguib Mahmoud  Arts & Humanities
# 10                             Mohammed Kamil Hussein  Arts & Humanities
# 11                                        Muheeb Nasr  Arts & Humanities
# 12                                      Youssef Karam  Arts & Humanities
# 13                              Yamna Tarif al-Khouli  Arts & Humanities
# 14  David L. Dotlich, Peter C. Cairo, and Stephen ...  Arts & Humanities
# 15                                      Ali al-Shadwi  Arts & Humanities
# 16                       Mamoun Abdul Latif Al-Rahhal               STEM
# 17                       Mamoun Abdul Latif Al-Rahhal               STEM
# 18                       Mamoun Abdul Latif Al-Rahhal               STEM
# 19                                        Jane Potter               STEM
# 20                       Mamoun Abdul Latif Al-Rahhal               STEM
# 21                                       Lisa Randall               STEM
# 22                                     Nicholas James               STEM
# 23                                     C. Julian Chen               STEM
# 24                            Ahmed Hamad Al-Husseini               STEM
# 25                                       John Griffin               STEM
# 26                                                  #               STEM
# 27                                                  #               STEM
# 28                                                  #               STEM
# 29                                                  #               STEM
# 30                                                  #               STEM
# 31                                                  #               STEM
# 32                                                  #               STEM
# 33                                       Paul Krugman    Social Sciences
# 34                                 Joseph M. Siracusa    Social Sciences
# 35                                   Kelsey Timmerman    Social Sciences
# 36                                    Sarah Bonjourni    Social Sciences
# 37                                    Nadia Shantzler    Social Sciences
# 38                                UN (United Nations)    Social Sciences
# 39                                 Richard L. Courier    Social Sciences
# 40                                       George Zidan    Social Sciences
# 41                                        Ahmed Jaber    Social Sciences
# 42                               Abdul Ilah Al-Diwaji    Social Sciences
# 43                                Rafeef Reda Saidawi    Social Sciences
# 44                                   Gaston Bachelard    Social Sciences
# 45                                  Abdul Wahab Azzam    Social Sciences
# 46                             Mohamed Mustafa Safwat    Social Sciences
# 47                                     Nabih Al-Burji    Social Sciences
# 48                                   Mohsen Al-Talili    Social Sciences
# 49                                      Salama Moussa    Social Sciences
#
#      Readership Group Text Category  Word Count  Sentence Count  \
# 0       Advanced Text      Academic         503              21
# 1       Advanced Text      Academic         501              19
# 2       Advanced Text      Academic         518              19
# 3       Advanced Text      Academic         506              43
# 4    Specialized Text      Academic         525              10
# 5    Specialized Text      Academic         521              11
# 6    Specialized Text      Academic         542              15
# 7    Specialized Text      Academic         522              21
# 8    Specialized Text      Academic         928               5
# 9    Specialized Text      Academic         529              11
# 10   Specialized Text      Academic         504              12
# 11   Specialized Text      Academic         498              20
# 12   Specialized Text      Academic         505              21
# 13   Specialized Text      Academic         529              27
# 14   Specialized Text      Academic         500              23
# 15   Specialized Text      Academic         503              24
# 16  Foundational Text      Academic         508              15
# 17  Foundational Text      Academic         510              19
# 18  Foundational Text      Academic         511              19
# 19  Foundational Text      Academic         519              77
# 20  Foundational Text      Academic         533              27
# 21      Advanced Text      Academic         504              21
# 22      Advanced Text      Academic         523              21
# 23      Advanced Text      Academic         509              40
# 24      Advanced Text      Academic         535               7
# 25      Advanced Text      Academic         512              26
# 26   Specialized Text      Academic         626              19
# 27   Specialized Text      Academic         634              23
# 28   Specialized Text      Academic         616              12
# 29   Specialized Text      Academic         624              14
# 30   Specialized Text      Academic         631              17
# 31   Specialized Text      Academic         615              23
# 32   Specialized Text      Academic         630              11
# 33      Advanced Text      Academic        1303              59
# 34      Advanced Text      Academic         504              23
# 35      Advanced Text      Academic         511              33
# 36      Advanced Text      Academic         508              27
# 37      Advanced Text      Academic         590              24
# 38      Advanced Text      Academic        1426              93
# 39      Advanced Text      Academic         523              21
# 40   Specialized Text      Academic         507              27
# 41   Specialized Text      Academic         663              20
# 42   Specialized Text      Academic         624              28
# 43   Specialized Text      Academic         617              20
# 44   Specialized Text      Academic         754              52
# 45   Specialized Text      Academic         504              22
# 46   Specialized Text      Academic         535              14
# 47   Specialized Text      Academic         619              17
# 48   Specialized Text      Academic         667              14
# 49   Specialized Text      Academic         505              14
#
#    In BAREC Corpus?  average sentence length  sampled_sentence_index
# 0                No                23.952381                       1
# 1                No                26.368421                       1
# 2                No                27.263158                       1
# 3                No                11.767442                      35
# 4                No                52.500000                       2
# 5                No                47.363636                       9
# 6                No                36.133333                      10
# 7                No                24.857143                       1
# 8                No               185.600000                       2
# 9                No                48.090909                       9
# 10               No                42.000000                       6
# 11               No                24.900000                       1
# 12               No                24.047619                      19
# 13               No                19.592593                       1
# 14               No                21.739130                       2
# 15               No                20.958333                      16
# 16               No                33.866667                      10
# 17               No                26.842105                       1
# 18               No                26.894737                       1
# 19               No                 6.740260                      76
# 20               No                19.740741                       9
# 21               No                24.000000                       1
# 22               No                24.904762                       1
# 23               No                12.725000                      36
# 24               No                76.428571                       2
# 25               No                19.692308                       1
# 26               No                32.947368                       0
# 27               No                27.565217                      15
# 28               No                51.333333                      10
# 29               No                44.571429                       9
# 30               No                37.117647                       0
# 31               No                26.739130                      15
# 32               No                57.272727                       5
# 33              Yes                22.084746                      35
# 34               No                21.913043                       1
# 35               No                15.484848                      29
# 36               No                18.814815                       9
# 37               No                24.583333                       1
# 38              Yes                15.333333                      77
# 39               No                24.904762                       1
# 40               No                18.777778                      21
# 41               No                33.150000                      14
# 42               No                22.285714                       3
# 43               No                30.850000                       0
# 44               No                14.500000                      45
# 45               No                22.909091                       1
# 46               No                38.214286                      12
# 47            ST2&3                36.411765                      11
# 48               No                47.642857                       8
# 49               No                36.071429                      12

# %%
D_df['selected_sent_raw'] = None
D_df['selected_sent_word_count'] = None
D_df['selected_sent_words'] = None

for i, row in D_df.iterrows():
    directory = row['Directory']
    document = row['Document']

    annotations_file_path = (
        f"BAREC-10M/Data/Morphology_and_Readability/"
        f"{directory}/{document}.json"
    )

    with open(annotations_file_path, 'r', encoding='utf-8') as f:
        annotations = json.load(f)

    annotations = pd.DataFrame(annotations)

    selected_sentence_index = int(row['sampled_sentence_index'])

    selected_row = annotations.iloc[selected_sentence_index]

    raw_sentence = selected_row['raw_sents']
    word_count = selected_row['sents_word_count']
    words = selected_row['word']   # list of strings

    D_df.at[i, 'selected_sent_raw'] = raw_sentence
    D_df.at[i, 'selected_sent_word_count'] = word_count
    D_df.at[i, 'selected_sent_words'] = words

# %%
D_df = D_df[[
    'Directory',
    'Document',
    'sampled_sentence_index',
    'Source',
    'Book',
    'Author',
    'Domain',
    'Readership Group',
    'Text Category',
    'average sentence length',
    'selected_sent_raw',
    'selected_sent_word_count',
    'selected_sent_words'
]]

# %%
D_df.rename(columns={
    'average sentence length': 'average_sentence_length_per_doc',
}, inplace=True)

# %%
D_df
# Out:
#     Directory                                           Document  \
# 0     Hindawi                         BAREC_Hindawi_58285828_001
# 1     Hindawi                         BAREC_Hindawi_97969752_001
# 2     Hindawi                         BAREC_Hindawi_42048057_001
# 3     Hindawi                         BAREC_Hindawi_90507395_001
# 4     Hindawi                         BAREC_Hindawi_57379637_001
# 5     Hindawi                         BAREC_Hindawi_14046425_001
# 6     Hindawi                         BAREC_Hindawi_41928480_001
# 7     Hindawi                         BAREC_Hindawi_59752571_001
# 8     Hindawi                         BAREC_Hindawi_38614175_001
# 9     Hindawi                         BAREC_Hindawi_51971317_001
# 10    Hindawi                         BAREC_Hindawi_29318372_001
# 11    Hindawi                         BAREC_Hindawi_97961385_001
# 12    Hindawi                         BAREC_Hindawi_19204286_001
# 13    Hindawi                         BAREC_Hindawi_30719715_001
# 14    Hindawi                         BAREC_Hindawi_74969797_001
# 15    Hindawi                         BAREC_Hindawi_60697085_001
# 16    Hindawi                         BAREC_Hindawi_85285919_001
# 17    Hindawi                         BAREC_Hindawi_25029086_001
# 18    Hindawi                         BAREC_Hindawi_74618628_001
# 19    Hindawi                         BAREC_Hindawi_13026818_001
# 20    Hindawi                         BAREC_Hindawi_92080696_001
# 21    Hindawi                         BAREC_Hindawi_48350803_001
# 22    Hindawi                         BAREC_Hindawi_51929307_001
# 23    Hindawi                         BAREC_Hindawi_79392975_001
# 24    Hindawi                         BAREC_Hindawi_75261636_001
# 25    Hindawi                         BAREC_Hindawi_26973525_001
# 26  MedArabiQ          BAREC_MedArabiQ_Y1_Physiology_PDF_QA1_015
# 27  MedArabiQ            BAREC_MedArabiQ_Y1_Anatomy_PDF_QA13_010
# 28  MedArabiQ   BAREC_MedArabiQ_Y5_Ophthalmology_Scanned_QA2_007
# 29  MedArabiQ      BAREC_MedArabiQ_Y2_Histology_Scanned_QA26_023
# 30  MedArabiQ         BAREC_MedArabiQ_Y1_Cardiology_PDF_QA10_002
# 31  MedArabiQ         BAREC_MedArabiQ_Y1_Anatomy_Scanned_QA5_036
# 32  MedArabiQ   BAREC_MedArabiQ_Y2_Biochemistry_Scanned_QA11_012
# 33    Hindawi                         BAREC_Hindawi_59395164_001
# 34    Hindawi                         BAREC_Hindawi_38063631_001
# 35    Hindawi                         BAREC_Hindawi_31306851_001
# 36    Hindawi                         BAREC_Hindawi_63172484_001
# 37    Hindawi                         BAREC_Hindawi_20271796_001
# 38         UN  BAREC_UN_Universal Declaration of Human Rights...
# 39    Hindawi                         BAREC_Hindawi_46494205_001
# 40    Hindawi                         BAREC_Hindawi_71858151_001
# 41       Ofoq               BAREC_Ofoq_May_2023_أحمد_جابر_7_001
# 42       Ofoq    BAREC_Ofoq_April_2021_عبد_الإله_الديوهﭽي_6_001
# 43       Ofoq         BAREC_Ofoq_Aug_2020_رفيف_رضا_صيداوي_10_001
# 44     Kalima        BAREC_Kalima_الارض_واحلام_يقظة_الإرادة_001
# 45    Hindawi                         BAREC_Hindawi_46050209_001
# 46    Hindawi                         BAREC_Hindawi_64731631_001
# 47       Ofoq             BAREC_Ofoq_July_2023_نبيه_البرجي_3_001
# 48       Ofoq             BAREC_Ofoq_Feb_2019_محسن_التليلي_1_001
# 49    Hindawi                         BAREC_Hindawi_90306293_001
#
#     sampled_sentence_index               Source  \
# 0                        1              Hindawi
# 1                        1              Hindawi
# 2                        1              Hindawi
# 3                       35              Hindawi
# 4                        2              Hindawi
# 5                        9              Hindawi
# 6                       10              Hindawi
# 7                        1              Hindawi
# 8                        2              Hindawi
# 9                        9              Hindawi
# 10                       6              Hindawi
# 11                       1              Hindawi
# 12                      19              Hindawi
# 13                       1              Hindawi
# 14                       2              Hindawi
# 15                      16              Hindawi
# 16                      10              Hindawi
# 17                       1              Hindawi
# 18                       1              Hindawi
# 19                      76              Hindawi
# 20                       9              Hindawi
# 21                       1              Hindawi
# 22                       1              Hindawi
# 23                      36              Hindawi
# 24                       2              Hindawi
# 25                       1              Hindawi
# 26                       0            MedArabiQ
# 27                      15            MedArabiQ
# 28                      10            MedArabiQ
# 29                       9            MedArabiQ
# 30                       0            MedArabiQ
# 31                      15            MedArabiQ
# 32                       5            MedArabiQ
# 33                      35              Hindawi
# 34                       1              Hindawi
# 35                      29              Hindawi
# 36                       9              Hindawi
# 37                       1              Hindawi
# 38                      77  UN (United Nations)
# 39                       1              Hindawi
# 40                      21              Hindawi
# 41                      14                 Ofoq
# 42                       3                 Ofoq
# 43                       0                 Ofoq
# 44                      45               Kalima
# 45                       1              Hindawi
# 46                      12              Hindawi
# 47                      11                 Ofoq
# 48                       8                 Ofoq
# 49                      12              Hindawi
#
#                                                  Book  \
# 0                History of Theatre in the Arab World
# 1                             The Bell Voting Mystery
# 2                               Islam Without Borders
# 3   Translator’s Guide (to the Most Difficult Comm...
# 4                        History of Modern Philosophy
# 5                      The Story of Modern Philosophy
# 6                                     Dream of Reason
# 7                 Dialogues of Alfred North Whitehead
# 8   Wonders of Monuments in Biographies and News (...
# 9                              An Islamic Perspective
# 10               Studies on Poetry in the Ayyubid Era
# 11                                      Mental Storms
# 12                        History of Greek Philosophy
# 13                           Religious Existentialism
# 14                           Mind, Heart, and Courage
# 15                          History of Arabic Grammar
# 16                                       Almond Borer
# 17                                            Plastic
# 18                        Abu al-Eid with Seven Marks
# 19                        Science in Seconds for Kids
# 20                                I Am a Sardine Fish
# 21                         Knocking on Heaven’s Doors
# 22                                             Cancer
# 23                            Physics of Solar Energy
# 24                                   Animal Migration
# 25                              Six Impossible Things
# 26                                    Y1 - Physiology
# 27                                       Y1 - Anatomy
# 28                                 Y5 - Ophthalmology
# 29                                     Y2 - Histology
# 30                                    Y1 - Cardiology
# 31                                       Y1 - Anatomy
# 32                                  Y2 - Biochemistry
# 33                             End This Recession Now
# 34                                    Nuclear Weapons
# 35                        Where Are Our Clothes Made?
# 36                   365 Days Without “Made in China”
# 37                                   The Idea Machine
# 38              Universal Declaration of Human Rights
# 39                               Without Restrictions
# 9    Specialized Text      Academic                        48.090909
# 10   Specialized Text      Academic                        42.000000
# 11   Specialized Text      Academic                        24.900000
# 12   Specialized Text      Academic                        24.047619
# 13   Specialized Text      Academic                        19.592593
# 14   Specialized Text      Academic                        21.739130
# 15   Specialized Text      Academic                        20.958333
# 16  Foundational Text      Academic                        33.866667
# 17  Foundational Text      Academic                        26.842105
# 18  Foundational Text      Academic                        26.894737
# 19  Foundational Text      Academic                         6.740260
# 20  Foundational Text      Academic                        19.740741
# 21      Advanced Text      Academic                        24.000000
# 22      Advanced Text      Academic                        24.904762
# 23      Advanced Text      Academic                        12.725000
# 24      Advanced Text      Academic                        76.428571
# 25      Advanced Text      Academic                        19.692308
# 26   Specialized Text      Academic                        32.947368
# 27   Specialized Text      Academic                        27.565217
# 28   Specialized Text      Academic                        51.333333
# 29   Specialized Text      Academic                        44.571429
# 30   Specialized Text      Academic                        37.117647
# 31   Specialized Text      Academic                        26.739130
# 32   Specialized Text      Academic                        57.272727
# 33      Advanced Text      Academic                        22.084746
# 34      Advanced Text      Academic                        21.913043
# 35      Advanced Text      Academic                        15.484848
# 36      Advanced Text      Academic                        18.814815
# 37      Advanced Text      Academic                        24.583333
# 38      Advanced Text      Academic                        15.333333
# 39      Advanced Text      Academic                        24.904762
# 40   Specialized Text      Academic                        18.777778
# 41   Specialized Text      Academic                        33.150000
# 42   Specialized Text      Academic                        22.285714
# 43   Specialized Text      Academic                        30.850000
# 44   Specialized Text      Academic                        14.500000
# 45   Specialized Text      Academic                        22.909091
# 46   Specialized Text      Academic                        38.214286
# 47   Specialized Text      Academic                        36.411765
# 48   Specialized Text      Academic                        47.642857
# 49   Specialized Text      Academic                        36.071429
#
#                                     selected_sent_raw  \
# 0   الحديث عن تاريخ المسرح العربي، في القرن التاسع...
# 1   عندما وقع هذا الكتاب بين يدي، كان هدفي الأساسي...
# 2   لا بُدَّ منها لأني أخشى أن يتصور مَن يقتني هذا...
# 3   وهكذا فحين يبدأ المُترجِم كتابةَ نصه المُترجَم...
# 4   أديب كما يهواه الإنسانيون ورياضي وفيلسوف وصوفي...
# 5   انتقلت التجارة من البحر الأبيض إلى المحيط الأط...
# 6   ولا شك أن هذا يفيد القارئ في الإلمام بإنجازات ...
# 7   يزخر القرن الذي يقع بين عامَي ١٨٥٠م و١٩٥٠م بمج...
# 8   وخبر موت حسين بك المذكور أنه لما مات إبراهيم ك...
# 9   لكيلا يفلت منه زمام عقله أو تشرد الأهواء بقلبه...
# 10  ولعلنا لا نغالي إذا قلنا: إن هذا الضعف بدأ في ...
# 11  رخيصة هي الأفكار، إذا ما تشبَّعت بحرارة الطور ...
# 12  إذ أغار أهل تساليا على شمال اليونان فهاجر الأي...
# 13  إلى الإنجيليِّين الأقباط … والإخوة الأعزاء بال...
# 14  إننا نمتلك الآن المعرفة والأدوات اللازمة لتطوي...
# 15  لذلك لن أتجاهله، إنما سآخذه مأخذ الجد، وسأبحث ...
# 16  وبعد وصولها تبدأ بحفر الأنفاق مُؤدِّيةً إلى تد...
# 17  حيث نظرتم حولكم في زوايا غرفتكم، أو في حقيبة ك...
# 18  ما إن يأتي فصل الربيع بطَلَّته الجميلة، وتكتسي...
# 19  عندما يُطلَق صاروخ، فإنه يحتاج قوةً هائلة لرفع...
# 20  تُحلِّق فوقنا طيور النورس الجائعة بأعدادها الك...
# 21        تحيا البشرية الآن على أعتاب عصر الاكتشافات؛
# 22               السرطان مرض شائع، بل هو شديد الشيوع.
# 23  توضح الأرقام أن الاحتياطيات الإجمالية المُثبتة...
# 24  ومعظم الثدييات يعيش على الأرض يتجول عليها ويقت...
# 25  تتلخَّص غرابة عالَم الكَم فيما يُعرَف رسميًّا ...
# 26  كل مما يلي يحدث في آلية التنظيم الموضعي لضغط ا...
# 27  . الدوران الوحشي (أ) صدرية كبيرة (ب) تحت الكتف...
# 28  واحدة فقط مما يلي خاطئة: (أ) الجدار العلوي للح...
# 29  في المخيخ: (أ) الطبقة الجزيئية تتألف من عصبونا...
# 30  تختلف الخلايا ذاتية النظم عن الخلايا المتقلصة ...
# 31  الجزء العلوي للرحم فوق مدخل البوق (أ) القاع (ب...
# 32  كل مما يلي حول التهاب الكبد الفيروسي B صحيح ما...
# 33  بالفعل تخبرنا أبحاثُ السعادةِ أن المال لا يظلُ...
# 34  في عام ١٩٥١ أشرفت إدارة الدفاع المدني الفيدرال...
# 35       عيونٍ تَتطلع إلى مستقبل يتخطى حدود مُستقبلي؛
# 36  وَوَفَّرَ تشارلز ريتشارد وباربرا كلارك الدَّفع...
# 37  استخدِمْ هذه المساحة في تسجيل كلِّ الأفكار الت...
# 38      ويكون التعليمُ الفنِّي والمهني متاحًا للعموم.
# 39                      تمرُّ كل الحقائق بثلاث مراحل؛
# 40  وكان في وسط تلك البلدة حصن كبير يدعى حصن بابل،...
# 41  خارج القيد الطائفي"، فأضاف إلى مكتبة "التجديدي...
# 42  يُستخدم مُصطلح Algorithm هذه الأيّام ليعني "مج...
# 43  قراءة في "صباح الخامس والعشرين من شهر ديسمبر" ...
# 44  وبمجرد أن يكشف عن صورة اندفاعية، وبمجرد أن يُر...
# 45  فريد الدين العطار شاعر فارسي من أئمة شعراء الت...
# 46  أخذت المسألة الشرقية تظهر بشكل واضح إذن في الق...
# 47  لكنّ أردوغان الذي تمكّن، وبواسطة قواعده الشعبي...
# 48  ففي ظلّ العربيّة وحضنها القرآنيّ، نبغَ الفكر ا...
# 49  وهنا قد يرد بعض القراء: ولكنَّ هناك أزواجًا يخ...
#
#    selected_sent_word_count                                selected_sent_words
# 0                        20  [الحديث, عن, تاريخ, المسرح, العربي, ,, في, الق...
# 1                        27  [عندما, وقع, هذا, الكتاب, بين, يدي, ,, كان, هد...
# 2                        31  [لا, بد, منها, لأني, أخشى, أن, يتصور, من, يقتن...
# 3                        55  [وهكذا, فحين, يبدأ, المترجم, كتابة, نصه, المتر...
# 4                       132  [أديب, كما, يهواه, الإنسانيون, ورياضي, وفيلسوف...
# 5                        72  [انتقلت, التجارة, من, البحر, الأبيض, إلى, المح...
# 6                        35  [ولا, شك, أن, هذا, يفيد, القارئ, في, الإلمام, ...
# 7                        54  [يزخر, القرن, الذي, يقع, بين, عامي, ١٨٥٠م, و١٩...
# 8                        43  [وخبر, موت, حسين, بك, المذكور, أنه, لما, مات, ...
# 9                        79  [لكيلا, يفلت, منه, زمام, عقله, أو, تشرد, الأهو...
# 10                       39  [ولعلنا, لا, نغالي, إذا, قلنا, :, إن, هذا, الض...
# 11                       47  [رخيصة, هي, الأفكار, ,, إذا, ما, تشبعت, بحرارة...
# 12                       41  [إذ, أغار, أهل, تساليا, على, شمال, اليونان, فه...
# 13                       18  [إلى, الإنجيليين, الأقباط, ., ., ., والإخوة, ا...
# 14                       10  [إننا, نمتلك, الآن, المعرفة, والأدوات, اللازمة...
# 15                       14  [لذلك, لن, أتجاهله, ,, إنما, سآخذه, مأخذ, الجد...
# 16                       69  [وبعد, وصولها, تبدأ, بحفر, الأنفاق, مؤدية, إلى...
# 17                       46  [حيث, نظرتم, حولكم, في, زوايا, غرفتكم, ,, أو, ...
# 18                       93  [ما, إن, يأتي, فصل, الربيع, بطلته, الجميلة, ,,...
# 19                       36  [عندما, يطلق, صاروخ, ,, فإنه, يحتاج, قوة, هائل...
# 20                       13  [تحلق, فوقنا, طيور, النورس, الجائعة, بأعدادها,...
# 21                        8  [تحيا, البشرية, الآن, على, أعتاب, عصر, الاكتشا...
# 22                        9   [السرطان, مرض, شائع, ,, بل, هو, شديد, الشيوع, .]
# 23                       24  [توضح, الأرقام, أن, الاحتياطيات, الإجمالية, ال...
# 24                       55  [ومعظم, الثدييات, يعيش, على, الأرض, يتجول, علي...
# 25                       14  [تتلخص, غرابة, عالم, الكم, فيما, يعرف, رسميا, ...
# 26                       49  [كل, مما, يلي, يحدث, في, آلية, التنظيم, الموضع...
# 27                       23  [., الدوران, الوحشي, (, أ, ), صدرية, كبيرة, (,...
# 28                       73  [واحدة, فقط, مما, يلي, خاطئة, :, (, أ, ), الجد...
# 29                       51  [في, المخيخ, :, (, أ, ), الطبقة, الجزيئية, تتأ...
# 30                       43  [تختلف, الخلايا, ذاتية, النظم, عن, الخلايا, ال...
# 31                       22  [الجزء, العلوي, للرحم, فوق, مدخل, البوق, (, أ,...
# 32                       64  [كل, مما, يلي, حول, التهاب, الكبد, الفيروسي, B...
# 33                       22  [بالفعل, تخبرنا, أبحاث, السعادة, أن, المال, لا...
# 34                       28  [في, عام, ١٩٥١, أشرفت, إدارة, الدفاع, المدني, ...
# 35                        8  [عيون, تتطلع, إلى, مستقبل, يتخطى, حدود, مستقبل...
# 36                       10  [ووفر, تشارلز, ريتشارد, وباربرا, كلارك, الدفعة...
# 37                       16  [استخدم, هذه, المساحة, في, تسجيل, كل, الأفكار,...
# 38                        7  [ويكون, التعليم, الفني, والمهني, متاحا, للعموم...
# 39                        6                [تمر, كل, الحقائق, بثلاث, مراحل, ؛]
# 40                       76  [وكان, في, وسط, تلك, البلدة, حصن, كبير, يدعى, ...
# 41                       93  [خارج, القيد, الطائفي, ", ,, فأضاف, إلى, مكتبة...
# 42                       22  [يستخدم, مصطلح, Algorithm, هذه, الأيام, ليعني,...
# 43                       12  [قراءة, في, ", صباح, الخامس, والعشرين, من, شهر...
# 44                       23  [وبمجرد, أن, يكشف, عن, صورة, اندفاعية, ,, وبمج...
# 45                       41  [فريد, الدين, العطار, شاعر, فارسي, من, أئمة, ش...
# 46                       65  [أخذت, المسألة, الشرقية, تظهر, بشكل, واضح, إذن...
# 47                       43  [لكن, أردوغان, الذي, تمكن, ,, وبواسطة, قواعده,...
# 48                       42  [ففي, ظل, العربية, وحضنها, القرآني, ,, نبغ, ال...
# 49                       36  [وهنا, قد, يرد, بعض, القراء, :, ولكن, هناك, أز...

# %%
# D_df.to_json('sampled_AC_sentences.json', orient='records', force_ascii=False, indent=4)

# %%
metadata['Text Category'].value_counts()
# Out:
# Text Category
# Media & Culture                                  7122
# Educational Materials; Language & Linguistics    4709
# Academic                                         4301
# Literature; Art & Music                          3974
# Religion & Philosophy                             254
# Encyclopedic                                      175
# Name: count, dtype: int64

# %%
RP_df = metadata[metadata['Text Category']=='Religion & Philosophy']
print("Religion & Philosophy")
print("==========================")
print(f"Number of documents: {RP_df.shape[0]}")
print("--------------------------")
print(f"Number of sentences: {RP_df['Sentence Count'].sum()}")
print("--------------------------")
print(f"Number of unique books: {RP_df['Book'].nunique()}")
print("--------------------------")
print(f"Number of unique authors: {RP_df['Author'].nunique()}")
print("--------------------------")
print(f"Domain distribution:\n{RP_df['Domain'].value_counts().to_dict()}")
print("--------------------------")
print(f"Readership Group distribution:\n{RP_df['Readership Group'].value_counts().to_dict()}")
print("--------------------------")
print(f"Average sentence length distribution:\n{RP_df['average sentence length'].describe().to_dict()}")
print("==========================")
# Out:
# Religion & Philosophy
# ==========================
# Number of documents: 254
# --------------------------
# Number of sentences: 4278
# --------------------------
# Number of unique books: 49
# --------------------------
# Number of unique authors: 10
# --------------------------
# Domain distribution:
# {'Arts & Humanities': 254}
# --------------------------
# Readership Group distribution:
# {'Specialized Text': 254}
# --------------------------
# Average sentence length distribution:
# {'count': 254.0, 'mean': 15.191069257160054, 'std': 7.0941729109666545, 'min': 6.2727272727272725, '25%': 10.0, '50%': 13.89247311827957, '75%': 18.065217391304348, 'max': 43.5}
# ==========================

# %%
sampled_RP_df = RP_df.sample(50, random_state=42)

# %%
sampled_RP_df.shape
# Out:
# (50, 12)

# %%
sampled_RP_sentences_indices = []
for i, row in sampled_RP_df.iterrows():
    directory = row['Directory']
    document = row['Document']
    annotations_file_path = f"BAREC-10M/Data/Morphology_and_Readability/{directory}/{document}.json"

    with open(annotations_file_path, 'r', encoding='utf-8') as f:
        annotations = json.load(f)
        annotations = pd.DataFrame(annotations)
    

    sampled_index = annotations[annotations['sents_word_count'] > 5].sample(1, random_state=42).index.item()
    sampled_RP_sentences_indices.append(sampled_index)
print(sampled_RP_sentences_indices)
# Out:
# [29, 5, 1, 1, 38, 1, 1, 1, 0, 1, 10, 7, 0, 9, 50, 9, 1, 1, 0, 1, 0, 2, 2, 64, 0, 8, 5, 7, 1, 26, 9, 13, 13, 0, 11, 1, 2, 2, 2, 65, 30, 16, 10, 30, 2, 1, 0, 3, 1, 2]

# %%
sampled_RP_df['sampled_sentence_index'] = sampled_RP_sentences_indices

# %%
E_df = sampled_RP_df.copy()
E_df
# Out:
#                               Document Directory            Source  \
# 18588           BAREC_OT_Genesis_1_001        OT     Old Testament
# 12343             BAREC_Hadith_1_7_001    Hadith            Hadith
# 12416             BAREC_Hadith_3_2_001    Hadith            Hadith
# 19477      BAREC_Quran_106_Quraysh_001     Quran             Quran
# 12454            BAREC_Hadith_3_64_001    Hadith            Hadith
# 18583          BAREC_OT_Genesis_15_001        OT     Old Testament
# 19473  BAREC_Quran_102_Al-Takathur_001     Quran             Quran
# 18565          BAREC_NT_Matthew_13_001        NT     New Testament
# 12346            BAREC_Hadith_2_12_001    Hadith            Hadith
# 12367            BAREC_Hadith_2_31_001    Hadith            Hadith
# 18578          BAREC_OT_Genesis_10_001        OT     Old Testament
# 12362  Religion & Philosophy          67               4              Yes
# 12423  Religion & Philosophy          44               5               No
# 12355  Religion & Philosophy         129              10              Yes
# 12412  Religion & Philosophy          52               6               No
# 12474  Religion & Philosophy        1064              67              Yes
# 18593  Religion & Philosophy         439              33              Yes
# 18574  Religion & Philosophy         629              35              Yes
# 19509  Religion & Philosophy         213              12               No
# 18579  Religion & Philosophy         485              33              Yes
# 12382  Religion & Philosophy          92              10              Yes
# 12403  Religion & Philosophy          72               7               No
# 12353  Religion & Philosophy          67               6              Yes
# 12404  Religion & Philosophy          46               4               No
# 19478  Religion & Philosophy          46               7              Yes
# 19472  Religion & Philosophy          69              11              Yes
#
#        average sentence length  sampled_sentence_index
# 18588                17.515152                      29
# 12343                 9.313131                       5
# 12416                 9.000000                       1
# 19477                 7.250000                       1
# 12454                 8.642857                      38
# 18583                16.090909                       1
# 19473                 6.500000                       1
# 18565                16.949153                       1
# 12346                28.500000                       0
# 12367                10.750000                       1
# 18578                10.909091                      10
# 19492                41.888889                       7
# 19500                16.904762                       0
# 19488                26.428571                       9
# 12473                13.951613                      50
# 12405                 8.000000                       9
# 18596                18.086957                       1
# 12352                12.833333                       1
# 12433                10.000000                       0
# 12361                10.000000                       1
# 19505                21.176471                       0
# 12356                16.000000                       2
# 12457                 9.153846                       2
# 12489                16.257576                      64
# 12370                15.000000                       0
# 12461                11.300000                       8
# 19523                20.181818                       5
# 19514                23.888889                       7
# 12347                 9.428571                       1
# 18562                15.790698                      26
# 18582                18.520000                       9
# 12434                10.666667                      13
# 12485                18.000000                      13
# 19481                 9.333333                       0
# 19493                27.461538                      11
# 12362                16.750000                       1
# 12423                 8.800000                       2
# 12355                12.900000                       2
# 12412                 8.666667                       2
# 12474                15.880597                      65
# 18593                13.303030                      30
# 18574                17.971429                      16
# 19509                17.750000                      10
# 18579                14.696970                      30
# 12382                 9.200000                       2
# 12403                10.285714                       1
# 12353                11.166667                       0
# 12404                11.500000                       3
# 19478                 6.571429                       1
# 19472                 6.272727                       2

# %%
E_df['selected_sent_raw'] = None
E_df['selected_sent_word_count'] = None
E_df['selected_sent_words'] = None

for i, row in E_df.iterrows():
    directory = row['Directory']
    document = row['Document']

    annotations_file_path = (
        f"BAREC-10M/Data/Morphology_and_Readability/"
        f"{directory}/{document}.json"
    )

    with open(annotations_file_path, 'r', encoding='utf-8') as f:
        annotations = json.load(f)

    annotations = pd.DataFrame(annotations)

    selected_sentence_index = int(row['sampled_sentence_index'])

    selected_row = annotations.iloc[selected_sentence_index]

    raw_sentence = selected_row['raw_sents']
    word_count = selected_row['sents_word_count']
    words = selected_row['word']   # list of strings

    E_df.at[i, 'selected_sent_raw'] = raw_sentence
    E_df.at[i, 'selected_sent_word_count'] = word_count
    E_df.at[i, 'selected_sent_words'] = words

# %%
E_df = E_df[[
    'Directory',
    'Document',
    'sampled_sentence_index',
    'Source',
    'Book',
    'Author',
    'Domain',
    'Readership Group',
    'Text Category',
    'average sentence length',
    'selected_sent_raw',
    'selected_sent_word_count',
    'selected_sent_words'
]]

# %%
E_df.rename(columns={
    'average sentence length': 'average_sentence_length_per_doc',
}, inplace=True)

# %%
E_df
# Out:
#       Directory                         Document  sampled_sentence_index  \
# 18588        OT           BAREC_OT_Genesis_1_001                      29
# 12343    Hadith             BAREC_Hadith_1_7_001                       5
# 12416    Hadith             BAREC_Hadith_3_2_001                       1
# 19477     Quran      BAREC_Quran_106_Quraysh_001                       1
# 12454    Hadith            BAREC_Hadith_3_64_001                      38
# 18583        OT          BAREC_OT_Genesis_15_001                       1
# 19473     Quran  BAREC_Quran_102_Al-Takathur_001                       1
# 18565        NT          BAREC_NT_Matthew_13_001                       1
# 12346    Hadith            BAREC_Hadith_2_12_001                       0
# 12367    Hadith            BAREC_Hadith_2_31_001                       1
# 18578        OT          BAREC_OT_Genesis_10_001                      10
# 19492     Quran   BAREC_Quran_2_Al-Baqara_15_001                       7
# 19500     Quran    BAREC_Quran_2_Al-Baqara_3_001                       0
# 19488     Quran   BAREC_Quran_2_Al-Baqara_11_001                       9
# 12473      Hayy                BAREC_Hayy_03_001                      50
# 12405    Hadith             BAREC_Hadith_3_1_001                       9
# 18596        OT           BAREC_OT_Genesis_8_001                       1
# 12352    Hadith            BAREC_Hadith_2_18_001                       1
# 12433    Hadith            BAREC_Hadith_3_45_001                       0
# 12361    Hadith            BAREC_Hadith_2_26_001                       1
# 19505     Quran    BAREC_Quran_2_Al-Baqara_8_001                       0
# 12356    Hadith            BAREC_Hadith_2_21_001                       2
# 12457    Hadith            BAREC_Hadith_3_67_001                       2
# 12489      Hayy                BAREC_Hayy_19_001                      64
# 12370    Hadith            BAREC_Hadith_2_34_001                       0
# 12461    Hadith            BAREC_Hadith_3_70_001                       8
# 19523     Quran    BAREC_Quran_3_Aal_Imran_7_001                       5
# 19514     Quran   BAREC_Quran_3_Aal_Imran_17_001                       7
# 12347    Hadith            BAREC_Hadith_2_13_001                       1
# 18562        NT          BAREC_NT_Matthew_10_001                      26
# 18582        OT          BAREC_OT_Genesis_14_001                       9
# 12434    Hadith            BAREC_Hadith_3_46_001                      13
# 12485      Hayy                BAREC_Hayy_15_001                      13
# 19481     Quran      BAREC_Quran_110_Al-Nasr_001                       0
# 19493     Quran   BAREC_Quran_2_Al-Baqara_16_001                      11
# 12362    Hadith            BAREC_Hadith_2_27_001                       1
# 12423    Hadith            BAREC_Hadith_3_36_001                       2
# 12355    Hadith            BAREC_Hadith_2_20_001                       2
# 12412    Hadith            BAREC_Hadith_3_26_001                       2
# 12474      Hayy                BAREC_Hayy_04_001                      65
# 18593        OT           BAREC_OT_Genesis_5_001                      30
# 18574        NT           BAREC_NT_Matthew_6_001                      16
# 19509     Quran   BAREC_Quran_3_Aal_Imran_12_001                      10
# 18579        OT          BAREC_OT_Genesis_11_001                      30
# 12382    Hadith            BAREC_Hadith_2_45_001                       2
# 12403    Hadith            BAREC_Hadith_3_18_001                       1
# 12353    Hadith            BAREC_Hadith_2_19_001                       0
# 12404    Hadith            BAREC_Hadith_3_19_001                       3
# 19478     Quran    BAREC_Quran_107_Al-Maaoun_001                       1
# 19472     Quran     BAREC_Quran_101_Al-Qaria_001                       2
#
#                  Source               Book      Author             Domain  \
# 18588     Old Testament          Chapter 1           #  Arts & Humanities
# 12343            Hadith      Sahih Bukhari           #  Arts & Humanities
# 
# 12454  فَجَاءَ عُصْفُورٌ فَوَقَعَ عَلَى حَرْفِ السَّف...
# 18583  1 بَعْدَ هذِهِ الأُمُورِ صَارَ كَلاَمُ الرَّبِ...
# 19473                   حَتَّى زُرْتُمُ الْمَقَابِرَ (2)
# 18565  1 فِي ذلِكَ الْيَوْمِ خَرَجَ يَسُوعُ مِنَ الْب...
# 12346  حَدَّثَنَا عَبْدُ اللَّهِ بْنُ مَسْلَمَةَ ، عَ...
# 12367        قَالَ أَخْبَرَنَا مُحَمَّدُ بْنُ فُضَيْلٍ ،
# 18578  10 وَكَانَ ابْتِدَاءُ مَمْلَكَتِهِ بَابِلَ وَأ...
# 19492  لَا جُنَاحَ عَلَيْكُمْ إِنْ طَلَّقْتُمُ النِّس...
# 19500  يَا بَنِي إِسْرَائِيلَ اذْكُرُوا نِعْمَتِيَ ال...
# 19488  فَمَنْ بَدَّلَهُ بَعْدَمَا سَمِعَهُ فَإِنَّمَا...
# 12473     فإنها لم تفارقه ولا فارقها إلى أن أسنَّت وضعفت
# 12405  فَقَالَ بَعْضُ الْقَوْمِ سَمِعَ مَا قَالَ ، فَ...
# 18596  1 ثُمَّ ذَكَرَ اللهُ نُوحًا وَكُلَّ الْوُحُوشِ...
# 12352  قَالَ حَدَّثَنَا أَبُو رَوْحٍ الْحَرَمِيُّ بْن...
# 12433           حَدَّثَنَا سَعِيدُ بْنُ أَبِي مَرْيَمَ ،
# 12361      قَالَ حَدَّثَنَا إِسْمَاعِيلُ بْنُ جَعْفَرٍ ،
# 19505  يَا بَنِي إِسْرَائِيلَ اذْكُرُوا نِعْمَتِيَ ال...
# 12356  قَالَ تُطْعِمُ الطَّعَامَ ، وَتَقْرَأُ السَّلا...
# 12457  قَالَ حَدَّثَنَا الأَعْمَشُ ، سُلَيْمَانُ عَنْ...
# 12489  وكان رأس تلك الجزيرة وكبيرها سلامان، وهو صاحب ...
# 12370  قَالَ مَالِكٌ أَخْبَرَنِي زَيْدُ بْنُ أَسْلَمَ...
# 12461  قَالَ يَا رَسُولَ اللَّهِ ، أَفَلاَ أُخْبِرُ ب...
# 19523  يَا أَهْلَ الْكِتَابِ لِمَ تَكْفُرُونَ بِآيَات...
# 19514  الَّذِينَ قَالُوا إِنَّ اللَّهَ عَهِدَ إِلَيْن...
# 12347  قَالَ أَخْبَرَنَا عَبْدَةُ ، عَنْ هِشَامٍ ، عَ...
# 18562  26 فَلاَ تَخَافُوهُمْ. لأَنْ لَيْسَ مَكْتُومٌ ...
# 18582  9 مَعَ كَدَرْلَعَوْمَرَ مَلِكِ عِيلاَمَ، وَتِد...
# 12434   قَالَ أَنَا أَعْلَمُ مِنْكَ يَا أَبَا شُرَيْحٍ ،
# 12485  وأما الضرب الثالث: فكان تشبهه بها فيه أن كان ي...
# 19481         إِذَا جَاءَ نَصْرُ اللَّهِ وَالْفَتْحُ (1)
# 19493  فَلَمَّا فَصَلَ طَالُوتُ بِالْجُنُودِ قَالَ إِ...
# 12362  قَالَ حَدَّثَنَا سُفْيَانُ ، عَنِ الأَعْمَشِ ،...
# 12423  قَالَ حَدَّثَنَا عَبْدُ اللَّهِ بْنُ الْمُثَنّ...
# 12355  قَالَ أَخْبَرَنِي عَامِرُ بْنُ سَعْدِ بْنِ أَب...
# 12412  قَالَ حَدَّثَنَا أَيُّوبُ ، عَنْ عِكْرِمَةَ ، ...
# 12474       وتشتَّت فكره في ذلك كله وسلا عن الجسد وطرحه.
# 18593  30 وَعَاشَ لاَمَكُ بَعْدَ مَا وَلَدَ نُوحًا خَ...
# 18574  16 «وَمَتَى صُمْتُمْ فَلاَ تَكُونُوا عَابِسِين...
# 19509  وَلِلَّهِ مَا فِي السَّمَاوَاتِ وَمَا فِي الْأ...
# 18579  30 وَكَانَتْ سَارَايُ عَاقِرًا لَيْسَ لَهَا وَ...
# 12382  قَالَ سَمِعْتُ النُّعْمَانَ بْنَ بَشِيرٍ ، يَق...
# 12403  قَالَ حَدَّثَنِي مَالِكٌ ، عَنِ ابْنِ شِهَابٍ ...
# 12353  حَدَّثَنَا أَحْمَدُ بْنُ يُونُسَ ، وَمُوسَى بْ...
# 12404  قَالَ عَقَلْتُ مِنَ النَّبِيِّ صلى الله عليه و...
# 19478            فَذَلِكَ الَّذِي يَدُعُّ الْيَتِيمَ (2)
# 19472               وَمَا أَدْرَاكَ مَا الْقَارِعَةُ (3)
#
#       selected_sent_word_count  \
# 18588                       29
# 12343                       10
# 12416                       20
# 19477                        7
# 12454                        7
# 18583                       28
# 19473                        6
# 18565                       12
# 12346                       53
# 12367                        6
# 18578                       13
# 19492                       28
# 19500                       17
# 19488                       16
# 12473                        9
# 12405                       11
# 18596                       22
# 12352                        8
# 12433                        6
# 12361                        6
# 19505                       15
# 12356                       12
# 12457                       15
# 12489                       19
# 12370                       41
# 12461                       16
# 19523                       12
# 19514                       31
# 12347                       13
# 18562                       15
# 18582                       23
# 12434                        8
# 12485                       22
# 19481                        8
# 19493                       63
# 12362                       37
# 12423                        7
# 12355                       27
# 12412                       26
# 12474                       10
# 18593                       17
# 18574                       26
# 19509                       19
# 18579                        8
# 12382                       20
# 12403                       23
# 12353                        9
# 12404                       19
# 19478                        7
# 19472                        7
#
#                                      selected_sent_words
# 18588  [28, وباركهم, الله, وقال, لهم, :, ", أثمروا, و...
# 12343  [فقال, أيكم, أقرب, نسبا, بهذا, الرجل, الذي, يز...
# 12416  [قال, حدثنا, أبو, عوانة, ,, عن, أبي, بشر, ,, ع...
# 19477           [إيلافهم, رحلة, الشتاء, والصيف, (, 2, )]
# 12454          [فجاء, عصفور, فوقع, على, حرف, السفينة, ,]
# 18583  [1, بعد, هذه, الأمور, صار, كلام, الرب, إلى, أب...
# 19473                      [حتى, زرتم, المقابر, (, 2, )]
# 18565  [1, في, ذلك, اليوم, خرج, يسوع, من, البيت, وجلس...
# 12346  [حدثنا, عبد, الله, بن, مسلمة, ,, عن, مالك, ,, ...
# 12367                   [قال, أخبرنا, محمد, بن, فضيل, ,]
# 18578  [10, وكان, ابتداء, مملكته, بابل, وأرك, وأكد, و...
# 19492  [لا, جناح, عليكم, إن, طلقتم, النساء, ما, لم, ت...
# %%
# E_df.to_json('sampled_RP_sentences.json', orient='records', force_ascii=False, indent=4)

# %%
metadata['Text Category'].value_counts()
# Out:
# Text Category
# Media & Culture                                  7122
# Educational Materials; Language & Linguistics    4709
# Academic                                         4301
# Literature; Art & Music                          3974
# Religion & Philosophy                             254
# Encyclopedic                                      175
# Name: count, dtype: int64

# %%
EN_df = metadata[metadata['Text Category']=='Encyclopedic']
print("Encyclopedic")
print("==========================")
print(f"Number of documents: {EN_df.shape[0]}")
print("--------------------------")
print(f"Number of sentences: {EN_df['Sentence Count'].sum()}")
print("--------------------------")
print(f"Number of unique books: {EN_df['Book'].nunique()}")
print("--------------------------")
print(f"Number of unique authors: {EN_df['Author'].nunique()}")
print("--------------------------")
print(f"Domain distribution:\n{EN_df['Domain'].value_counts().to_dict()}")
print("--------------------------")
print(f"Readership Group distribution:\n{EN_df['Readership Group'].value_counts().to_dict()}")
print("--------------------------")
print(f"Average sentence length distribution:\n{EN_df['average sentence length'].describe().to_dict()}")
print("==========================")
# Out:
# Encyclopedic
# ==========================
# Number of documents: 175
# --------------------------
# Number of sentences: 5749
# --------------------------
# Number of unique books: 175
# --------------------------
# Number of unique authors: 1
# --------------------------
# Domain distribution:
# {'Social Sciences': 90, 'Arts & Humanities': 48, 'STEM': 37}
# --------------------------
# Readership Group distribution:
# {'Advanced Text': 175}
# --------------------------
# Average sentence length distribution:
# {'count': 175.0, 'mean': 22.279801555703763, 'std': 3.686049565777941, 'min': 11.491228070175438, '25%': 19.79873949579832, '50%': 21.8125, '75%': 24.34188034188034, 'max': 36.904761904761905}
# ==========================

# %%
EN_AH_df = EN_df[EN_df['Domain']=='Arts & Humanities']
print("Encyclopedic - Arts & Humanities")
print("==========================")
print(f"Number of documents: {EN_AH_df.shape[0]}")
print("--------------------------")
print(f"Number of sentences: {EN_AH_df['Sentence Count'].sum()}")
print("--------------------------")
print(f"Number of unique books: {EN_AH_df['Book'].nunique()}")
print("--------------------------")
print(f"Number of unique authors: {EN_AH_df['Author'].nunique()}")
print("--------------------------")
print(f"Domain distribution:\n{EN_AH_df['Domain'].value_counts().to_dict()}")
print("--------------------------")
print(f"Readership Group distribution:\n{EN_AH_df['Readership Group'].value_counts().to_dict()}")
print("--------------------------")
print(f"Average sentence length distribution:\n{EN_AH_df['average sentence length'].describe().to_dict()}")
print("==========================")
# Out:
# Encyclopedic - Arts & Humanities
# ==========================
# Number of documents: 48
# --------------------------
# Number of sentences: 1674
# --------------------------
# Number of unique books: 48
# --------------------------
# Number of unique authors: 1
# --------------------------
# Domain distribution:
# {'Arts & Humanities': 48}
# --------------------------
# Readership Group distribution:
# {'Advanced Text': 48}
# --------------------------
# Average sentence length distribution:
# {'count': 48.0, 'mean': 21.893738189027854, 'std': 3.8578502565209836, 'min': 11.491228070175438, '25%': 19.16559829059829, '50%': 21.563541666666666, '75%': 24.717741935483872, 'max': 33.12903225806452}
# ==========================

# %%
sampled_EN_AH_advanced_df = EN_AH_df.sample(17, random_state=42)

# %%
sampled_EN_AH_df = sampled_EN_AH_advanced_df.copy()

# %%
sampled_EN_AH_sentences_indices = []
for i, row in sampled_EN_AH_df.iterrows():
    directory = row['Directory']
    document = row['Document']
    annotations_file_path = f"BAREC-10M/Data/Morphology_and_Readability/{directory}/{document}.json"

    with open(annotations_file_path, 'r', encoding='utf-8') as f:
        annotations = json.load(f)
        annotations = pd.DataFrame(annotations)
    

    sampled_index = annotations[annotations['sents_word_count'] > 5].sample(1, random_state=42).index.item()
    sampled_EN_AH_sentences_indices.append(sampled_index)
print(sampled_EN_AH_sentences_indices)
# Out:
# [27, 0, 18, 16, 28, 29, 26, 8, 29, 23, 27, 9, 9, 9, 27, 33, 27]

# %%
sampled_EN_AH_df['sampled_sentence_index'] = sampled_EN_AH_sentences_indices

# %%
EN_ST_df = EN_df[EN_df['Domain']=='STEM']
print("Encyclopedic - STEM")
print("==========================")
print(f"Number of documents: {EN_ST_df.shape[0]}")
print("--------------------------")
print(f"Number of sentences: {EN_ST_df['Sentence Count'].sum()}")
print("--------------------------")
print(f"Number of unique books: {EN_ST_df['Book'].nunique()}")
print("--------------------------")
print(f"Number of unique authors: {EN_ST_df['Author'].nunique()}")
print("--------------------------")
print(f"Domain distribution:\n{EN_ST_df['Domain'].value_counts().to_dict()}")
print("--------------------------")
print(f"Readership Group distribution:\n{EN_ST_df['Readership Group'].value_counts().to_dict()}")
print("--------------------------")
print(f"Average sentence length distribution:\n{EN_ST_df['average sentence length'].describe().to_dict()}")
print("==========================")
# Out:
# Encyclopedic - STEM
# ==========================
# Number of documents: 37
# --------------------------
# Number of sentences: 1207
# --------------------------
# Number of unique books: 37
# --------------------------
# Number of unique authors: 1
# --------------------------
# Domain distribution:
# {'STEM': 37}
# --------------------------
# Readership Group distribution:
# {'Advanced Text': 37}
# --------------------------
# Average sentence length distribution:
# {'count': 37.0, 'mean': 21.50345219510831, 'std': 3.586902951861836, 'min': 11.76923076923077, '25%': 18.72222222222222, '50%': 21.7, '75%': 23.25, 'max': 30.291666666666668}
# ==========================

# %%
sampled_EN_ST_advanced_df = EN_ST_df.sample(16, random_state=42)

# %%
sampled_EN_ST_df = sampled_EN_ST_advanced_df.copy()

# %%
sampled_EN_ST_sentences_indices = []
for i, row in sampled_EN_ST_df.iterrows():
    directory = row['Directory']
    document = row['Document']
    annotations_file_path = f"BAREC-10M/Data/Morphology_and_Readability/{directory}/{document}.json"

    with open(annotations_file_path, 'r', encoding='utf-8') as f:
        annotations = json.load(f)
        annotations = pd.DataFrame(annotations)
    

    sampled_index = annotations[annotations['sents_word_count'] > 5].sample(1, random_state=42).index.item()
    sampled_EN_ST_sentences_indices.append(sampled_index)
print(sampled_EN_ST_sentences_indices)
# Out:
# [9, 33, 34, 29, 9, 28, 8, 15, 8, 9, 27, 8, 8, 8, 27, 8]

# %%
sampled_EN_ST_df['sampled_sentence_index'] = sampled_EN_ST_sentences_indices

# %%
EN_SS_df = EN_df[EN_df['Domain']=='Social Sciences']
print("Encyclopedic - Social Sciences")
print("==========================")
print(f"Number of documents: {EN_SS_df.shape[0]}")
print("--------------------------")
print(f"Number of sentences: {EN_SS_df['Sentence Count'].sum()}")
print("--------------------------")
print(f"Number of unique books: {EN_SS_df['Book'].nunique()}")
print("--------------------------")
print(f"Number of unique authors: {EN_SS_df['Author'].nunique()}")
print("--------------------------")
print(f"Domain distribution:\n{EN_SS_df['Domain'].value_counts().to_dict()}")
print("--------------------------")
print(f"Readership Group distribution:\n{EN_SS_df['Readership Group'].value_counts().to_dict()}")
print("--------------------------")
print(f"Average sentence length distribution:\n{EN_SS_df['average sentence length'].describe().to_dict()}")
print("==========================")
# Out:
# Encyclopedic - Social Sciences
# ==========================
# Number of documents: 90
# --------------------------
# Number of sentences: 2868
# --------------------------
# Number of unique books: 90
# --------------------------
# Number of unique authors: 1
# --------------------------
# Domain distribution:
# {'Social Sciences': 90}
# --------------------------
# Readership Group distribution:
# {'Advanced Text': 90}
# --------------------------
# Average sentence length distribution:
# {'count': 90.0, 'mean': 22.804867866175705, 'std': 3.590235208744769, 'min': 15.5, '25%': 20.44017595307918, '50%': 22.192028985507246, '75%': 24.75607142857143, 'max': 36.904761904761905}
# ==========================

# %%
sampled_EN_SS_advanced_df = EN_SS_df.sample(17, random_state=42)

# %%
sampled_EN_SS_df = sampled_EN_SS_advanced_df.copy()
sampled_EN_SS_df.shape
# Out:
# (17, 12)

# %%
sampled_EN_SS_sentences_indices = []
for i, row in sampled_EN_SS_df.iterrows():
    directory = row['Directory']
    document = row['Document']
    annotations_file_path = f"BAREC-10M/Data/Morphology_and_Readability/{directory}/{document}.json"

    with open(annotations_file_path, 'r', encoding='utf-8') as f:
        annotations = json.load(f)
        annotations = pd.DataFrame(annotations)
    

    sampled_index = annotations[annotations['sents_word_count'] > 5].sample(1, random_state=42).index.item()
    sampled_EN_SS_sentences_indices.append(sampled_index)
print(sampled_EN_SS_sentences_indices)
# Out:
# [8, 15, 17, 29, 28, 26, 8, 9, 8, 9, 27, 8, 36, 36, 0, 15, 9]

# %%
sampled_EN_SS_df['sampled_sentence_index'] = sampled_EN_SS_sentences_indices

# %%
F_df = pd.concat([sampled_EN_AH_df, sampled_EN_ST_df, sampled_EN_SS_df], ignore_index=True)
F_df
# Out:
#                                              Document  Directory     Source  \
# 0                     BAREC_Wikipedia_أنغكور_وات_001  Wikipedia  Wikipedia
# 1                 BAREC_Wikipedia_ضريح_سليمان_شاه_001  Wikipedia  Wikipedia
# 2             BAREC_Wikipedia_أليساندرو_دل_بييرو_001  Wikipedia  Wikipedia
# 3                   BAREC_Wikipedia_عمارة_بنائية_001  Wikipedia  Wikipedia
# 4                    BAREC_Wikipedia_ألسنة_اللهب_001  Wikipedia  Wikipedia
# 7   Arts & Humanities    Advanced Text  Encyclopedic         709
# 8   Arts & Humanities    Advanced Text  Encyclopedic         589
# 9   Arts & Humanities    Advanced Text  Encyclopedic         924
# 10  Arts & Humanities    Advanced Text  Encyclopedic         689
# 11  Arts & Humanities    Advanced Text  Encyclopedic         637
# 12  Arts & Humanities    Advanced Text  Encyclopedic         809
# 13  Arts & Humanities    Advanced Text  Encyclopedic         729
# 14  Arts & Humanities    Advanced Text  Encyclopedic         800
# 15  Arts & Humanities    Advanced Text  Encyclopedic         842
# 16  Arts & Humanities    Advanced Text  Encyclopedic         767
# 17               STEM    Advanced Text  Encyclopedic         627
# 18               STEM    Advanced Text  Encyclopedic         881
# 19               STEM    Advanced Text  Encyclopedic         868
# 20               STEM    Advanced Text  Encyclopedic         605
# 21               STEM    Advanced Text  Encyclopedic         651
# 22               STEM    Advanced Text  Encyclopedic         676
# 23               STEM    Advanced Text  Encyclopedic         693
# 24               STEM    Advanced Text  Encyclopedic         676
# 25               STEM    Advanced Text  Encyclopedic         471
# 26               STEM    Advanced Text  Encyclopedic         344
# 27               STEM    Advanced Text  Encyclopedic         734
# 28               STEM    Advanced Text  Encyclopedic         727
# 29               STEM    Advanced Text  Encyclopedic         657
# 30               STEM    Advanced Text  Encyclopedic         654
# 31               STEM    Advanced Text  Encyclopedic         734
# 32               STEM    Advanced Text  Encyclopedic         586
# 33    Social Sciences    Advanced Text  Encyclopedic         563
# 34    Social Sciences    Advanced Text  Encyclopedic         599
# 35    Social Sciences    Advanced Text  Encyclopedic         796
# 36    Social Sciences    Advanced Text  Encyclopedic         687
# 37    Social Sciences    Advanced Text  Encyclopedic         641
# 38    Social Sciences    Advanced Text  Encyclopedic         794
# 39    Social Sciences    Advanced Text  Encyclopedic         607
# 40    Social Sciences    Advanced Text  Encyclopedic         636
# 41    Social Sciences    Advanced Text  Encyclopedic         695
# 42    Social Sciences    Advanced Text  Encyclopedic         576
# 43    Social Sciences    Advanced Text  Encyclopedic         699
# 44    Social Sciences    Advanced Text  Encyclopedic         763
# 45    Social Sciences    Advanced Text  Encyclopedic         888
# 46    Social Sciences    Advanced Text  Encyclopedic         715
# 47    Social Sciences    Advanced Text  Encyclopedic         775
# 48    Social Sciences    Advanced Text  Encyclopedic         671
# 49    Social Sciences    Advanced Text  Encyclopedic         737
#
#     Sentence Count In BAREC Corpus?  average sentence length  \
# 0               31              Yes                21.258065
# 1               23              Yes                25.434783
# 2               38              Yes                20.184211
# 3               24              Yes                25.875000
# 4               49              Yes                20.204082
# 5               32              Yes                21.093750
# 6               39              Yes                19.051282
# 7               27              Yes                26.259259
# 8               31              Yes                19.000000
# 9               56              Yes                16.500000
# 10              30              Yes                22.966667
# 11              29              Yes                21.965517
# 12              28              Yes                28.892857
# 13              29              Yes                25.137931
# 14              44              Yes                18.181818
# 15              35              Yes                24.057143
# 16              44              Yes                17.431818
# 17              28              Yes                22.392857
# 18              38              Yes                23.184211
# 19              40              Yes                21.700000
# 20              33              Yes                18.333333
# 21              28              Yes                23.250000
# 22              37              Yes                18.270270
# 23              26              Yes                26.653846
# 24              23              Yes                29.391304
# 25              25              Yes                18.840000
# 26              16              Yes                21.500000
# 27              29              Yes                25.310345
# 28              24              Yes                30.291667
# 29              26              Yes                25.269231
# 30              27              Yes                24.222222
# 31              30              Yes                24.466667
# 32              27              Yes                21.703704
# 33              27              Yes                20.851852
# 34              23              Yes                26.043478
# 35              37              Yes                21.513514
# 36              32              Yes                21.468750
# 37              32              Yes                20.031250
# 38              43              Yes                18.465116
# 39              28              Yes                21.678571
# 40              26              Yes                24.461538
# 41              28              Yes                24.821429
# 42              27              Yes                21.333333
# 43              29              Yes                24.103448
# 44              27              Yes                28.259259
# 45              37              Yes                24.000000
# 46              37              Yes                19.324324
# 47              21              Yes                36.904762
# 48              35              Yes                19.171429
# 49              28              Yes                26.321429
#
#     sampled_sentence_index
# 0                       27
# 1                        0
# 2                       18
# 3                       16
# 4                       28
# 5                       29
# 6                       26
# 7                        8
# 8                       29
# 9                       23
# 10                      27
# 11                       9
# 12                       9
# 13                       9
# 14                      27
# 15                      33
# 16                      27
# 17                       9
# 18                      33
# 19                      34
# 20                      29
# 21                       9
# 22                      28
# 23                       8
# 24                      15
# 25                       8
# 26                       9
# 27                      27
# 28                       8
# 29                       8
# 30                       8
# 31                      27
# 32                       8
# 33                       8
# 34                      15
# 35                      17
# 36                      29
# 37                      28
# 38                      26
# 39                       8
# 40                       9
# 41                       8
# 42                       9
# 43                      27
# 44                       8
# 45                      36
# 46                      36
# 47                       0
# 48                      15
# 49                       9

# %%
F_df['selected_sent_raw'] = None
F_df['selected_sent_word_count'] = None
F_df['selected_sent_words'] = None

for i, row in F_df.iterrows():
    directory = row['Directory']
    document = row['Document']

    annotations_file_path = (
        f"BAREC-10M/Data/Morphology_and_Readability/"
        f"{directory}/{document}.json"
    )

    with open(annotations_file_path, 'r', encoding='utf-8') as f:
        annotations = json.load(f)

    annotations = pd.DataFrame(annotations)

    selected_sentence_index = int(row['sampled_sentence_index'])

    selected_row = annotations.iloc[selected_sentence_index]

    raw_sentence = selected_row['raw_sents']
    word_count = selected_row['sents_word_count']
    words = selected_row['word']   # list of strings

    F_df.at[i, 'selected_sent_raw'] = raw_sentence
    F_df.at[i, 'selected_sent_word_count'] = word_count
    F_df.at[i, 'selected_sent_words'] = words

# %%
F_df = F_df[[
    'Directory',
    'Document',
    'sampled_sentence_index',
    'Source',
    'Book',
    'Author',
    'Domain',
    'Readership Group',
    'Text Category',
    'average sentence length',
    'selected_sent_raw',
    'selected_sent_word_count',
    'selected_sent_words'
]]

# %%
F_df.rename(columns={
    'average sentence length': 'average_sentence_length_per_doc',
}, inplace=True)

# %%
F_df
# Out:
#     Directory                                           Document  \
# 0   Wikipedia                    BAREC_Wikipedia_أنغكور_وات_001
# 1   Wikipedia                BAREC_Wikipedia_ضريح_سليمان_شاه_001
# 2   Wikipedia            BAREC_Wikipedia_أليساندرو_دل_بييرو_001
# 3   Wikipedia                  BAREC_Wikipedia_عمارة_بنائية_001
# 4   Wikipedia                   BAREC_Wikipedia_ألسنة_اللهب_001
# 5   Wikipedia                          BAREC_Wikipedia_ريتان_001
# 6   Wikipedia                 BAREC_Wikipedia_المسجد_الأقصى_001
# 7   Wikipedia  BAREC_Wikipedia_الموثوقية_التاريخية_للأناجيل_001
# 8   Wikipedia               BAREC_Wikipedia_الحج_في_الإسلام_001
# 9   Wikipedia                BAREC_Wikipedia_ألفية_ابن_مالك_001
# 10  Wikipedia                 BAREC_Wikipedia_الطائر_المقلد_001
# 11  Wikipedia                 BAREC_Wikipedia_الجامع_الأزهر_001
# 12  Wikipedia                 BAREC_Wikipedia_الزوجة_القروية_001
# 13  Wikipedia                BAREC_Wikipedia_شاعر_في_نيويورك_001
# 14  Wikipedia          BAREC_Wikipedia_جامع_بني_أمية_الكبير_001
# 15  Wikipedia             BAREC_Wikipedia_المسجد_الإبراهيمي_001
# 16  Wikipedia                BAREC_Wikipedia_المشاعر_المقدسة_001
# 17  Wikipedia         BAREC_Wikipedia_ترانزستور_ثنائي_القطب_001
# 18  Wikipedia            BAREC_Wikipedia_تاريخ_المنهج_العلمي_001
# 19  Wikipedia                       BAREC_Wikipedia_إلكترون_001
# 20  Wikipedia                      BAREC_Wikipedia_عدد أولي_001
# 21  Wikipedia             BAREC_Wikipedia_مرصد_هابل_الفضائي_001
# 22  Wikipedia                   BAREC_Wikipedia_ذكاء_اصطناعي_001
# 23  Wikipedia                       BAREC_Wikipedia_بث_متعدد_001
# 24  Wikipedia                          BAREC_Wikipedia_روبوت_001
# 25  Wikipedia                       BAREC_Wikipedia_خوارزمية_001
# 26  Wikipedia                  BAREC_Wikipedia_تجزئة_الشبكة_001
# 27  Wikipedia  BAREC_Wikipedia_بروتوكول_التوجيه_الداخلي_المحس...
# 28  Wikipedia             BAREC_Wikipedia_تاريخ_علم_الأحياء_001
# 29  Wikipedia  BAREC_Wikipedia_تاريخ_الإمارات_العربية_المتحد...
# 30  Wikipedia                         BAREC_Wikipedia_فيزياء_001
# 31  Wikipedia  BAREC_Wikipedia_بروتوكول_تهيئة_المضيف_الآلية...
# 32  Wikipedia                 BAREC_Wikipedia_تمثيل_القبولية_001
# 33  Wikipedia                      BAREC_Wikipedia_بوبي_فيشر_001
# 34  Wikipedia        BAREC_Wikipedia_المهرجان_العالمي_للعلوم_001
# 35  Wikipedia  BAREC_Wikipedia_حفل_زفاف_الأمير_ويليام_وكيت_م...
# 36  Wikipedia                    BAREC_Wikipedia_عروج_بربروس_001
# 37  Wikipedia                      BAREC_Wikipedia_ابن_خلدون_001
# 38  Wikipedia                       BAREC_Wikipedia_أرمينيا_001
# 39  Wikipedia                    BAREC_Wikipedia_بوبي_روبسون_001
# 40  Wikipedia                    BAREC_Wikipedia_طريق_الحرير_001
# 41  Wikipedia                       BAREC_Wikipedia_الريفيون_001
# 42  Wikipedia                   BAREC_Wikipedia_تاريخ_الكويت_001
# 43  Wikipedia                          BAREC_Wikipedia_كيرلا_001
# 44  Wikipedia                    BAREC_Wikipedia_بايرن_ميونخ_001
# 45  Wikipedia             BAREC_Wikipedia_رجال_المينتش_الزرق_001
# 4                         20.204082
# 5                         21.093750
# 6                         19.051282
# 7                         26.259259
# 8                         19.000000
# 9                         16.500000
# 10                        22.966667
# 11                        21.965517
# 12                        28.892857
# 13                        25.137931
# 14                        18.181818
# 15                        24.057143
# 16                        17.431818
# 17                        22.392857
# 18                        23.184211
# 19                        21.700000
# 20                        18.333333
# 21                        23.250000
# 22                        18.270270
# 23                        26.653846
# 24                        29.391304
# 25                        18.840000
# 26                        21.500000
# 27                        25.310345
# 28                        30.291667
# 29                        25.269231
# 30                        24.222222
# 31                        24.466667
# 32                        21.703704
# 33                        20.851852
# 34                        26.043478
# 35                        21.513514
# 36                        21.468750
# 37                        20.031250
# 38                        18.465116
# 39                        21.678571
# 40                        24.461538
# 41                        24.821429
# 42                        21.333333
# 43                        24.103448
# 44                        28.259259
# 45                        24.000000
# 46                        19.324324
# 47                        36.904762
# 48                        19.171429
# 49                        26.321429
#
#                                     selected_sent_raw  \
# 0   يرجع ذلك إلى وجود الخندق المائي الذي قام كعامل...
# 1   قبر سليمان شاه أو ضريح سليمان شاه (بالتركية ال...
# 2   وترعرع في قرية «ساكون» ببلدية سان فينديميانو ا...
# 3   وقد تمحور هذا الصراع منذ البداية بين شخصيتين ر...
# 4   توفي والدها في انفجار منجم تعدين قبل سنوات، وه...
# 5   وكانت نسبة 16.3% من القاطنين تحت سن الثامنة عش...
# 6                          '== تاريخ المسجد الأقصى ==
# 7   يلجأ المؤرخون الذين يخضعون الأناجيل إلى التحلي...
# 8   والطوائف الإسلامية المختلفة، من سنة وشيعة، تؤد...
# 9   محمد بن عبد الله بن محمد بن عبد الله بن مالك ا...
# 10  ففي الميثولوجيا الإغريقية، كعقوبة على مقتل أند...
# 11  يعتبر المسجد ثاني أقدم جامعة قائمة بشكل مستمر ...
# 12  ولكن من جديد عادت المسرحية الأصلية لتُصبح مُفض...
# 13  لقد كان هذا الديوان صرخة مدويّة ضد الرّعب، للت...
# 14  وقد أُعجب السكان المحليين بتماثُل وأبعاد «معبد...
# 15  قال ابن كثير في كتابه البداية والنهاية: «فقبره...
# 16  ثبير الأثبرة: أو ثبير غيناء، يواجه جبل النور م...
# 17  ولهذا فإنّ الترانزستور يخضع لقواعد التحييز الخ...
# 18  في محاورة بروتاغوراس، ذكر أفلاطون وجود تعليم ل...
# 19  وكان قادرًا على تقييم قيمة هذه الشحنة الأولية ...
# 20  3 عدد أولي أيضا لأن القاسمين الوحيدين له هما 1...
# 21  لقد أدَّت العديد من مُشاهدات مرصد هابل إلى تقد...
# 22  بحلول منتصف الستينيات أصبحت تلك البحوث تمول بس...
# 23                                   '== نظرة عامة ==
# 24  وهذه الإنسالات مبرمجة عادةً لتنفيذ مهامها بصور...
# 25   هذه الطريقة هي ما تسمى اتخاذ القرار أو الاختيار.
# 26  تجزئة فضاء العناوين هي عملية رياضية يُقسَّم فض...
# 27  واستغرق العمل 3 سنوات أخرى، مع مشاركة من أطراف...
# 28  بدأ أنطوان لافوازييه وغيره من علماء الفيزياء ب...
# 29          لأرض الإمارات العربية المتحدة تاريخ قديم.
# 30  تهتم الفيزياء في نفس الوقت بدقة القياس وابتكار...
# 31  في حين يعتمد العملاء الموجودون في شبكة بعيدة ع...
# 32  وبالتالي جميع قوانين تحليل الدوائر الكهربية - ...
# 33  في تموز 1971 صار فيشر الأول عالمياً في تصنيف ا...
# 34  وفقًا لغرين، فإن الفكرة لاقت القبول والاستحسان...
# 35                               '=== بروفة الحفل ===
# 36  وبعد أن استقر يعقوب في الجزيرة وانتظمت أمور حي...
# 37  فإذا كان جده الداخل إلى الأندلس عند الفتح فإن ...
# 38  بلغت المملكة ذروتها بين 95 و66 قبل الميلاد تحت...
# 39  عانى من مشاكل بالرئة منذ عام 1991، حتى أعلن في...
# 40  وقد أذهلت هذه الصناعة الناس قديماً، فسعوا لاقت...
# 41  في نفس السياق، يصنف الأنثروبولوجيون أيضا سكان ...
# 42                              '== التاريخ القديم ==
# 43  وتُعد إحدى الوجهات السياحية البارزة في الهند، ...
# 44  فاز بايرن أيضًا بكأس الاتحاد الأوروبي مرة واحد...
# 45  وعندما تنقلب السفينة يجعلهم هذا الأمر يضحكون م...
# 46  من الأسماء الأخرى لمكة في التوراة: تل فران، وه...
# 47  الصومال (بالصومالية: Soomaaliya)‏، أو (رسمياً:...
# 48  إن اقتصاد دولة الإمارات يحتل المرتبة 22 على مس...
# 49  وبعد قرن من ظهور كتاب كريستين دي بيزان، ستؤكد ...
#
#    selected_sent_word_count                                selected_sent_words
# 0                        15  [يرجع, ذلك, إلى, وجود, الخندق, المائي, الذي, ق...
# 1                        38  [قبر, سليمان, شاه, أو, ضريح, سليمان, شاه, (, ب...
# 2                        10  [وترعرع, في, قرية, ", ساكون, ", ببلدية, سان, ف...
# 3                        16  [وقد, تمحور, هذا, الصراع, منذ, البداية, بين, ش...
# 4                        37  [توفي, والدها, في, انفجار, منجم, تعدين, قبل, س...
# 5                        26  [وكانت, نسبة, 16, ., 3, %, من, القاطنين, تحت, ...
# 6                         7             [', =, =, تاريخ, المسجد, الأقصى, =, =]
# 7                        20  [يلجأ, المؤرخون, الذين, يخضعون, الأناجيل, إلى,...
# 8                        14  [والطوائف, الإسلامية, المختلفة, ,, من, سنة, وش...
# 9                        23  [محمد, بن, عبد, الله, بن, محمد, بن, عبد, الله,...
# 10                       34  [ففي, الميثولوجيا, الإغريقية, ,, كعقوبة, على, ...
# 11                       14  [يعتبر, المسجد, ثاني, أقدم, جامعة, قائمة, بشكل...
# 12                       35  [ولكن, من, جديد, عادت, المسرحية, الأصلية, لتصب...
# 13                       33  [لقد, كان, هذا, الديوان, صرخة, مدوية, ضد, الرع...
# 14                       13  [وقد, أعجب, السكان, المحليين, بتماثل, وأبعاد, ...
# 15                       37  [قال, ابن, كثير, في, كتابه, البداية, والنهاية,...
# 16                       28  [ثبير, الأثبرة, :, أو, ثبير, غيناء, ,, يواجه, ...
# 17                       10  [ولهذا, فإن, الترانزستور, يخضع, لقواعد, التحيي...
# 18                       14  [في, محاورة, بروتاغوراس, ,, ذكر, أفلاطون, وجود...
# 19                       16  [وكان, قادرا, على, تقييم, قيمة, هذه, الشحنة, ا...
# 20                       14  [3, عدد, أولي, أيضا, لأن, القاسمين, الوحيدين, ...
# 21                       21  [لقد, أدت, العديد, من, مشاهدات, مرصد, هابل, إل...
# 22                       13  [بحلول, منتصف, الستينيات, أصبحت, تلك, البحوث, ...
# 23                        6                        [', =, =, نظرة, عامة, =, =]
# 24                       11  [وهذه, الإنسالات, مبرمجة, عادة, لتنفيذ, مهامها...
# 25                       10  [هذه, الطريقة, هي, ما, تسمى, اتخاذ, القرار, أو...
# 26                       20  [تجزئة, فضاء, العناوين, هي, عملية, رياضية, يقس...
# 27                       22  [واستغرق, العمل, 3, سنوات, أخرى, ,, مع, مشاركة...
# 28                       16  [بدأ, أنطوان, لافوازييه, وغيره, من, علماء, الف...
# 29                        7  [لأرض, الإمارات, العربية, المتحدة, تاريخ, قديم...
# 30                       15  [تهتم, الفيزياء, في, نفس, الوقت, بدقة, القياس,...
# 31                       29  [في, حين, يعتمد, العملاء, الموجودون, في, شبكة,...
# 32                       24  [وبالتالي, جميع, قوانين, تحليل, الدوائر, الكهر...
# 33                       13  [في, تموز, 1971, صار, فيشر, الأول, عالميا, في,...
# 34                       25  [وفقا, لغرين, ,, فإن, الفكرة, لاقت, القبول, وا...
# 35                        8                [', =, =, =, بروفة, الحفل, =, =, =]
# 36                       23  [وبعد, أن, استقر, يعقوب, في, الجزيرة, وانتظمت,...
# 37                       31  [فإذا, كان, جده, الداخل, إلى, الأندلس, عند, ال...
# 38                       24  [بلغت, المملكة, ذروتها, بين, 95, و66, قبل, الم...
# 39                       18  [عانى, من, مشاكل, بالرئة, منذ, عام, 1991, ,, ح...
# 40                       23  [وقد, أذهلت, هذه, الصناعة, الناس, قديما, ,, فس...
# 41                       17  [في, نفس, السياق, ,, يصنف, الأنثروبولوجيون, أي...
# 42                        6                   [', =, =, التاريخ, القديم, =, =]
# 43                       17  [وتعد, إحدى, الوجهات, السياحية, البارزة, في, ا...
# 44                       30  [فاز, بايرن, أيضا, بكأس, الاتحاد, الأوروبي, مر...
# 45                       10  [وعندما, تنقلب, السفينة, يجعلهم, هذا, الأمر, ي...
# 46                       19  [من, الأسماء, الأخرى, لمكة, في, التوراة, :, تل...
# 47                       65  [الصومال, (, بالصومالية, :, Soomaaliya, ), ,, ...
# 48                       15  [إن, اقتصاد, دولة, الإمارات, يحتل, المرتبة, 22...
# 49                       19  [وبعد, قرن, من, ظهور, كتاب, كريستين, دي, بيزان...

# %%
# F_df.to_json('sampled_EN_sentences.json', orient='records', force_ascii=False, indent=4)

# %%
## Data groups:

# A --> Literature; Arts & Music
# B --> Media & Culture
# C --> Educational Materials; Language & Linguistics
# D --> Academic
# E --> Religion & Philosophy
# F --> Encyclopedic

# %%
## Annotators:

# 1 --> 
# 2 --> 
# 3 -->
# 4 -->
# 5 -->
# 6 -->

# %%
## Annotation Assignment:

# A --> 1, 2, 3
# B --> 1, 2, 4
# C --> 1, 5, 6
# D --> 2, 5, 6
# E --> 3, 4, 5
# F --> 3, 4, 6
